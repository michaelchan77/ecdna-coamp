# %%
import pandas as pd
import numpy as np
import re
from ast import literal_eval
from scipy.stats import expon

# %%
# imports

# %%
edges = pd.read_csv("/Users/michael/Downloads/neo4j-community-5.12.0/import/test_edges.csv")

# %%
edges
# Out:
#            source     target    weight  \
# 0          ARNTL2    SLCO1B1  1.000000
# 1           COX10      MYOCD  1.000000
# 2           DUPD1    SYNPO2L  0.666667
# 3        B4GALNT2    TPD52L2  0.250000
# 4       ANKRD40CL  NME1-NME2  0.333333
# ...           ...        ...       ...
# 118028     TM4SF4      WWTR1  1.000000
# 118029     LPCAT3       PHB2  1.000000
# 118030     NT5C1A     MANEAL  0.083333
# 118031        NLK     RPL23A  1.000000
# 118032      MIEN1    WFDC21P  0.076923
#
#                                                     inter  \
# 0                         NCIH2171_LUNG_amplicon2_ecDNA_1
# 1                          SNU182_LIVER_amplicon1_ecDNA_1
# 2       PC3_PROSTATE_amplicon1_ecDNA_2|EFM19_BREAST_am...
# 3                        HCC1419_BREAST_amplicon1_ecDNA_2
# 4                        EFM192A_BREAST_amplicon1_ecDNA_2
# ...                                                   ...
# 118028                     HCC38_BREAST_amplicon3_ecDNA_1
# 118029                    NCIH2171_LUNG_amplicon2_ecDNA_2
# 118030                    NCIH1184_LUNG_amplicon1_ecDNA_1
# 118031               KYSE410_OESOPHAGUS_amplicon3_ecDNA_1
# 118032                     BT474_BREAST_amplicon1_ecDNA_3
#
#                                                     union
# 0                         NCIH2171_LUNG_amplicon2_ecDNA_1
# 1                          SNU182_LIVER_amplicon1_ecDNA_1
# 2       PC3_PROSTATE_amplicon1_ecDNA_2|MFE280_ENDOMETR...
# 3       JHOS2_OVARY_amplicon5_ecDNA_1|BT474_BREAST_amp...
# 4       HCC202_BREAST_amplicon3_ecDNA_2|EFM192A_BREAST...
# ...                                                   ...
# 118028                     HCC38_BREAST_amplicon3_ecDNA_1
# 118029                    NCIH2171_LUNG_amplicon2_ecDNA_2
# 118030  NCIH1963_LUNG_amplicon1_ecDNA_1|NCIH1836_LUNG_...
# 118031               KYSE410_OESOPHAGUS_amplicon3_ecDNA_1
# 118032  MKN7_STOMACH_amplicon7_ecDNA_1|HCC202_BREAST_a...
#
# [118033 rows x 5 columns]

# %%
gene_coords = pd.read_csv("/Users/michael/Downloads/hg38_genes.bed", sep="\t", header=None)

# %%
gene_coords
# Out:
#           0         1         2          3  4  5             6
# 0      chr1     11873     14409    DDX11L1  .  +     NR_046018
# 1      chr1     14361     29370     WASH7P  .  -     NR_024540
# 2      chr1     34610     36081    FAM138A  .  -     NR_026818
# 3      chr1     34610     36081    FAM138F  .  -     NR_026820
# 4      chr1     34610     36081    FAM138C  .  -     NR_026822
# ...     ...       ...       ...        ... .. ..           ...
# 22993  chrY  24045229  24048014       CDY1  .  -     NM_004680
# 22994  chrY  24045229  24048014      CDY1B  .  -  NM_001003895
# 22995  chrY  24183433  24187231   CSPG4P1Y  .  -     NR_001554
# 22996  chrY  24209966  24214831  GOLGA2P2Y  .  -     NR_001555
# 22997  chrY  24209966  24214831  GOLGA2P3Y  .  -     NR_002195
#
# [22998 rows x 7 columns]

# %%
# save loc data in dictionary

# %%
gene_coords['chr_num'] = gene_coords.apply(lambda row: row[0][-1], axis=1)

# %%
locs = {}
for i,row in gene_coords.iterrows():
    locs[row[3]] = (row['chr_num'], int(row[1]))

# %%
locs
# Out:
# {'DDX11L1': ('1', 11873),
#  'WASH7P': ('1', 14361),
#  'FAM138A': ('1', 34610),
#  'FAM138F': ('1', 34610),
#  'FAM138C': ('1', 34610),
#  'OR4F5': ('1', 69090),
#  'FAM138D': ('1', 205128),
#  'OR4F3': ('1', 450739),
#  'OR4F29': ('1', 450739),
#  'OR4F16': ('1', 450739),
#  'FAM87B': ('1', 817370),
#  'FAM41C': ('1', 868070),
#  'SAMD11': ('1', 925730),
#  'NOC2L': ('1', 944202),
#  'KLHL17': ('1', 960583),
#  'PLEKHN1': ('1', 966481),
#  'PERM1': ('1', 975197),
#  'HES4': ('1', 998963),
#  'ISG15': ('1', 1013496),
#  'AGRN': ('1', 1020119),
#  'RNF223': ('1', 1070966),
#  'C1orf159': ('1', 1081822),
#  'TTLL10': ('1', 1173879),
#  'TNFRSF18': ('1', 1203507),
#  'TNFRSF4': ('1', 1211339),
#  'SDF4': ('1', 1216907),
#  'B3GALT6': ('1', 1232236),
#  'C1QTNF12': ('1', 1242452),
#  'UBE2J2': ('1', 1253911),
#  'SCNN1D': ('1', 1280435),
#  'ACAP3': ('1', 1292390),
#  'SNORD167': ('1', 1304728),
#  'PUSL1': ('1', 1308579),
#  'INTS11': ('1', 1311584),
#  'CPTP': ('1', 1324801),
#  'TAS1R3': ('1', 1331279),
#  'DVL1': ('1', 1335277),
#  'MXRA8': ('1', 1352688),
#  'AURKAIP1': ('1', 1373735),
#  'CCNL2': ('1', 1385710),
#  'MRPL20-AS1': ('1', 1399529),
#  'MRPL20': ('1', 1401908),
#  'ANKRD65': ('1', 1418419),
#  'TMEM88B': ('1', 1426127),
#  'VWA1': ('1', 1435689),
#  'ATAD3C': ('1', 1449688),
#  'ATAD3B': ('1', 1471764),
#  'ATAD3A': ('1', 1512161),
#  'TMEM240': ('1', 1534777),
#  'SSU72': ('1', 1541672),
#  'FNDC10': ('1', 1598011),
#  'MIB2': ('1', 1615414),
#  'MMP23B': ('1', 1632172),
#  'MMP23A': ('1', 1632779),
#  'CDK11B': ('1', 1635224),
#  'SLC35E2B': ('1', 1661477),
#  'CDK11A': ('1', 1702378),
#  'SLC35E2A': ('1', 1724837),
#  'NADK': ('1', 1751231),
#  'GNB1': ('1', 1785284),
#  'CALML6': ('1', 1915259),
#  'TMEM52': ('1', 1917590),
#  'CFAP74': ('1', 1921956),
#  'GABRD': ('1', 2019344),
#  'PRKCZ': ('1', 2050410),
#  'PRKCZ-AS1': ('1', 2181793),
#  'FAAP20': ('1', 2184459),
#  'SKI': ('1', 2228318),
#  'MORN1': ('1', 2321252),
#  'RER1': ('1', 2391840),
#  'PEX10': ('1', 2404801),
#  'PLCH2': ('1', 2467450),
#  'PANK4': ('1', 2508536),
#  'HES5': ('1', 2528744),
#  'TNFRSF14-AS1': ('1', 2549919),
#  'TNFRSF14': ('1', 2556364),
#  'PRXL2B': ('1', 2586522),
#  'MMEL1': ('1', 2590639),
#  'TTC34': ('1', 2641268),
#  'ACTRT2': ('1', 3021466),
#  'PRDM16-DT': ('1', 3059616),
#  'PRDM16': ('1', 3069202),
#  'ARHGEF16': ('1', 3454664),
#  'MEGF6': ('1', 3487950),
#  'TPRG1L': ('1', 3625014),
#  'WRAP73': ('1', 3630769),
#  'TP73': ('1', 3652515),
#  'TP73-AS1': ('1', 3735983),
#  'CCDC27': ('1', 3752449),
#  'SMIM1': ('1', 3772760),
#  'LRRC47': ('1', 3778558),
#  'CEP104': ('1', 3812085),
#  'DFFB': ('1', 3857266),
#  'C1orf174': ('1', 3889132),
#  'AJAP1': ('1', 4654608),
#  'NPHP4': ('1', 5862810),
#  'KCNAB2': ('1', 5992675),
#  'CHD5': ('1', 6101786),
#  'RPL22': ('1', 6185019),
#  'RNF207': ('1', 6206118),
#  'ICMT': ('1', 6221192),
#  'HES3': ('1', 6244178),
#  'GPR153': ('1', 6247352),
#  'ACOT7': ('1', 6264271),
#  'HES2': ('1', 6415233),
#  'ESPN': ('1', 6424775),
#  'TNFRSF25': ('1', 6461153),
#  'PLEKHG5': ('1', 6466091),
#  'NOL9': ('1', 6521346),
#  'TAS1R1': ('1', 6555306),
#  'ZBTB48': ('1', 6579993),
#  'KLHL21': ('1', 6590723),
#  'PHF13': ('1', 6613730),
#  'THAP3': ('1', 6624864),
#  'DNAJC11': ('1', 6634169),
#  'CAMTA1-DT': ('1', 6783891),
#  'CAMTA1': ('1', 6785323),
#  'CAMTA1-AS2': ('1', 7382486),
#  'VAMP3': ('1', 7771295),
#  'PER3': ('1', 7784186),
#  'UTS2': ('1', 7847611),
#  'TNFRSF9': ('1', 7915870),
#  'PARK7': ('1', 7961653),
#  'ERRFI1': ('1', 8011726),
#  'SLC45A1': ('1', 8318113),
#  'RERE': ('1', 8352403),
#  'RERE-AS1': ('1', 8424644),
#  'SNORD128': ('1', 8494799),
#  'ENO1': ('1', 8860999),
#  'ENO1-AS1': ('1', 8878834),
#  'CA6': ('1', 8945867),
#  'SLC2A7': ('1', 9003299),
#  'SLC2A5': ('1', 9035105),
#  'GPR157': ('1', 9100304),
#  'LNCTAM34A': ('1', 9182203),
#  'H6PD': ('1', 9234773),
#  'SPSB1': ('1', 9292893),
#  'SLC25A33': ('1', 9539464),
#  'TMEM201': ('1', 9588910),
#  'PIK3CD': ('1', 9651730),
#  'PIK3CD-AS1': ('1', 9652609),
#  'PIK3CD-AS2': ('1', 9672425),
#  'CLSTN1': ('1', 9728925),
#  'CTNNBIP1': ('1', 9848275),
#  'LZIC': ('1', 9922117),
#  'NMNAT1': ('1', 9942922),
#  'TMEM274P': ('1', 9950571),
#  'RBP7': ('1', 9997227),
#  'UBE4B': ('1', 10032957),
#  'KIF1B': ('1', 10210569),
#  'RNU6-1': ('1', 10298965),
#  'RNU6-9': ('1', 10298965),
#  'RNU6-7': ('1', 10298965),
#  'RNU6-8': ('1', 10298965),
#  'RNU6-2': ('1', 10298965),
#  'PGD': ('1', 10399063),
#  'CENPS': ('1', 10430432),
#  'CENPS-CORT': ('1', 10430432),
#  'CORT': ('1', 10450030),
#  'DFFA': ('1', 10456521),
#  'PEX14': ('1', 10474949),
#  'CASZ1': ('1', 10636605),
#  'C1orf127': ('1', 10946472),
#  'TARDBP': ('1', 11012621),
#  'MASP2': ('1', 11026522),
#  'SRM': ('1', 11054589),
#  'EXOSC10': ('1', 11066618),
#  'EXOSC10-AS1': ('1', 11099674),
#  'MTOR': ('1', 11106534),
#  'MTOR-AS1': ('1', 11143897),
#  'ANGPTL7': ('1', 11189354),
#  'UBIAD1': ('1', 11273197),
#  'DISP3': ('1', 11479154),
#  'FBXO2': ('1', 11648386),
#  'FBXO44': ('1', 11654406),
#  'FBXO6': ('1', 11664199),
#  'MAD2L2': ('1', 11674479),
#  'DRAXIN': ('1', 11691709),
#  'AGTRAP': ('1', 11736084),
#  'C1orf167': ('1', 11762192),
#  'C1orf167-AS1': ('1', 11777076),
#  'MTHFR': ('1', 11785725),
#  'CLCN6': ('1', 11806095),
#  'NPPA-AS1': ('1', 11840318),
#  'NPPA': ('1', 11845709),
#  'NPPB': ('1', 11857463),
#  'RNU5E-1': ('1', 11908153),
#  'KIAA2013': ('1', 11919590),
#  'PLOD1': ('1', 11934716),
#  'MFN2': ('1', 11980180),
#  'MIIP': ('1', 12019497),
#  'TNFRSF8': ('1', 12063302),
#  'TNFRSF1B': ('1', 12166990),
#  'VPS13D': ('1', 12230029),
#  'SNORA59B': ('1', 12507245),
#  'SNORA59A': ('1', 12507245),
#  'DHRS3': ('1', 12567909),
#  'AADACL4': ('1', 12644546),
#  'AADACL3': ('1', 12716109),
#  'C1orf158': ('1', 12746199),
#  'PRAMEF12': ('1', 12774847),
#  'PRAMEF1': ('1', 12791396),
#  'PRAMEF11': ('1', 12824604),
#  'HNRNPCL1': ('1', 12847376),
#  'PRAMEF2': ('1', 12857085),
#  'PRAMEF4': ('1', 12879211),
#  'PRAMEF10': ('1', 12892895),
#  'PRAMEF7': ('1', 12916646),
#  'PRAMEF6': ('1', 12938471),
#  'PRAMEF27': ('1', 13049807),
#  'HNRNPCL3': ('1', 13061231),
#  'HNRNPCL4': ('1', 13061309),
#  'PRAMEF26': ('1', 13073677),
#  'PRAMEF25': ('1', 13073677),
#  'PRAMEF36P': ('1', 13094514),
#  'PRAMEF34P': ('1', 13094514),
#  'HNRNPCL2': ('1', 13115487),
#  'PRAMEF9': ('1', 13175280),
#  'PRAMEF13': ('1', 13196187),
#  'PRAMEF18': ('1', 13222694),
#  'PRAMEF22': ('1', 13223331),
#  'PRAMEF5': ('1', 13254197),
#  'PRAMEF8': ('1', 13281303),
#  'PRAMEF33': ('1', 13303538),
#  'PRAMEF15': ('1', 13315580),
#  'PRAMEF14': ('1', 13341891),
#  'PRAMEF19': ('1', 13368430),
#  'PRAMEF17': ('1', 13389631),
#  'PRAMEF20': ('1', 13410449),
#  'LRRC38': ('1', 13474972),
#  'PDPN': ('1', 13583756),
#  'PRDM2': ('1', 13700187),
#  'KAZN-AS1': ('1', 14348954),
#  'KAZN': ('1', 14598684),
#  'TMEM51-AS1': ('1', 15111814),
#  'TMEM51': ('1', 15152531),
#  'C1orf195': ('1', 15164195),
#  'FHAD1': ('1', 15247224),
#  'FHAD1-AS1': ('1', 15326679),
#  'EFHD2': ('1', 15409887),
#  'CTRC': ('1', 15438442),
#  'CELA2A': ('1', 15456731),
#  'CELA2B': ('1', 15476103),
#  'CASP9': ('1', 15491400),
#  'DNAJC16': ('1', 15526812),
#  'SCARNA21B': ('1', 15542165),
#  'AGMAT': ('1', 15571698),
#  'DDI2': ('1', 15617457),
#  'RSC1A1': ('1', 15659712),
#  'PLEKHM2': ('1', 15684319),
#  'SLC25A34': ('1', 15736257),
#  'SLC25A34-AS1': ('1', 15740050),
#  'TMEM82': ('1', 15742498),
#  'FBLIM1': ('1', 15756637),
#  'UQCRHL': ('1', 15807161),
#  'FLJ37453': ('1', 15834214),
#  'SPEN': ('1', 15847706),
#  'ZBTB17': ('1', 15941868),
#  'SRARP': ('1', 16004235),
#  'HSPB7': ('1', 16014027),
#  'CLCNKA': ('1', 16022035),
#  'CLCNKB': ('1', 16043781),
#  'FAM131C': ('1', 16057768),
#  'EPHA2': ('1', 16124336),
#  'ARHGEF19': ('1', 16197853),
#  'CPLANE2': ('1', 16231691),
#  'FBXO42': ('1', 16246839),
#  'SZRD1': ('1', 16367241),
#  'SPATA21': ('1', 16395680),
#  'NECAP2': ('1', 16440671),
#  'CROCCP3': ('1', 16467435),
#  'RNVU1-18': ('1', 16514121),
#  'RNU1-3': ('1', 16514121),
#  'RNU1-4': ('1', 16514121),
#  'RNU1-2': ('1', 16514121),
#  'RNU1-1': ('1', 16514121),
#  'NBPF1': ('1', 16562322),
#  'CROCCP2': ('1', 16618255),
#  'MST1P2': ('1', 16645573),
#  'ESPNP': ('1', 16691217),
#  'MST1L': ('1', 16754633),
#  'CROCC': ('1', 16921930),
#  'MFAP2': ('1', 16974503),
#  'ATP13A2': ('1', 16985957),
#  'SDHB': ('1', 17018725),
#  'PADI2': ('1', 17066760),
#  'PADI1': ('1', 17205127),
#  'PADI3': ('1', 17249097),
#  'PADI4': ('1', 17308196),
#  'PADI6': ('1', 17372195),
#  'RCC2': ('1', 17406759),
#  'ARHGEF10L': ('1', 17539697),
#  'ACTL8': ('1', 17755332),
#  'IGSF21': ('1', 18107797),
#  'KLHDC7A': ('1', 18480929),
#  'PAX7': ('1', 18630845),
#  'TAS1R2': ('1', 18839598),
#  'ALDH4A1': ('1', 18871429),
#  'IFFO2': ('1', 18904279),
#  'UBR4': ('1', 19074510),
#  'EMC1-AS1': ('1', 19210385),
#  'EMC1': ('1', 19215660),
#  'MRTO4': ('1', 19251804),
#  'AKR7L': ('1', 19265981),
#  'AKR7A3': ('1', 19282572),
#  'AKR7A2': ('1', 19302707),
#  'SLC66A1': ('1', 19312325),
#  'CAPZB': ('1', 19338774),
#  'MICOS10': ('1', 19596976),
#  'MICOS10-NBL1': ('1', 19596978),
#  'RPS14P3': ('1', 19607806),
#  'NBL1': ('1', 19643228),
#  'HTR6': ('1', 19664874),
#  'TMCO4': ('1', 19682212),
#  'RNF186': ('1', 19814028),
#  'OTUD3': ('1', 19882394),
#  'PLA2G2E': ('1', 19920008),
#  'PLA2G2A': ('1', 19975430),
#  'PLA2G5': ('1', 20070193),
#  'PLA2G2D': ('1', 20111940),
#  'PLA2G2F': ('1', 20139322),
#  'PLA2G2C': ('1', 20163054),
#  'UBXN10-AS1': ('1', 20184242),
#  'UBXN10': ('1', 20186095),
#  'VWA5B1': ('1', 20290874),
#  'CAMK2N1': ('1', 20482390),
#  'MUL1': ('1', 20499447),
#  'FAM43B': ('1', 20552572),
#  'CDA': ('1', 20589096),
#  'PINK1': ('1', 20633457),
#  'PINK1-AS': ('1', 20642656),
#  'DDOST': ('1', 20651766),
#  'KIF17': ('1', 20664013),
#  'SH2D5': ('1', 20719730),
#  'HP1BP3': ('1', 20740265),
#  'EIF4G3': ('1', 20806291),
#  'ECE1': ('1', 21217249),
#  'ECE1-AS1': ('1', 21293289),
#  'NBPF3': ('1', 21440136),
#  'ALPL': ('1', 21508983),
#  'RAP1GAP': ('1', 21596220),
#  'USP48': ('1', 21678298),
#  'LDLRAD2': ('1', 21812264),
#  'HSPG2': ('1', 21822243),
#  'CELA3B': ('1', 21977021),
#  'CELA3A': ('1', 22001656),
#  'CDC42': ('1', 22052708),
#  'WNT4': ('1', 22117312),
#  'ZBTB40': ('1', 22451850),
#  'EPHA8': ('1', 22563488),
#  'C1QA': ('1', 22636627),
#  'C1QC': ('1', 22643632),
#  'C1QB': ('1', 22653235),
#  'EPHB2': ('1', 22710837),
#  'LACTBL1': ('1', 22953042),
#  'TEX46': ('1', 23010833),
#  'KDM1A': ('1', 23019467),
#  'LUZP1': ('1', 23084022),
#  'HTR1D': ('1', 23191894),
#  'HNRNPR': ('1', 23304689),
#  'ZNF436': ('1', 23359447),
#  'ZNF436-AS1': ('1', 23368970),
#  'TCEA3': ('1', 23380908),
#  'ASAP3': ('1', 23428562),
#  'E2F2': ('1', 23506437),
#  'ID3': ('1', 23557925),
#  'MDS2': ('1', 23627333),
#  'RPL11': ('1', 23691778),
#  'ELOA': ('1', 23743365),
#  'ELOA-AS1': ('1', 23760381),
#  'PITHD1': ('1', 23778417),
#  'LYPLA2': ('1', 23791144),
#  'GALE': ('1', 23795598),
#  'HMGCL': ('1', 23801876),
#  'FUCA1': ('1', 23845080),
#  'CNR2': ('1', 23870515),
#  'PNRC2': ('1', 23959827),
#  'SRSF10': ('1', 23964346),
#  'MYOM3': ('1', 24056040),
#  'IL22RA1': ('1', 24119770),
#  'IFNLR1': ('1', 24154171),
#  'GRHL3': ('1', 24319356),
#  'STPG1': ('1', 24356998),
#  'NIPAL3': ('1', 24413486),
#  'RCAN3AS': ('1', 24496253),
#  'RCAN3': ('1', 24502343),
#  'NCMAP-DT': ('1', 24539273),
#  'NCMAP': ('1', 24556086),
#  'SRRM1': ('1', 24643301),
#  'CLIC4': ('1', 24745446),
#  'RUNX3': ('1', 24899510),
#  'SYF2': ('1', 25222275),
#  'RSRP1': ('1', 25242236),
#  'RHD': ('1', 25272485),
#  'TMEM50A': ('1', 25338333),
#  'RHCE': ('1', 25362248),
#  'MACO1': ('1', 25430857),
#  'LDLRAP1': ('1', 25543605),
#  'MAN1C1': ('1', 25617467),
#  'SELENON': ('1', 25800192),
#  'MTFR1L': ('1', 25819905),
#  'AUNIP': ('1', 25831912),
#  'PAQR7': ('1', 25861483),
#  'STMN1': ('1', 25884178),
#  'PAFAH2': ('1', 25959766),
#  'EXTL1': ('1', 26021774),
#  'SLC30A2': ('1', 26037251),
#  'TRIM63': ('1', 26051304),
#  'PDIK1L': ('1', 26111164),
#  'FAM110D': ('1', 26159078),
#  'C1orf232': ('1', 26164160),
#  'ZNF593': ('1', 26169907),
#  'CNKSR1': ('1', 26177490),
#  'CATSPER4': ('1', 26190627),
#  'ZPLD2P': ('1', 26225319),
#  'CEP85': ('1', 26234199),
#  'SH3BGRL3': ('1', 26280085),
#  'UBXN11': ('1', 26282281),
#  'CD52': ('1', 26317957),
#  'CRYBG2': ('1', 26321858),
#  'ZNF683': ('1', 26361633),
#  'LIN28A': ('1', 26410816),
#  'DHDDS': ('1', 26432281),
#  'DHDDS-AS1': ('1', 26462756),
#  'HMGN2': ('1', 26472439),
#  'RPS6KA1': ('1', 26529760),
#  'ARID1A': ('1', 26696014),
#  'PIGV': ('1', 26787962),
#  'ZDHHC18': ('1', 26826687),
#  'SFN': ('1', 26863148),
#  'GPN2': ('1', 26876131),
#  'GPATCH3': ('1', 26890487),
#  'NR0B2': ('1', 26911488),
#  'NUDC': ('1', 26921742),
#  'KDF1': ('1', 26949561),
#  'TRNP1': ('1', 26993691),
#  'TENT5B': ('1', 27005019),
#  'SLC9A1': ('1', 27098808),
#  'WDTC1': ('1', 27234631),
#  'TMEM222': ('1', 27322144),
#  'ACTG1P20': ('1', 27323873),
#  'SYTL1': ('1', 27342021),
#  'MAP3K6': ('1', 27355183),
#  'FCN3': ('1', 27369109),
#  'CD164L2': ('1', 27379175),
#  'GPR3': ('1', 27392621),
#  'WASF2': ('1', 27404229),
#  'AHDC1': ('1', 27534244),
#  'FGR': ('1', 27612063),
#  'IFI6': ('1', 27666063),
#  'FAM76A': ('1', 27725960),
#  'STX12': ('1', 27773218),
#  'PPP1R8': ('1', 27830781),
#  'SCARNA1': ('1', 27834400),
#  'THEMIS2': ('1', 27872542),
#  'RPA2': ('1', 27891525),
#  'SMPDL3B': ('1', 27934954),
#  'XKR8': ('1', 27959972),
#  'EYA3': ('1', 27970343),
#  'PTAFR': ('1', 28147165),
#  'DNAJC8': ('1', 28200278),
#  'ATP5IF1': ('1', 28236090),
#  'SESN2': ('1', 28259517),
#  'MED18': ('1', 28329039),
#  'PHACTR4': ('1', 28369739),
#  'SNHG3': ('1', 28505942),
#  'RCC1': ('1', 28505942),
#  'SNORA73A': ('1', 28507364),
#  'SNORA73B': ('1', 28508557),
#  'TRNAU1AP': ('1', 28553016),
#  'SNHG12': ('1', 28578537),
#  'SNORD99': ('1', 28578742),
#  'SNORA61': ('1', 28579763),
#  'SNORA44': ('1', 28580380),
#  'SNORA16A': ('1', 28580919),
#  'RAB42': ('1', 28592264),
#  'TAF12': ('1', 28602849),
#  'RNU11': ('1', 28648599),
#  'GMEB1': ('1', 28668783),
#  'YTHDF2': ('1', 28736620),
#  'OPRD1': ('1', 28812169),
#  'EPB41': ('1', 28887090),
#  'TMEM200B': ('1', 29119424),
#  'SRSF4': ('1', 29147744),
#  'MECR': ('1', 29192656),
#  'PTPRU': ('1', 29236521),
#  'MATN1': ('1', 30711276),
#  'MATN1-AS1': ('1', 30718771),
#  'LAPTM5': ('1', 30732468),
#  'SDC3': ('1', 30869465),
#  'PUM1': ('1', 30931505),
#  'SNORD103A': ('1', 30935688),
#  'SNORD103B': ('1', 30935688),
#  'SNORD103C': ('1', 30968162),
#  'NKAIN1': ('1', 31179744),
#  'SNRNP40': ('1', 31259567),
#  'ZCCHC17': ('1', 31296981),
#  'FABP3': ('1', 31365252),
#  'SERINC2': ('1', 31409776),
#  'LDC1P': ('1', 31500084),
#  'TINAGL1': ('1', 31576484),
#  'HCRTR1': ('1', 31617699),
#  'PEF1': ('1', 31629861),
#  'COL16A1': ('1', 31652263),
#  'ADGRB2': ('1', 31727104),
#  'SPOCD1': ('1', 31790421),
#  'PTP4A2': ('1', 31906420),
#  'KHDRBS1': ('1', 32013867),
#  'TMEM39B': ('1', 32072030),
#  'KPNA6': ('1', 32108055),
#  'TXLNA': ('1', 32179674),
#  'CCDC28B': ('1', 32200385),
#  'IQCC': ('1', 32205670),
#  'DCDC2B': ('1', 32209093),
#  'TMEM234': ('1', 32214476),
#  'EIF3I': ('1', 32221583),
#  'MTMR9LP': ('1', 32231659),
#  'FAM167B': ('1', 32247221),
#  'LCK': ('1', 32251264),
#  'HDAC1': ('1', 32292082),
#  'MARCKSL1': ('1', 32333838),
#  'FAM229A': ('1', 32361269),
#  'TSSK3': ('1', 32362538),
#  'BSDC1': ('1', 32364632),
#  'ZBTB8B': ('1', 32465071),
#  'ZBTB8A': ('1', 32539426),
#  'ZBTB8OS': ('1', 32620822),
#  'RBBP4': ('1', 32651207),
#  'SYNC': ('1', 32679905),
#  'KIAA1522': ('1', 32741829),
#  'YARS1': ('1', 32775238),
#  'S100PBP': ('1', 32817441),
#  'FNDC5': ('1', 32862267),
#  'HPCA': ('1', 32886490),
#  'TMEM54': ('1', 32894594),
#  'RNF19B': ('1', 32936448),
#  'AK2': ('1', 33007939),
#  'AZIN2': ('1', 33081152),
#  'TRIM62': ('1', 33145398),
#  'ZNF362': ('1', 33256491),
#  'A3GALT2': ('1', 33306765),
#  'PHC2': ('1', 33323622),
#  'PHC2-AS1': ('1', 33350351),
#  'ZSCAN20': ('1', 33472644),
#  'CSMD2': ('1', 33513998),
#  'HMGB4': ('1', 33860474),
#  'CSMD2-AS1': ('1', 33868955),
#  'C1orf94': ('1', 34166992),
#  'GJB5': ('1', 34755046),
#  'GJB4': ('1', 34759739),
#  'GJB3': ('1', 34781213),
#  'GJA4': ('1', 34792998),
#  'SMIM12': ('1', 34850361),
#  'DLGAP3': ('1', 34865435),
#  'TMEM35B': ('1', 34981525),
#  'ZMYM6': ('1', 34986165),
#  'ZMYM1': ('1', 35059785),
#  'SFPQ': ('1', 35176377),
#  'ZMYM4': ('1', 35268708),
#  'ZMYM4-AS1': ('1', 35358823),
#  'KIAA0319L': ('1', 35433491),
#  'NCDN': ('1', 35557791),
#  'TFAP2E': ('1', 35573313),
#  'PSMB2': ('1', 35599540),
#  'C1orf216': ('1', 35713875),
#  'CLSPN': ('1', 35720212),
#  'AGO4': ('1', 35807635),
#  'AGO1': ('1', 35869807),
#  'AGO3': ('1', 35931104),
#  'TEKT2': ('1', 36084093),
#  'ADPRHL2': ('1', 36088891),
#  'COL8A2': ('1', 36095238),
#  'TRAPPC3': ('1', 36136568),
#  'MAP7D1': ('1', 36156159),
#  'THRAP3': ('1', 36224442),
#  'SH3D21': ('1', 36306367),
#  'EVA1B': ('1', 36322029),
#  'STK40': ('1', 36339627),
#  'LSM10': ('1', 36393435),
#  'OSCP1': ('1', 36417905),
#  'SNORA63C': ('1', 36418447),
#  'MRPS15': ('1', 36455717),
#  'CSF3R': ('1', 36466042),
#  'GRIK3': ('1', 36795526),
#  'ZC3H12A': ('1', 37474579),
#  'MEAF6': ('1', 37489960),
#  'SNIP1': ('1', 37534448),
#  'DNALI1': ('1', 37556939),
#  'GNL2': ('1', 37566811),
#  'RSPO1': ('1', 37611349),
#  'C1orf109': ('1', 37681569),
#  'CDCA8': ('1', 37692515),
#  'EPHA10': ('1', 37715975),
#  'MANEAL': ('1', 37794101),
#  'YRDC': ('1', 37802944),
#  'C1orf122': ('1', 37807789),
#  'MTF1': ('1', 37809574),
#  'INPP5B': ('1', 37860696),
#  'SF3A3': ('1', 37956979),
#  'FHL3': ('1', 37996769),
#  'UTP11': ('1', 38012733),
#  'POU3F1': ('1', 38043828),
#  'RRAGC': ('1', 38838199),
#  'MYCBP': ('1', 38862489),
#  'GJA9-MYCBP': ('1', 38862489),
#  'GJA9': ('1', 38874068),
#  'RHBDL2': ('1', 38885806),
#  'AKIRIN1': ('1', 38991243),
#  'NDUFS5': ('1', 39026294),
#  'MACF1': ('1', 39084166),
#  'KIAA0754': ('1', 39409072),
#  'BMP8A': ('1', 39491635),
#  'OXCT2P1': ('1', 39514865),
#  'PPIEL': ('1', 39522279),
#  'PABPC4': ('1', 39560815),
#  'PABPC4-AS1': ('1', 39565069),
#  'SNORA55': ('1', 39567373),
#  'HEYL': ('1', 39623434),
#  'NT5C1A': ('1', 39659120),
#  'HPCAL4': ('1', 39678647),
#  'PPIE': ('1', 39738844),
#  'BMP8B': ('1', 39757181),
#  'OXCT2': ('1', 39769522),
#  'TRIT1': ('1', 39838109),
#  'MYCL': ('1', 39895427),
#  'MFSD2A': ('1', 39955111),
#  'CAP1': ('1', 40040064),
#  'PPT1': ('1', 40071460),
#  'RLF': ('1', 40161386),
#  'TMCO2': ('1', 40247936),
#  'ZMPSTE24': ('1', 40258235),
#  'COL9A2': ('1', 40300488),
#  'SMAP2': ('1', 40373726),
#  'ZFP69B': ('1', 40450063),
#  'ZFP69': ('1', 40477289),
#  'EXO5': ('1', 40508718),
#  'ZNF684': ('1', 40531636),
#  'RIMS3': ('1', 40620679),
#  'NFYC-AS1': ('1', 40689079),
#  'NFYC': ('1', 40691703),
#  'KCNQ4': ('1', 40783786),
#  'CITED4': ('1', 40861053),
#  'CTPS1': ('1', 40979695),
#  'SLFNL1-AS1': ('1', 41014589),
#  'SLFNL1': ('1', 41015596),
#  'SCMH1': ('1', 41027198),
#  'FOXO6': ('1', 41361433),
#  'FOXO6-AS1': ('1', 41375003),
#  'EDN2': ('1', 41478774),
#  'HIVEP3': ('1', 41506364),
#  'GUCA2B': ('1', 42153409),
#  'GUCA2A': ('1', 42162689),
#  'FOXJ3': ('1', 42176538),
#  'RIMKLA': ('1', 42380791),
#  'ZMYND12': ('1', 42430329),
#  'CCDC30': ('1', 42456106),
#  'PPCS': ('1', 42456340),
#  'PPIH': ('1', 42658422),
#  'YBX1': ('1', 42682417),
#  'CLDN19': ('1', 42733092),
#  'P3H1': ('1', 42746334),
#  'C1orf50': ('1', 42767248),
#  'TMEM269-DT': ('1', 42776665),
#  'TMEM269': ('1', 42785031),
#  'SVBP': ('1', 42807051),
#  'ERMAP': ('1', 42817121),
#  'ZNF691': ('1', 42846572),
#  'SLC2A1': ('1', 42925374),
#  'SLC2A1-AS1': ('1', 42959048),
#  'FAM183A': ('1', 43147903),
#  'EBNA1BP2': ('1', 43164173),
#  'CFAP57': ('1', 43172329),
#  'TMEM125': ('1', 43269982),
#  'C1orf210': ('1', 43281879),
#  'TIE1': ('1', 43300981),
#  'MPL': ('1', 43337817),
#  'CDC20': ('1', 43358980),
#  'ELOVL1': ('1', 43363396),
#  'MED8': ('1', 43383916),
#  'SZT2': ('1', 43389898),
#  'SZT2-AS1': ('1', 43447775),
#  'HYI': ('1', 43450989),
#  'PTPRF': ('1', 43526036),
#  'KDM4A': ('1', 43650148),
#  'KDM4A-AS1': ('1', 43699737),
#  'ST3GAL3': ('1', 43707496),
#  'ARTN': ('1', 43933319),
#  'IPO13': ('1', 43946949),
#  'DPH2': ('1', 43970009),
#  'ATP6V0B': ('1', 43974959),
#  'B4GALT2': ('1', 43979201),
#  'CCDC24': ('1', 43991595),
#  'SLC6A9': ('1', 43996482),
#  'KLF17': ('1', 44118820),
#  'KLF18': ('1', 44137820),
#  'DMAP1': ('1', 44213470),
#  'ERI3': ('1', 44221069),
#  'ERI3-IT1': ('1', 44222594),
#  'SNORA110': ('1', 44252343),
#  'RNF220': ('1', 44405159),
#  'TMEM53': ('1', 44653246),
#  'SNORD145': ('1', 44670956),
#  'ARMH1': ('1', 44674713),
#  'RNU5F-1': ('1', 44721785),
#  'RNU5D-1': ('1', 44731068),
#  'KIF2C': ('1', 44739836),
#  'SNORD160': ('1', 44762034),
#  'RPS8': ('1', 44775539),
#  'SNORD55': ('1', 44775864),
#  'SNORD46': ('1', 44776491),
#  'SNORD38A': ('1', 44777841),
#  'SNORD38B': ('1', 44778389),
#  'BEST4': ('1', 44783584),
#  'PLK3': ('1', 44800376),
#  'TCTEX1D4': ('1', 44805909),
#  'BTBD19': ('1', 44808481),
#  'PTCH2': ('1', 44819843),
#  'EIF2B3': ('1', 44850521),
#  'HECTD3': ('1', 45002547),
#  'UROD': ('1', 45012253),
#  'ZSWIM5': ('1', 45016398),
#  'HPDL': ('1', 45326894),
#  'MUTYH': ('1', 45329241),
#  'TOE1': ('1', 45340169),
#  'TESK2': ('1', 45343882),
#  'CCDC163': ('1', 45493865),
#  'MMACHC': ('1', 45500299),
#  'PRDX1': ('1', 45511034),
#  'AKR1A1': ('1', 45550782),
#  'NASP': ('1', 45583987),
#  'CCDC17': ('1', 45620043),
#  'GPBP1L1': ('1', 45627303),
#  'RPS15AP10': ('1', 45645780),
#  'TMEM69': ('1', 45688180),
#  'IPP': ('1', 45694325),
#  'MAST2': ('1', 45803606),
#  'PIK3R3': ('1', 46040139),
#  'TSPAN1': ('1', 46175086),
#  'P3R3URF': ('1', 46175485),
#  'POMGNT1': ('1', 46188680),
#  'LURAP1': ('1', 46203333),
#  'RAD54L': ('1', 46247687),
#  'LRRC41': ('1', 46278399),
#  'UQCRH': ('1', 46303697),
#  'NSUN4': ('1', 46340176),
#  'FAAH': ('1', 46394316),
#  'FAAHP1': ('1', 46433826),
#  'DMBX1': ('1', 46489835),
#  'TMEM275': ('1', 46532165),
#  'MKNK1-AS1': ('1', 46538695),
#  'KNCN': ('1', 46545637),
#  'MKNK1': ('1', 46557406),
#  'MOB3C': ('1', 46607714),
#  'ATPAF1': ('1', 46635038),
#  'TEX38': ('1', 46671853),
#  'EFCAB14-AS1': ('1', 46674035),
#  'EFCAB14': ('1', 46675158),
#  'CYP4B1': ('1', 46799045),
#  'CYP4Z2P': ('1', 46843094),
#  'CYP4A11': ('1', 46929187),
#  'CYP4X1': ('1', 46961363),
#  'CYP4Z1': ('1', 47067230),
#  'CYP4A22': ('1', 47137424),
#  'PDZK1IP1': ('1', 47183581),
#  'TAL1': ('1', 47216289),
#  'STIL': ('1', 47250138),
#  'CMPK1': ('1', 47333789),
#  'FOXE3': ('1', 47416284),
#  'FOXD2-AS1': ('1', 47432134),
#  'FOXD2': ('1', 47438043),
#  'TRABD2B': ('1', 47760527),
#  'SKINT1L': ('1', 48101714),
#  'SLC5A9': ('1', 48222715),
#  'SPATA6': ('1', 48295371),
#  'AGBL4': ('1', 48532853),
#  'BEND5': ('1', 48727518),
#  'AGBL4-AS1': ('1', 49257410),
#  'AGBL4-IT1': ('1', 49374200),
#  'ELAVL4': ('1', 50048054),
#  'DMRTA2': ('1', 50417549),
#  'FAF1': ('1', 50437027),
#  'CDKN2C': ('1', 50968694),
#  'C1orf185': ('1', 51102227),
#  'RNF11': ('1', 51236272),
#  'TTC39A': ('1', 51287257),
#  'TTC39A-AS1': ('1', 51329653),
#  'EPS15': ('1', 51354262),
#  'CALR4P': ('1', 51561865),
#  'OSBPL9': ('1', 51617091),
#  'NRDC': ('1', 51789193),
#  'RAB3B': ('1', 51907955),
#  'TXNDC12': ('1', 52020131),
#  'KTI12': ('1', 52032102),
#  'TXNDC12-AS1': ('1', 52050917),
#  'BTF3L4': ('1', 52056184),
#  'ZFYVE9': ('1', 52142088),
#  'CC2D1B': ('1', 52350592),
#  'ORC1': ('1', 52372828),
#  'PRPF38A': ('1', 52404601),
#  'TUT4': ('1', 52423275),
#  'GPX7': ('1', 52602370),
#  'SHISAL2A': ('1', 52633167),
#  'COA7': ('1', 52684448),
#  'ZYG11B': ('1', 52726452),
#  'ZYG11A': ('1', 52842759),
#  'ECHDC2': ('1', 52895909),
#  'SCP2': ('1', 52927228),
#  'PODN': ('1', 53062212),
#  'SLC1A7': ('1', 53087182),
#  'CPT2': ('1', 53196823),
#  'CZIB': ('1', 53214099),
#  'MAGOH': ('1', 53226899),
#  'LRP8': ('1', 53242369),
#  'SLC25A3P1': ('1', 53438369),
#  'DMRTB1': ('1', 53459398),
#  'GLIS1': ('1', 53506232),
#  'NDC1': ('1', 53765480),
#  'YIPF1': ('1', 53851732),
#  'DIO1': ('1', 53894186),
#  'HSPB11': ('1', 53921560),
#  'LRRC42': ('1', 53946349),
#  'LDLRAD1': ('1', 54007297),
#  'TMEM59': ('1', 54026680),
#  'TCEANC2': ('1', 54053607),
#  'CDCP2': ('1', 54132719),
#  'CYB5RL': ('1', 54169657),
#  'MRPL37': ('1', 54200166),
#  'SSBP3': ('1', 54225431),
#  'SSBP3-AS1': ('1', 54236442),
#  'ACOT11': ('1', 54548227),
#  'FAM151A': ('1', 54609180),
#  'MROH7': ('1', 54641739),
#  'MROH7-TTC4': ('1', 54641739),
#  'TTC4': ('1', 54715821),
#  'PARS2': ('1', 54756897),
#  'TTC22': ('1', 54779712),
#  'LEXM': ('1', 54806062),
#  'DHCR24': ('1', 54849626),
#  'TMEM61': ('1', 54980627),
#  'BSND': ('1', 54998932),
#  'PCSK9': ('1', 55039547),
#  'USP24': ('1', 55066358),
#  'PLPP3': ('1', 56494760),
#  'PRKAA2': ('1', 56645313),
#  'FYB2': ('1', 56718790),
#  'C8A': ('1', 56854796),
#  'C8B': ('1', 56929206),
#  'DAB1': ('1', 56994777),
#  'DAB1-AS1': ('1', 57860580),
#  'OMA1': ('1', 58480718),
#  'TACSTD2': ('1', 58575432),
#  'MYSM1': ('1', 58654743),
#  'JUN': ('1', 58780790),
#  'HSD52': ('1', 59131935),
#  'FGGY': ('1', 59296812),
#  'HOOK1': ('1', 59814948),
#  'CYP2J2': ('1', 59893307),
#  'C1orf87': ('1', 59990393),
#  'NFIA-AS2': ('1', 60940243),
#  'NFIA': ('1', 61077226),
#  'NFIA-AS1': ('1', 61248944),
#  'MGC34796': ('1', 61654241),
#  'TM2D1': ('1', 61681045),
#  'PATJ': ('1', 61742479),
#  'L1TD1': ('1', 62194848),
#  'KANK4': ('1', 62236164),
#  'USP1': ('1', 62436303),
#  'DOCK7': ('1', 62454725),
#  'ANGPTL3': ('1', 62597519),
#  'ATG4C': ('1', 62784105),
#  'FOXD3-AS1': ('1', 63320883),
#  'FOXD3': ('1', 63322566),
#  'ALG6': ('1', 63367626),
#  'ITGB3BP': ('1', 63440769),
#  'EFCAB7': ('1', 63523524),
#  'DLEU2L': ('1', 63548979),
#  'PGM1': ('1', 63593410),
#  'ROR1': ('1', 63774016),
#  'ROR1-AS1': ('1', 64094441),
#  'UBE2U': ('1', 64203622),
#  'CACHD1': ('1', 64470128),
#  'RAVER2': ('1', 64744972),
#  'JAK1': ('1', 64833222),
#  'AK4': ('1', 65147548),
#  'DNAJC6': ('1', 65264693),
#  'LEPR': ('1', 65420651),
#  'LEPROT': ('1', 65420667),
#  'PDE4B': ('1', 65792509),
#  'PDE4B-AS1': ('1', 66042499),
#  'SGIP1': ('1', 66533592),
#  'TCTEX1D1': ('1', 66752458),
#  'INSL5': ('1', 66797740),
#  'WDR78': ('1', 66812885),
#  'MIER1': ('1', 66924894),
#  'SLC35D1': ('1', 66999349),
#  'C1orf141': ('1', 67092165),
#  'IL23R': ('1', 67166453),
#  'IL12RB2': ('1', 67307363),
#  'SERBP1': ('1', 67407809),
#  'GADD45A': ('1', 67685200),
#  'GNG12': ('1', 67701474),
#  'GNG12-AS1': ('1', 67832287),
#  'DIRAS3': ('1', 68045885),
#  'WLS': ('1', 68098458),
#  'RPE65': ('1', 68428821),
#  'DEPDC1': ('1', 68474151),
#  'DEPDC1-AS1': ('1', 68496675),
#  'LRRC7': ('1', 69567333),
#  'PIN1P1': ('1', 69919321),
#  'LRRC40': ('1', 70144804),
#  'SRSF11': ('1', 70205695),
#  'ANKRD13C': ('1', 70258998),
#  'HHLA3': ('1', 70354810),
#  'CTH': ('1', 70411217),
#  'PTGER3': ('1', 70852357),
#  'ZRANB2-AS1': ('1', 71046505),
#  'ZRANB2': ('1', 71063290),
#  'ZRANB2-AS2': ('1', 71081323),
#  'NEGR1': ('1', 71395942),
#  'NEGR1-IT1': ('1', 71794231),
#  'LRRIQ3': ('1', 74026017),
#  'FPGT': ('1', 74198211),
#  'FPGT-TNNI3K': ('1', 74198211),
#  'TNNI3K': ('1', 74235386),
#  'LRRC53': ('1', 74468979),
#  'ERICH3': ('1', 74568122),
#  'ERICH3-AS1': ('1', 74577429),
#  'CRYZ': ('1', 74705487),
#  'TYW3': ('1', 74733151),
#  'LHX8': ('1', 75128433),
#  'SLC44A5': ('1', 75202128),
#  'ACADM': ('1', 75724346),
#  'DLSTP1': ('1', 75742001),
#  'RABGGTB': ('1', 75786193),
#  'SNORD45C': ('1', 75787071),
#  'SNORD45A': ('1', 75787888),
#  'SNORD45B': ('1', 75789476),
#  'MSH4': ('1', 75796881),
#  'ASB17': ('1', 75918872),
#  'ST6GALNAC3': ('1', 76074745),
#  'ST6GALNAC5': ('1', 76867479),
#  'PIGK': ('1', 77088989),
#  'AK5': ('1', 77282018),
#  'ZZZ3': ('1', 77562415),
#  'USP33': ('1', 77695988),
#  'MIGA1': ('1', 77779623),
#  'NEXN-AS1': ('1', 77881347),
#  'NEXN': ('1', 77888514),
#  'FUBP1': ('1', 77944054),
#  'DNAJB4': ('1', 77979157),
#  'GIPC2': ('1', 78044969),
#  'MGC27382': ('1', 78229598),
#  'PTGFR': ('1', 78490973),
#  'IFI44L': ('1', 78620447),
#  'IFI44': ('1', 78649788),
#  'ADGRL4': ('1', 78889763),
#  'ADGRL2': ('1', 81306191),
#  'TTLL7': ('1', 83865023),
#  'PRKACB': ('1', 84077974),
#  'SAMD13': ('1', 84298537),
#  'UOX': ('1', 84364957),
#  'DNASE2B': ('1', 84398531),
#  'RPF1': ('1', 84479265),
#  'GNG5': ('1', 84498324),
#  'SPATA1': ('1', 84506385),
#  'CTBS': ('1', 84549610),
#  'SSX2IP': ('1', 84643705),
#  'LPAR3': ('1', 84811601),
#  'MCOLN2': ('1', 84925582),
#  'MCOLN3': ('1', 85018081),
#  'WDR63': ('1', 85062297),
#  'SYDE2': ('1', 85156891),
#  'C1orf52': ('1', 85249953),
#  'BCL10': ('1', 85265775),
#  'DDAH1': ('1', 85318484),
#  'CCN1': ('1', 85580760),
#  'ZNHIT6': ('1', 85649416),
#  'COL24A1': ('1', 85729232),
#  'ODF2L': ('1', 86346823),
#  'CLCA2': ('1', 86424170),
#  'CLCA1': ('1', 86468926),
#  'CLCA4': ('1', 86547077),
#  'CLCA4-AS1': ('1', 86571180),
#  'CLCA3P': ('1', 86634275),
#  'SH3GLB1': ('1', 86704569),
#  'SELENOF': ('1', 86862444),
#  'HS2ST1': ('1', 86914634),
#  'LMO4': ('1', 87328879),
#  'PKN2-AS1': ('1', 88537512),
#  'PKN2': ('1', 88684143),
#  'GTF2B': ('1', 88852632),
#  'KYAT3': ('1', 88921043),
#  'RBMXL1': ('1', 88979455),
#  'GBP3': ('1', 89006676),
#  'GBP1': ('1', 89052320),
#  'GBP2': ('1', 89106132),
#  'GBP7': ('1', 89131744),
#  'GBP4': ('1', 89181144),
#  'GBP5': ('1', 89258950),
#  'GBP6': ('1', 89363876),
#  ...}

# %%
# only consider co-amplified genes in hg38 refseq gene list (with loc data)

nodes = pd.read_csv("/Users/michael/Downloads/neo4j-community-5.12.0/import/test_nodes.csv")

gene_labels = nodes['label'].tolist()

not_in_refseq = [g for g in gene_labels if g not in locs.keys()]

not_in_refseq
# Out:
# ['THRA1',
#  'BTR',
#  'CTD-2194D22',
#  '4',
#  'CTD-3080P12',
#  '3',
#  'CH17-340M24',
#  'HGC6',
#  'CTD-2350J17',
#  '1']

# %%
edges['valid_genes'] = edges.apply(lambda row: not(row['source'] in not_in_refseq or row['target'] in not_in_refseq), axis=1)

# %%
edges_valid = edges[edges['valid_genes'] == True]

# %%
# calculate p_values from theoretical distribution

# %%
models = {
    'expon': [2, # loc
              319813.96455938695 # scale
             ],
    'gamma': [0.569504897386201, # a
              1.9999999999999996, # loc
              304238.4694626314 # scale
             ],
    'fatigue_life': [4.087390011411001, # c
                     -287.3206721470797, # loc
                     26297.62638444689, # scale
                    ]
}

# %%
def distance(a, b):
    
    if locs[a][0] != locs[b][0]:
        return 'N/A'# f"{locs[a][0]}, {locs[b][0]}"
    return abs(locs[a][1] - locs[b][1])

def p_val(a, b, model='expon'):
    params = models[model]
    if model == 'expon':
        d = distance(a, b)
        if not type(d) is str:
            cdf = expon.cdf(d, loc=params[0], scale=params[1])
            return 1-cdf
    return 'N/A'

# %%
p_val('ARNTL2','ARNTL2')
# Out:
# 1.0

# %%
edges_valid['p_val'] = edges_valid.apply(lambda row: p_val(row['source'], row['target']), axis=1)
edges_valid['distance'] = edges_valid.apply(lambda row: distance(row['source'], row['target']), axis=1)
# Out:
# /var/folders/vq/53fmy78n3bj45d2gghcc_fvh0000gp/T/ipykernel_37093/2248486453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edges_valid['p_val'] = edges_valid.apply(lambda row: p_val(row['source'], row['target']), axis=1)
# /var/folders/vq/53fmy78n3bj45d2gghcc_fvh0000gp/T/ipykernel_37093/2248486453.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edges_valid['distance'] = edges_valid.apply(lambda row: distance(row['source'], row['target']), axis=1)

# %%
# plot p_val dist

# %%
p_values = edges_valid[edges_valid['p_val'] != 'N/A']['p_val'].tolist()

# %%
plt.figure(figsize=(8, 6))
plt.hist(p_values, bins=50, alpha=0.7)
plt.title("p_values")
plt.xlabel("p_values")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# plot gene coamplification distances dist

# %%
distances = edges_valid[edges_valid['distance'] != 'N/A']['distance'].tolist()

# %%
plt.figure(figsize=(8, 6))
plt.hist(distances, bins=50, alpha=0.7)
plt.title("distances")
plt.xlabel("distances")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Create the scatter plot
plt.scatter(distances, p_values, color='blue', s=5)

# Add labels, title, and legend
plt.xlabel('distances')
plt.ylabel('p_values')
plt.title('Co-amplification significance by distance (nt)')
plt.legend()

# Show the plot
plt.show()
# Out:
# /var/folders/vq/53fmy78n3bj45d2gghcc_fvh0000gp/T/ipykernel_37093/4083883184.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
