# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import fdrcorrection
from ast import literal_eval
import itertools
import requests
from Bio import Entrez
import time
from tqdm import tqdm

# %% [markdown]
# #### Load Genes From Aggregated Results Files

# %%
aa_agg_results = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/aggregated_results_ccle_tcga_pcawg.csv"
aa = pd.read_csv(aa_agg_results)
aa["All genes"] = aa.apply(lambda x : x["All genes"].replace("\"", ""), axis = 1)
aa['All genes'] = aa['All genes'].apply(literal_eval) # convert to list

# %%
all_genes = []
for i, row in aa.iterrows():
    all_genes += row["All genes"]
all_genes = [gene for gene in all_genes if gene != '']
all_genes = list(set(all_genes))

# %%
len(all_genes)
# Out:
# 16091

# %%
aa_full_gene_list_hg38 = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/refGene_hg38.txt"
aa_full_gene_list_hg19 = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/refGene_hg19.txt"

list1 = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/GRCh38/refGene.txt"
list2 = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/GRCh37/human_hg19_september_2011/Genes_July_2010_hg19.gff"
list3 = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/hg19/human_hg19_september_2011/Genes_July_2010_hg19.gff"

aa_full_gene_list_hg38 = pd.read_csv(aa_full_gene_list_hg38, sep = "\t", header = None)
aa_full_gene_list_hg19 = pd.read_csv(aa_full_gene_list_hg19, sep = "\t", header = None)

list1 = pd.read_csv(list1, sep = "\t", header = None)
list2 = pd.read_csv(list2, sep = "\t", header = None)
list3 = pd.read_csv(list3, sep = "\t", header = None)

list2[9] = list2.apply(lambda x : x[8].strip().split(";")[2].split("=")[1], axis = 1)
list3[9] = list3.apply(lambda x : x[8].strip().split(";")[2].split("=")[1], axis = 1)

# %%
aa_full_gene_list_hg38 = set(list(aa_full_gene_list_hg38[12]))
aa_full_gene_list_hg19 = set(list(aa_full_gene_list_hg19[12]))

list1 = set(list(list1[12]))
list2 = set(list(list2[9]))
list3 = set(list(list3[9]))

print("hg38:", len(aa_full_gene_list_hg38))
print("hg19:", len(aa_full_gene_list_hg19))
print("hg38_2:", len(list1))
print("hg19_2:", len(list2))
print("hg19_3:", len(list3))

aa_full_gene_list_full = set(list(aa_full_gene_list_hg38) + list(aa_full_gene_list_hg19) + list(list1) + list(list2) + list(list3))
print("Combined Gene List:", len(aa_full_gene_list_full))
# Out:
# hg38: 28286
# hg19: 27325
# hg38_2: 28278
# hg19_2: 21824
# hg19_3: 21841
# Combined Gene List: 32247

# %% [markdown]
# #### Find Aliases Using HGNC

# %%
def fetch_previous_hgnc_symbols(gene_name):
    url = f"https://rest.genenames.org/fetch/symbol/{gene_name}"
    headers = {"Accept": "application/json"}
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        if "response" in data and data["response"]["numFound"] > 0:
            doc = data["response"]["docs"][0]
            aliases = doc.get('alias_symbol', [])
            prev = doc.get('prev_symbol', [])
            return aliases + prev
    else:
        print(f"Failed to retrieve data for {gene_name}, Status code: {response.status_code}")
    return []

# %%
gene_alias_mapping = {}

for gene in tqdm(aa_full_gene_list_full, desc="Processing genes"):
    aliases = fetch_previous_hgnc_symbols(gene)
    if aliases == ['']:
        aliases = []
    gene_alias_mapping[gene] = aliases
# Out:
# Processing genes: 100%|█████████████████████████████████████████████████████████| 32247/32247 [3:10:25<00:00,  2.82it/s]

# %% [markdown]
# #### Final Alias Mapper

# %%
gene_alias_mapping
# Out:
# {'SLC2A12': ['GLUT12', 'GLUT8'],
#  'CEACAM20': ['UNQ9366'],
#  'C7orf27': [],
#  'PCBP4': ['MCG10', 'LIP4'],
#  'MMP9': ['CLG4B'],
#  'MIR9-3': ['hsa-mir-9-3', 'MIRN9-3'],
#  'DLC1': ['HP', 'ARHGAP7', 'STARD12', 'DLC-1', 'p122-RhoGAP'],
#  'RBM12': ['HRIHFB2091', 'KIAA0765', 'SWAN'],
#  'CD300H': [],
#  'SNORA36B': ['ACA36b'],
#  'DIAPH1-AS1': [],
#  'CEP89': ['FLJ14640', 'CCDC123'],
#  'FURIN': ['SPC1', 'PCSK3', 'FUR', 'PACE'],
#  'GJB5': ['CX31.1'],
#  'CRB3': ['MGC17303'],
#  'MRM1': ['FLJ22578'],
#  'SLC38A8': ['SNAT8'],
#  'C1QTNF1-AS1': [],
#  'VAC14-AS1': [],
#  'PHF20L1': ['CGI-72', 'FLJ13649', 'MGC64923', 'FLJ21615', 'TDRD20B'],
#  'SFTPB': ['SP-B', 'SFTP3'],
#  'NUDT18': ['FLJ22494', 'MTH3'],
#  'SOGA1': [],
#  'SNORA41B': [],
#  'LINC01511': ['RP11-325I22.2'],
#  'LOC442421': [],
#  'CPSF2': ['KIAA1367', 'CPSF100'],
#  'SKIDA1': ['FLJ45187', 'C10orf140'],
#  'FAM213B': [],
#  'SPRR2A': [],
#  'PLEKHA9': [],
#  'PCDHA4': ['CNR1', 'CRNR1', 'PCDH-ALPHA4', 'CNRN1'],
#  'C6orf146': [],
#  'PSMB8-AS1': ['XXbac-BPG246D15.8', 'TAP1-AS1', 'TAPSAR1'],
#  'HSPB1': ['HSP27', 'HSP28', 'Hs.76067', 'Hsp25', 'CMT2F'],
#  'MIR577': ['hsa-mir-577', 'MIRN577'],
#  'CLDN34': [],
#  'MAFG': ['MGC13090', 'MGC20149'],
#  'STK11IP': ['LIP1', 'KIAA1898', 'LKB1IP', 'STK11IP1'],
#  'CHRM5': [],
#  'PTTG1IP': ['PBF', 'PTTG1IP1', 'C21orf3', 'C21orf1'],
#  'HIST2H2BE': [],
#  'LOC101928820': [],
#  'PLEKHM1P': [],
#  'LOC105372038': [],
#  'TNFRSF18': ['AITR', 'GITR', 'CD357'],
#  'JKAMP': ['HSPC213', 'JAMP', 'HSPC327', 'CDA06', 'C14orf100'],
#  'GIMAP1-GIMAP5': [],
#  'ARHGAP28': ['KIAA1314', 'FLJ10312'],
#  'MIR193A': ['hsa-mir-193', 'hsa-mir-193a', 'MIRN193', 'MIRN193A'],
#  'LOC440084': [],
#  'C11orf91': [],
#  'GNAI3': ['87U6'],
#  'FBXW7': ['AGO',
#   'FLJ11071',
#   'SEL-10',
#   'SEL10',
#   'FBW7',
#   'FBX30',
#   'CDC4',
#   'FBXW6'],
#  'YWHAE': ['FLJ45465'],
#  'CD84': ['SLAMF5', 'hCD84', 'mCD84'],
#  'TMPRSS11GP': [],
#  'CCNG2': [],
#  'ST8SIA6': ['SIAT8F'],
#  'MIR4432': ['hsa-mir-4432'],
#  'KCTD20': ['dJ108K11.3', 'MGC14254', 'C6orf69'],
#  'DPRXP4': [],
#  'FAM223A': ['SPCX', 'CXorf52', 'NCRNA00204', 'NCRNA00204A', 'LINC00204A'],
#  'C1QC': ['C1QG'],
#  'IL17RC': ['IL17-RL'],
#  'ELF2': ['EU32', 'NERF', 'NERF-2', 'NERF-1A', 'NERF-1B'],
#  'LOC105369443': [],
#  'HEMGN': ['EDAG', 'CT155', 'NDR'],
#  'HRAT5': [],
#  'MRPS14': ['HSMRPS14', 'uS14m'],
#  'VCPIP1': ['VCIP135', 'KIAA1850', 'FLJ23132', 'DUBA3'],
#  'CASR': ['FHH', 'NSHPT', 'GPRC2A', 'HHC', 'HHC1'],
#  'THAP6': ['MGC30052'],
#  'ATP6V1B1': ['VATB', 'RTA1B', 'Vma2', 'VPP3', 'ATP6B1'],
#  'SLC16A1-AS1': ['ENST00000421157.1', 'LINC01357'],
#  'TMEM241': ['MGC11386', 'FLJ44259', 'SLC35D4', 'C18orf45'],
#  'TOMM7': ['Tom7'],
#  'CYP4A11': ['CYP4AII', 'CYP4A2'],
#  'LZTFL1': ['BBS17'],
#  'PIAS1': ['GBP', 'GU/RH-II', 'ZMIZ3', 'DDXBP1'],
#  'LINC01695': [],
#  'LOC100132247': [],
#  'STK32B': ['STKG6', 'YANK2', 'STK32', 'HSA250839'],
#  'MRPS35': ['MRPS28', 'MDS023', 'mS35'],
#  'CFL1P1': ['MGC35136', 'CFLP1'],
#  'CFAP206': ['FLJ25974', 'dJ382I10.1', 'C6orf165'],
#  'OR14A16': ['OR5AT1'],
#  'ATF2': ['TREB7', 'CRE-BP1', 'HB16', 'CREB2'],
#  'LOC158376': [],
#  'HOMER3': ['HOMER-3'],
#  'RABL3': ['MGC23920'],
#  'SYNJ1': ['INPP5G', 'PARK20'],
#  'RNFT1': ['PTD016'],
#  'MIR6799': ['hsa-mir-6799'],
#  'GTPBP2': [],
#  'NRIP3': ['C11orf14'],
#  'FLJ33630': [],
#  'LOC401097': [],
#  'MIR4490': ['hsa-mir-4490'],
#  'RGS8': ['MGC119067', 'MGC119068', 'MGC119069'],
#  'UBE2S': ['E2-EPF'],
#  'LNPEP': ['CAP', 'PLAP', 'P-LAP', 'IRAP'],
#  'AHCY': ['SAHH', 'AdoHcyase'],
#  'MIR32': ['hsa-mir-32', 'MIRN32'],
#  'OBI1-AS1': ['POU4F1-AS1', 'RNF219-AS1'],
#  'SLC17A4': ['KIAA2138'],
#  'SNORA70J': [],
#  'LOC100419583': [],
#  'LOC105370792': [],
#  'CYP4F62P': ['CYP4F-se11[6:7:8]', 'CYP4F43P'],
#  'SEPT7P2': [],
#  'C7orf11': [],
#  'KLHL13': ['FLJ10262', 'BKLHD2', 'KIAA1309'],
#  'BAT2L2': [],
#  'MIR3605': ['hsa-mir-3605'],
#  'LOC101927157': [],
#  'MIR212': ['hsa-mir-212', 'MIRN212'],
#  'LOC729867': [],
#  'LRP10': ['DKFZP564C1940', 'MGC8675', 'LRP9', 'MST087', 'MSTP087'],
#  'NMNAT1': ['NMNAT', 'PNAT1', 'LCA9'],
#  'TNFRSF8': ['KI-1', 'CD30', 'D1S166E'],
#  'LINC02185': [],
#  'HUS1': [],
#  'BPIL2': [],
#  'FAM127B': [],
#  'NBEAL1': ['MGC164581', 'ALS2CR17', 'ALS2CR16'],
#  'LOC643486': [],
#  'ADCK5': ['FLJ35454'],
#  'YME1L1': ['YME1L'],
#  'EIF2B2': ['EIF2B', 'EIF-2Bbeta', 'EIF2Bbeta'],
#  'C18orf54': ['MGC33382', 'LAS2'],
#  'LOC101928021': [],
#  'LINC00908': ['ASRPS', 'LINC00683', 'LINC01879'],
#  'C14orf104': [],
#  'LOC106780825': [],
#  'FLRT3': [],
#  'CABP5': ['CaBP3', 'CABP3'],
#  'NUP62': ['p62',
#   'DKFZp547L134',
#   'IBSN',
#   'SNDI',
#   'MGC841',
#   'FLJ20822',
#   'FLJ43869'],
#  'TTTY14': ['TTY14', 'NCRNA00137', 'PRO2834', 'NCRNA00185', 'CYorf14'],
#  'B9D1': ['B9', 'EPPB9', 'MKS9', 'MKSR-1'],
#  'ALDH16A1': ['MGC10204'],
#  'ZG16': ['hZG16', 'JCLN1', 'ZG16A', 'JCLN'],
#  'PSMA6': ['IOTA', 'PROS27', 'p27K', 'MGC22756', 'MGC2333', 'MGC23846'],
#  'RNA5S3': ['RN5S3'],
#  'DDX6': ['RCK', 'Rck/p54', 'HLR2'],
#  'LNX2': ['MGC46315', 'PDZRN1'],
#  'C9orf80': [],
#  'LOC283352': [],
#  'ONECUT2': ['OC-2'],
#  'LOC283404': [],
#  'psiTPTE22': [],
#  'RAB30-AS1': [],
#  'CALD1': ['CDM', 'H-CAD', 'L-CAD', 'h-CD'],
#  'FAM114A2': ['133K02', 'C5orf3'],
#  'ACTR8': ['INO80N', 'ARP8'],
#  'FAM36A': [],
#  'SS18L1': ['KIAA0693', 'CREST', 'SMARCL2'],
#  'PATL2': ['Pat1a'],
#  'PLEKHH3': ['FLJ21019'],
#  'HTR1E': ['5-HT1E'],
#  'XRN1': ['SEP1'],
#  'TNRC18P1': [],
#  'ZKSCAN2': ['FLJ23199', 'ZSCAN34', 'ZNF694'],
#  'CYP4F35P': ['CYP4F-se8[6:7:8]'],
#  'PIANP': ['DKFZp547D2210', 'PANP', 'C12orf53'],
#  'MGC34796': [],
#  'LOC283856': [],
#  'LOC729970': [],
#  'SNORD29': ['U29', 'RNU29'],
#  'FAM75A5': [],
#  'LOC100132741': [],
#  'TSPAN33': ['MGC50844', 'Penumbra'],
#  'SLC9A9': ['FLJ35613', 'NHE9'],
#  'MIR6868': ['hsa-mir-6868'],
#  'LINC01216': ['EMCN-IT3'],
#  'DPP8': ['DP8', 'DPRP1', 'MSTP141', 'FLJ14920', 'FLJ20283', 'MGC26191'],
#  'PIK3R6': ['FLJ34500', 'HsT41028', 'p87PIKAP', 'C17orf38'],
#  'LOC339568': [],
#  'MIR92B': ['hsa-mir-92b', 'MIRN92B'],
#  'LINC02343': [],
#  'NXNL1': ['RDCVF', 'TXNL6'],
#  'SLC49A3': ['FLJ22269', 'LP2561', 'MFSD7'],
#  'LOC729737': [],
#  'LINC01809': [],
#  'HCG25': ['dJ1033B10.16'],
#  'IAPP': ['AMYLIN', 'DAP', 'IAP'],
#  'KLHL25': ['FLJ12587', 'ENC2', 'ENC-2'],
#  'PROM1': ['AC133', 'CD133', 'RP41', 'CORD12', 'PROML1', 'MCDR2', 'STGD4'],
#  'LINC00842': [],
#  'POLA1': ['p180', 'POLA', 'NSX'],
#  'LCP2': ['SLP-76', 'SLP76'],
#  'EGR1': ['225',
#   'TIS8',
#   'AT225',
#   'G0S30',
#   'NGFI-A',
#   'ZIF268',
#   'KROX-24',
#   'ZIF-268'],
#  'CLEC4D': ['Mpcl', 'CD368', 'MCL', 'Dectin-3', 'CLECSF8'],
#  'OR2F2': ['OR7-1'],
#  'RPS15': ['RIG', 'MGC111130', 'S15', 'uS19'],
#  'DUSP22': ['MKPX', 'JSP1', 'JKAP', 'VHX'],
#  'LOC648740': [],
#  'ABHD14A': ['DKFZP564O243', 'DORZ1'],
#  'OR1E1': ['OR17-2',
#   'HGM071',
#   'OR17-32',
#   'OR13-66',
#   'OR1E9P',
#   'OR1E5',
#   'OR1E6'],
#  'MICA-AS1': [],
#  'LINC02513': [],
#  'MAPK14': ['PRKM14', 'p38', 'Mxi2', 'PRKM15', 'CSPB1', 'CSBP1', 'CSBP2'],
#  'KLHL5': [],
#  'FNDC9': ['MGC27121', 'C5orf40'],
#  'BCAS3': ['FLJ20128', 'PHAF2'],
#  'C10orf99': [],
#  'LOC100506551': [],
#  'IFNA8': ['IFN-alphaB'],
#  'ERICH6': ['MGC39662', 'ERICH6A', 'C3orf44', 'FAM194A'],
#  'ACOT11': ['STARD14', 'BFIT', 'KIAA0707', 'BFIT1', 'THEM1', 'THEA'],
#  'RILP': ['FLJ31193'],
#  'FZD10': ['CD350'],
#  'LINC00595': ['C10orf101'],
#  'PSMB11': ['beta5t'],
#  'SMAD9': ['SMAD8', 'SMAD8/9', 'MADH6', 'MADH9'],
#  'PIP5K1C': ['PIP5Kgamma', 'KIAA0589', 'LCCS3'],
#  'CNOT6': ['CCR4', 'KIAA1194', 'Ccr4a'],
#  'MAGEA4-AS1': [],
#  'ZNF677': ['MGC48625'],
#  'DCAF8L1': ['WDR42B'],
#  'DOCK8-AS1': ['FLJ31158', 'C9orf66'],
#  'CDRT15L1': [],
#  'CALCB': ['FLJ30166', 'CGRP-II', 'CALC2'],
#  'KRTAP13-1': ['KAP13.1'],
#  'LINC01532': [],
#  'DAP': ['DAP1'],
#  'OBI1': ['FLJ13449', 'C13orf7', 'RNF219'],
#  'REN': [],
#  'GABPB2': ['MGC29891'],
#  'FAM9B': ['TEX39B'],
#  'LINC00242': ['FLJ31451', 'dJ266L20.5', 'C6orf122', 'NCRNA00242'],
#  'MBD3L2B': [],
#  'TDRKH-AS1': ['RP11-98D18.9'],
#  'SERPINA6': ['CBG'],
#  'C1orf227': [],
#  'ADRA1B': [],
#  'RNF208': ['DKFZP761H1710'],
#  'HEXIM2': ['FLJ32384'],
#  'MIR4283-2': ['hsa-mir-4283-2'],
#  'TUG1': ['FLJ20618', 'NCRNA00080', 'LINC00080'],
#  'SNX31': ['MGC39715'],
#  'SNORD45C': ['U45C'],
#  'THYN1': ['THY28'],
#  'KRI1': ['FLJ12949'],
#  'DTX4': ['KIAA0937', 'RNF155'],
#  'THRSP': ['SPOT14', 'Lpgp', 'S14', 'THRP', 'LPGP1'],
#  'UGT3A1': ['FLJ34658'],
#  'MMP2-AS1': ['ENST00000569037'],
#  'ADGRD1-AS1': ['LACAT8'],
#  'MIR3688-2': ['hsa-mir-3688-2'],
#  'KRTAP15-1': ['KAP15.1'],
#  'BTF3': ['BTF3a', 'BTF3b', 'NACB'],
#  'LINC00526': ['MGC17515', 'HsT959', 'TP53LC13', 'C18orf18'],
#  'GGTA1': ['GLYT2', 'GGTA', 'GGTA1P'],
#  'MTX3': [],
#  'CST8': ['CRES', 'CTES5'],
#  'TJAP1': ['PILT', 'TJP4'],
#  'LOC606724': [],
#  'SGK3': ['SGK2', 'SGKL'],
#  'VN1R5': ['V1RL5'],
#  'MIR3150A': ['hsa-mir-3150', 'hsa-mir-3150a', 'MIR3150'],
#  'OR8B2': [],
#  'MUC5B-AS1': [],
#  'LOC100507472': [],
#  'C21orf128': [],
#  'PYCARD': ['TMS-1', 'CARD5', 'ASC'],
#  'SPNS1': ['HSpin1', 'nrs', 'SPINL', 'PP2030', 'SPIN1', 'LAT', 'SLC63A1'],
#  'USP33': ['KIAA1097', 'VDU1'],
#  'ZNHIT1': ['CG1I', 'H_DJ0747G18.14', 'p18(Hamlet)', 'ZNFN4A1'],
#  'MIR5697': ['hsa-mir-5697'],
#  'PDCL2': ['GCPHLP'],
#  'FLJ41278': [],
#  'ProSAPiP1': [],
#  'LOC102723713': [],
#  'AIRN': ['AIR', 'NCRNA00088', 'IGF2RAS', 'IGF2R-AS1'],
#  'CIC': ['KIAA0306'],
#  'SLC4A5': ['NBC4'],
#  'CCDC82': ['FLJ23518'],
#  'LINC00458': ['ES3', 'HBL1', 'LncRNA-ES3'],
#  'ENAH': ['FLJ10773', 'NDPP1', 'MENA'],
#  'MCOLN3': ['TRPML3', 'FLJ11006', 'TRP-ML3'],
#  'MIR1302-10': ['hsa-mir-1302-10'],
#  'FCGR1C': [],
#  'ARL8A': ['FLJ45195', 'Gie2', 'ARL10B'],
#  'CCNA2': ['CCNA', 'CCN1'],
#  'LINC01358': [],
#  'LOC339751': [],
#  'LOC101928605': [],
#  'GLTPD2': [],
#  'KCNK15-AS1': ['RP11-445H22.4', 'LINC01260'],
#  'LOC440434': [],
#  'HLA-DQA1': ['CELIAC1', 'HLA-DQA'],
#  'IQCJ': [],
#  'SEPT10': [],
#  'SNORA63C': [],
#  'DACT1': ['DAPPER1', 'THYEX3', 'HDPR1', 'DAPPER', 'FRODO'],
#  'CEACAM22P': [],
#  'BIRC2': ['cIAP1', 'hiap-2', 'MIHB', 'RNF48', 'c-IAP1', 'API1'],
#  'CTSB': [],
#  'CSGALNACT1': ['CSGalNAcT-1', 'FLJ11264', 'ChGn'],
#  'RPUSD3': ['MGC29784'],
#  'EGLN3': ['PHD3', 'HIFPH3'],
#  'LINC00390': ['TCONS_00021641'],
#  'ZBED5-AS1': [],
#  'SPTY2D1': ['FLJ39441', 'DKFZp686I068', 'Spt2'],
#  'C18orf21': ['PNAS-131', 'PNAS-124', 'HsT3108'],
#  'CFAP97D1': ['C17orf105'],
#  'XAGE5': ['XAGE-5', 'CT12.5', 'GAGED5'],
#  'ATXN7L2': ['MGC46534', 'FLJ00381'],
#  'DNAH17-AS1': [],
#  'ZNF709': ['FLJ38281'],
#  'LINC00847': [],
#  'HDAC5': ['KIAA0600', 'NY-CO-9', 'FLJ90614'],
#  'ZC3H12C': ['KIAA1726', 'MCPIP3'],
#  'SCIMP': ['DTFT5783',
#   'UNQ5783',
#   'FLJ32580',
#   'MGC163426',
#   'MGC163428',
#   'C17orf87'],
#  'CASP2': ['ICH1', 'PPP1R57', 'MGC2181', 'NEDD2'],
#  'DGCR11': ['DGS-D'],
#  'SGSM3': ['DJ1042K10.2', 'RUSC3', 'RabGAP-5', 'RABGAP5', 'RUTBC3'],
#  'MUC22': ['PBMUCL1'],
#  'PPAP2A': [],
#  'ZNF496': ['ZKSCAN17', 'MGC15548', 'ZSCAN49'],
#  'NAT6': [],
#  'MTOR': ['RAFT1', 'RAPT1', 'FLJ44809', 'FRAP', 'FRAP2', 'FRAP1'],
#  'SPSB4': ['SSB-4'],
#  'ARL5C': ['ARL12'],
#  'MIR520F': ['hsa-mir-520f', 'MIRN520F'],
#  'C21orf71': [],
#  'ESYT3': ['CHR3SYT', 'FAM62C'],
#  'MRPL55': ['bL31m'],
#  'MIR629': ['hsa-mir-629', 'MIRN629'],
#  'PPP2R4': [],
#  'NEURL1': ['h-neu', 'RNF67', 'neu-1', 'NEURL'],
#  'APLP2': ['APPH', 'APPL2'],
#  'IFIT3': ['ISG60', 'RIG-G', 'CIG-49', 'IFI60', 'GARG-49', 'IRG2', 'IFIT4'],
#  'CDK5R2': ['p39nck5ai', 'P39', 'NCK5AI'],
#  'RLF': ['ZNF292L', 'Zn-15L'],
#  'DOCK1': ['DOCK180', 'ced5'],
#  'IL13RA1': ['IL-13Ra', 'NR4', 'CD213a1'],
#  'LINC01607': [],
#  'BNIP3': ['Nip3', 'HABON'],
#  'TKFC': ['DKFZP586B1621', 'NET45', 'DAK'],
#  'MIR4687': ['hsa-mir-4687'],
#  'SRL': ['SAR'],
#  'ASCL3': ['bHLHa42', 'HASH3', 'Sgn1'],
#  'DHRS4L1': ['SDR25C4'],
#  'GABRA1': ['EJM5'],
#  'ADD3': ['ADDL'],
#  'C19orf54': [],
#  'PTMAP11': [],
#  'MIR4277': ['hsa-mir-4277'],
#  'MIR3184': ['hsa-mir-3184'],
#  'VEGFB': ['VEGFL', 'VRF'],
#  'SRD5A2': [],
#  'GOLGA8R': [],
#  'ZNF440': ['FLJ37933'],
#  'RNF138P1': [],
#  'ROBO3': ['RBIG1', 'FLJ21044', 'HGPS', 'HGPPS'],
#  'JAGN1': ['GL009', 'FLJ14602'],
#  'PJA2': ['KIAA0438', 'Neurodap1', 'PRAJA2', 'RNF131'],
#  'LOC100128239': [],
#  'ARHGEF38': ['FLJ20184'],
#  'MIR548Q': ['hsa-mir-548q'],
#  'ADAMTS8': ['METH2', 'FLJ41712', 'ADAM-TS8'],
#  'ZNF271': [],
#  'FBRS': ['FBS', 'FLJ11618', 'FBS1'],
#  'TMEM251': [],
#  'GGH': ['GATD10'],
#  'COL26A1': ['Emu2', 'EMI6', 'EMID2'],
#  'VAT1': ['VATI', 'FLJ20230'],
#  'FCGR1A': ['CD64', 'CD64A', 'FcgammaRI', 'FcgammaRIa', 'FCG1', 'FCGR1'],
#  'NUFIP2': ['KIAA1321',
#   'MGC117262',
#   'PIG1',
#   '182-FIP',
#   'FIP-82',
#   '82-FIP',
#   'NUFP2'],
#  'ZNF514': ['FLJ14457'],
#  'ECE1-AS1': [],
#  'TMEM202-AS1': [],
#  'PDZK1IP1': ['DD96', 'MAP17', 'SPAP'],
#  'LOC102467217': [],
#  'YWHAH': ['YWHA1'],
#  'MLXIP': ['MONDOA', 'KIAA0867', 'MIR', 'bHLHe36'],
#  'DUSP9': ['MKP-4', 'MKP4'],
#  'EBF3': ['COE3', 'DKFZp667B0210'],
#  'MCMBP': ['FLJ13081', 'MCM-BP', 'C10orf119'],
#  'CYP4F24P': [],
#  'LINC02004': [],
#  'OTX2': [],
#  'PTDSS1': ['KIAA0024', 'PSSA', 'PSS1'],
#  'C13orf38': [],
#  'C17orf71': [],
#  'CENPC1': [],
#  'C7orf51': [],
#  'MYOZ3': ['CS-3', 'CS3', 'FRP3', 'FATZ-3'],
#  'ERG': ['erg-3', 'p55'],
#  'ETDC': [],
#  'CNKSR2': ['KIAA0902', 'CNK2', 'KSR2'],
#  'ARSE': [],
#  'C10orf110': [],
#  'LRRD1': ['IMAGE:4798971'],
#  'MIR103-2': [],
#  'LINC02554': [],
#  'ZNF112': ['ZFP112', 'ZNF228'],
#  'MIR4491': ['hsa-mir-4491'],
#  'LOC101927592': [],
#  'LOC731779': [],
#  'PPIL2': ['UBOX7', 'CYC4', 'Cyp-60'],
#  'RPGRIP1': ['RGI1', 'LCA6', 'CORD13', 'RPGRIP'],
#  'NAA11': ['ARD2', 'hARD2', 'ARD1B'],
#  'TIGD1': ['EEYORE'],
#  'ZNF485': [],
#  'ZNF77': ['pT1'],
#  'FUT3': ['CD174', 'LE'],
#  'LINC00261': ['bA216C10.1',
#   'HCCDR1',
#   'TCONS_00027846',
#   'ALIEN',
#   'DEANR1',
#   'onco-lncRNA-17',
#   'FALCOR',
#   'LCAL62',
#   'C20orf56',
#   'NCRNA00261'],
#  'SBK1': ['Sbk'],
#  'PGD': [],
#  'PRICKLE2': ['DKFZp686D143'],
#  'LOC100507384': [],
#  'LINGO3': ['LERN2', 'LRRN6B'],
#  'LOC100132288': [],
#  'ZRANB3': ['DKFZP434B1727', 'AH2'],
#  'INF2': ['MGC13251', 'C14orf151', 'C14orf173'],
#  'LINC02789': [],
#  'C6orf226': [],
#  'IRAK3': ['IRAK-M'],
#  'C16orf79': [],
#  'TNIP3': ['LIND', 'FLJ21162', 'ABIN-3'],
#  'PDE4C': ['DPDE1'],
#  'SNORD50B': ['U50B'],
#  'TMEM254-AS1': ['CPHX'],
#  'MIR10526': ['hsa-mir-10526'],
#  'PYGL': ['GSD6'],
#  'NINL': ['KIAA0980', 'NLP'],
#  'KANSL1': ['DKFZP727C091', 'MSL1v1', 'CENP-36', 'NSL1', 'KIAA1267'],
#  'MIR936': ['hsa-mir-936', 'MIRN936'],
#  'LINC01061': ['FLJ14186', 'KIKAT'],
#  'LPAR4': ['P2Y9', 'P2Y5-LIKE', 'P2RY9', 'LPA4', 'GPR23'],
#  'MIR3146': ['hsa-mir-3146'],
#  'PLVAP': ['gp68', 'PV-1', 'PV1', 'FELS'],
#  'ITGAE': ['CD103', 'HUMINAE'],
#  'C10orf108': [],
#  'MIR1228': ['hsa-mir-1228', 'MIRN1228'],
#  'HRH3': ['GPCR97'],
#  'KRTAP23-1': ['KAP23.1'],
#  'TMEM18': ['DKFZp434C1714', 'lncND'],
#  'RTCA-AS1': [],
#  'HRH2': [],
#  'ANKRD20A2': [],
#  'LOC149134': [],
#  'LINC01905': [],
#  'ZNF793-AS1': [],
#  'KCNJ2': ['Kir2.1', 'IRK1', 'LQT7'],
#  'DEFB104B': [],
#  'IBA57-DT': ['FLJ32878', 'C1orf148', 'IBA57-AS1'],
#  'MOV10L1': ['DJ402G11.8', 'DKFZp434B0717', 'CHAMP'],
#  'LRTM2': [],
#  'MIR4640': ['hsa-mir-4640'],
#  'KIAA0247': [],
#  'DNAJB1': ['Hsp40', 'Sis1', 'RSPH16B', 'HSPF1'],
#  'MIR1976': ['hsa-mir-1976'],
#  'WAPAL': [],
#  'LINC00355': [],
#  'C17orf112': [],
#  'NEK4': ['NRK2', 'pp12301', 'STK2'],
#  'SNX29P2': ['RUNDC2C'],
#  'C7orf16': [],
#  'LOC100130894': [],
#  'LINC02029': [],
#  'BCYRN1': ['BC200', 'BC200a', 'NCRNA00004', 'LINC00004'],
#  'LOC100287042': [],
#  'C1orf192': [],
#  'FRAT1': [],
#  'EN1': [],
#  'CTNS': ['CTNS-LSB', 'PQLC4', 'SLC66A4'],
#  'EFCAB14-AS1': ['KIAA0494-AS1'],
#  'LOC400752': [],
#  'MIR4739': ['hsa-mir-4739'],
#  'TMX1': ['TMX', 'PDIA11', 'TXNDC', 'TXNDC1'],
#  'RRP12': ['KIAA0690'],
#  'LOC284788': [],
#  'LOC100286906': [],
#  'NCRNA00119': [],
#  'UBR2': ['bA49A4.1', 'dJ392M17.3', 'KIAA0349', 'C6orf133'],
#  'SNORD116-21': ['HBII-85-21'],
#  'GRPEL2': ['DKFZp451C205', 'Mt-GrpE#2', 'FLJ23713'],
#  'SYTL5': ['Slp5'],
#  'HSCB': ['HSC20', 'DNAJC20', 'Jac1'],
#  'TMEM86A': ['FLJ90119'],
#  'PI4KB': ['PI4K-BETA', 'pi4K92', 'PIK4CB'],
#  'CKS1B': ['ckshs1', 'CKS1'],
#  'LINC00317': ['PRED89', 'C21orf117', 'NCRNA00317'],
#  'MIR4492': ['hsa-mir-4492'],
#  'HACD4': ['Em:AL662879.1', 'OTTHUMG00000021016', 'PTPLAD2'],
#  'MBD6': ['KIAA1887'],
#  'DNTTIP1': ['dJ447F3.4', 'Tdif1', 'C20orf167'],
#  'MIPOL1': ['CCDC193'],
#  'FCER2': ['CLEC4J', 'CD23', 'FCErII', 'FcepsilonRII', 'CD23A', 'FCE2'],
#  'KRT3': ['CK3', 'K3'],
#  'ITGB4': ['CD104'],
#  'HPCAL4': ['HLP4', 'DKFZp761G122'],
#  'MIR200C': ['hsa-mir-200c', 'MIRN200C'],
#  'OR4F15': [],
#  'SIN3A': ['KIAA0700', 'DKFZP434K2235'],
#  'KLHDC2': ['HCLP-1', 'LCP'],
#  'GFRA4': [],
#  'LSM12': ['FLJ30656'],
#  'DGAT1': ['ARGP1', 'DGAT'],
#  'KIR2DL5A': ['KIR2DL5.1', 'KIR2DL5', 'CD158F'],
#  'KIAA1841': [],
#  'ISYNA1': ['Ino1', 'INOS', 'IPS'],
#  'LOC105370333': [],
#  'RAB11B-AS1': ['MIR4999HG'],
#  'SNORA3B': ['ACA3-2', 'SNORA45', 'SNORA45B'],
#  'GPBP1': ['DKFZp761C169'],
#  'ANGPT2': ['Ang2'],
#  'LINC00667': ['lncOCMRL1'],
#  'IRAK1': ['IRAK', 'pelle'],
#  'PPP2R5C': ['B56G', 'PR61G', 'B56gamma'],
#  'MIR641': ['hsa-mir-641', 'MIRN641'],
#  'SERGEF': ['DelGEF', 'Gnefr'],
#  'TMEM8B': ['NAG-5', 'NGX6', 'NGX6a', 'FP588', 'C9orf127', 'LINC00950'],
#  'LOC644634': [],
#  'LBX1': ['LBX1H', 'HPX6'],
#  'RAMP2-AS1': [],
#  'LINC02057': [],
#  'LOC100272216': [],
#  'PKD1P5-LOC105376752': [],
#  'TGM2': ['TGC', 'TG2'],
#  'CAMK1D': ['CKLiK'],
#  'TRIM34': ['RNF21'],
#  'CORO7': ['FLJ22021', 'POD1'],
#  'KIAA1467': [],
#  'HSPA12B': ['dJ1009E24.2', 'C20orf60'],
#  'FAM110D': ['FLJ14050', 'GRRP1'],
#  'MIR548D1': ['hsa-mir-548d-1', 'MIRN548D1'],
#  'LINC01440': [],
#  'MIR451B': ['hsa-mir-451b'],
#  'CDK5RAP3': ['MST016',
#   'FLJ13660',
#   'C53',
#   'IC53',
#   'HSF-27',
#   'OK/SW-cl.114',
#   'LZAP'],
#  'IL23R': ['IL-23R'],
#  'PDLIM1': ['CLP-36', 'hCLIM1', 'CLP36', 'CLIM1'],
#  'KHDRBS1': ['Sam68', 'p62', 'FLJ34027'],
#  'C2orf47': [],
#  'GPR37L1': ['ETBR-LP-2'],
#  'PPP1R14A': ['CPI-17', 'PPP1INL'],
#  'DNAH6': ['Dnahc6', 'HL-2', 'FLJ37357', 'DNHL1'],
#  'LNCOG': ['RP11-54A9.1', 'lncRNA-OG', 'LINC02407'],
#  'DOCK5': ['FLJ21034'],
#  'LOC286238': [],
#  'HECTD2-AS1': [],
#  'C1QTNF12': ['MGC105127', 'CTRP12', 'ADIPOLIN', 'C1QDC2', 'FAM132A'],
#  'MT1JP': ['MTB', 'MT1', 'MT1NP', 'MT1J'],
#  'PIM3': [],
#  'ALKAL1': ['UNQ9433', 'AUGB', 'FAM150A'],
#  'NUP160': ['KIAA0197', 'FLJ22583'],
#  'GCNT1': ['C2GNT', 'NAGCT2', 'NACGT2'],
#  'GLOD4': ['CGI-150', 'HC71', 'C17orf25'],
#  'MSL2': ['FLJ10546', 'KIAA1585', 'msl-2', 'RNF184', 'MSL2L1'],
#  'KRTAP19-4': ['KAP19.4'],
#  'RASGEF1B': ['GPIG4', 'FLJ31695'],
#  'SMCR5': ['NCRNA00034'],
#  'ALDH8A1': ['ALDH12'],
#  'H3P4': ['p05', 'HIST2H3DP1'],
#  'WASHC2A': ['bA56A21.1', 'bA98I6.1', 'FLJ10824', 'FAM21B', 'FAM21A'],
#  'ENOX1': ['FLJ10094', 'PIG38', 'CNOX', 'cCNOX'],
#  'WDR38': [],
#  'LOC643802': [],
#  'USP21': ['USP16', 'USP23'],
#  'THNSL2': ['FLJ10916', 'TSH2', 'SOFAT'],
#  'MIR1281': ['hsa-mir-1281', 'MIRN1281'],
#  'LOC100505984': [],
#  'PI16': ['MGC45378', 'dJ90K10.5', 'MSMBBP', 'CD364'],
#  'NPY5R': ['NPYR5'],
#  'LOC388948': [],
#  'TMC8': ['EVIN2', 'EVER2'],
#  'GNA14': [],
#  'SAA2-SAA4': [],
#  'RANBP3L': ['FLJ25422'],
#  'CHPT1': ['CPT1'],
#  'C1QA': [],
#  'TNFRSF10B': ['DR5',
#   'KILLER',
#   'TRICK2A',
#   'TRAIL-R2',
#   'TRICKB',
#   'CD262',
#   'TRAILR2'],
#  'USP34': ['KIAA0570', 'KIAA0729'],
#  'LOC100128079': [],
#  'ADHFE1': ['FLJ32430'],
#  'HIST2H2BA': [],
#  'CDC27': ['APC3', 'ANAPC3', 'NUC2', 'D0S1430E', 'D17S978E'],
#  'MIR10396B': ['hsa-mir-10396b'],
#  'RPL41': ['L41', 'eL41'],
#  'DNAAF2': ['FLJ10563', 'KTU', 'pf13', 'CILD10', 'C14orf104'],
#  'LOC105377342': [],
#  'MOCOS': ['HMCS', 'FLJ20733', 'MOS', 'MCS'],
#  'ZNF544': ['AF020591'],
#  'LINC02289': [],
#  'PPM1K': ['DKFZp761G058', 'PP2Ckappa', 'hPTMP', 'PP2Cm', 'BDP'],
#  'FAM185A': ['MGC35361'],
#  'MIR208A': ['hsa-mir-208', 'hsa-mir-208a', 'MIRN208', 'MIRN208A'],
#  'SNORA2C': ['ACA34', 'SNORA34'],
#  'IFT122': ['WDR140', 'WDR10p', 'SPG', 'FAP80', 'CFAP80', 'WDR10'],
#  'FGF14-IT1': [],
#  'HSP90B1': ['GP96', 'GRP94', 'TRA1'],
#  'SELENOF': ['SEP15'],
#  'HCLS1': ['HS1', 'CTTNL'],
#  'MOBKL2A': [],
#  'SPOCK1': ['testican-1', 'TIC1', 'SPOCK'],
#  'SNORD96A': ['U96a'],
#  'PVRL2': [],
#  'TCAF2': ['FLJ40722', 'GATD9B', 'FAM139A', 'FAM115C'],
#  'FXR1': [],
#  'MIR1251': ['hsa-mir-1251', 'MIRN1251'],
#  'DNAJC5B': ['MGC26226', 'CSP-beta'],
#  'SNORA25B': [],
#  'SNORD105B': [],
#  'ESR1': ['ER', 'NR3A1', 'Era', 'ER-alpha', 'ESR'],
#  'MIR6804': ['hsa-mir-6804'],
#  'LOC100130849': [],
#  'CLPS': [],
#  'PARVA': ['FLJ12254', 'FLJ10793', 'MXRA2'],
#  'GCNT2': ['IGNT',
#   'NAGCT1',
#   'bA421M1.1',
#   'bA360O19.2',
#   'ULG3',
#   'NACGT1',
#   'II',
#   'GCNT5',
#   'CCAT'],
#  'H2BC1': ['bA317E16.3', 'STBP', 'TSH2B', 'H2BFU', 'HIST1H2BA'],
#  'SLC17A1': ['NAPI-1', 'NPT1'],
#  'MIR5579': ['hsa-mir-5579'],
#  'ARMCX5': ['FLJ12969', 'GASP5'],
#  'FAM18B': [],
#  'GOLGA2': ['GM130', 'golgin-95'],
#  'LLGL2': ['HGL', 'Hugl-2'],
#  'SFSWAP': ['SWAP', 'SFRS8'],
#  'UBE2E1-AS1': [],
#  'LOC101928618': [],
#  'LINC00457': [],
#  'DNAJC8': ['SPF31'],
#  'ZNF137': [],
#  'PPFIA3': ['KIAA0654', 'LPNA3', 'MGC126567', 'MGC126569'],
#  'H3C14': ['MGC9629',
#   'H3/m',
#   'H3',
#   'H3.2',
#   'H3/M',
#   'H3F2',
#   'H3FM',
#   'HIST2H3C'],
#  'LOC101928437': [],
#  'USPL1': ['bA121O19.1', 'D13S106E', 'C13orf22'],
#  'NXPH3': ['NPH3'],
#  'LOC105371998': [],
#  'LINC01387': ['C18orf64'],
#  'LINC00202-1': [],
#  'CCZ1': ['CGI-43', 'CCZ1A', 'C7orf28A'],
#  'LECT2': ['chm-II', 'chm2'],
#  'ACTR10': ['HARP11', 'ACTR11', 'Arp11', 'Arp10'],
#  'HIST1H2APS1': [],
#  'PSMD12': ['p55', 'Rpn5'],
#  'MIR518F': ['hsa-mir-518f', 'MIRN518F'],
#  'ERMP1': ['FLJ23309', 'FXNA', 'KIAA1815'],
#  'TMEM271': [],
#  'FKBP1AP1': ['FKBP1P1'],
#  'C17orf54': [],
#  'MIR380': ['hsa-mir-380', 'MIRN380'],
#  'ZSCAN22': ['ZNF50', 'HKR2'],
#  'LOC100506388': [],
#  'GDF9': [],
#  'LOC100132111': [],
#  'MED15': ['TIG-1', 'CAG7A', 'Arc105', 'TNRC7', 'PCQAP'],
#  'PRPF4B': [],
#  'ID1': ['dJ857M17.1.2', 'bHLHb24'],
#  'ZNF397': ['ZSCAN15', 'MGC13250', 'ZNF47'],
#  'CD83': ['HB15', 'BL11'],
#  'GPR6': [],
#  'ASAH1': ['AC', 'PHP32', 'FLJ21558', 'ACDase', 'ASAH'],
#  'SEC24D': ['KIAA0755'],
#  'C12orf70': [],
#  'MIR365-2': [],
#  'LINC02141': [],
#  'KIAA1524': [],
#  'MLKL': ['FLJ34389'],
#  'USP17L9P': ['RS447', 'USP17'],
#  'CELP': ['CELL'],
#  'SNORD31B': [],
#  'RPS28': ['S28', 'eS28'],
#  'HCG2040054': [],
#  'FLJ37543': [],
#  'C4orf50': ['FLJ46481'],
#  'H4C2': ['H4/I', 'H4FI', 'HIST1H4B'],
#  'LINC02092': [],
#  'SNORA116': [],
#  'INSM2': ['IA-6', 'Mlt1'],
#  'ADAMTS20': ['GON-1'],
#  'DACT3-AS1': [],
#  'PSORS1C1': ['SEEK1', 'C6orf16'],
#  'MIR4306': ['hsa-mir-4306'],
#  'RPL13AP17': [],
#  'MIR548F2': ['hsa-mir-548f-2', 'MIRN548F2'],
#  'LINC01843': ['Lnc-APUE'],
#  'ASPHD1': [],
#  'TSPEAR-AS2': [],
#  'C14orf135': [],
#  'CCL16': ['NCC-4',
#   'SCYL4',
#   'LEC',
#   'HCC-4',
#   'LMC',
#   'LCC-1',
#   'CKb12',
#   'Mtn-1',
#   'SCYA16'],
#  'LINC00323': ['PRED42', 'FLJ37173', 'C21orf130', 'NCRNA00323'],
#  'C9orf123': [],
#  'LINC01501': [],
#  'LOC107986876': [],
#  'CAMTA1-DT': ['lncCAMTA1'],
#  'PWWP2B': ['bA432J24.1', 'FLJ46823', 'PWWP2'],
#  'CBWD1': [],
#  'NIPAL1': ['DKFZp686A06115', 'SLC57A3', 'NIPA3', 'NPAL1'],
#  'MIR224': ['hsa-mir-224', 'MIRN224'],
#  'MEX3D': ['Tino', 'KIAA2031', 'OK/SW-cl.4', 'RNF193', 'RKHD1'],
#  'ZNF324': ['ZF5128', 'ZNF324A'],
#  'ANGEL1': ['Ccr4e', 'KIAA0759'],
#  'OR4C12': [],
#  'LOC100506188': [],
#  'CCDC69': ['FLJ13705', 'DKFZP434C171'],
#  'ELAVL3': ['HUC', 'PLE21', 'DKFZp547J036', 'HUCL', 'MGC20653'],
#  'IQCB1': ['KIAA0036', 'NPHP5', 'SLSN5'],
#  'CC2D1B': ['KIAA1836', 'Freud-2', 'Lgd1'],
#  'DLG2': ['PSD-93', 'PSD93', 'chapsyn-110', 'PPP1R58'],
#  'MIR4685': ['hsa-mir-4685'],
#  'IFITM10': ['DSPA3'],
#  'MIR6754': ['hsa-mir-6754'],
#  'MIR103B2': ['hsa-mir-103-2-as',
#   'hsa-mir-103b-2',
#   'MIRN103-2AS',
#   'MIR103-2AS'],
#  'SCG3': ['SgIII', 'FLJ90833'],
#  'NCRNA00259': [],
#  'NLK': [],
#  'RNU4-1': ['U4BL', 'U4', 'RNU4B2', 'RNU4A'],
#  'LINC02361': [],
#  'CMTM6': ['FLJ20396', 'CKLFSF6'],
#  'MFSD14C': [],
#  'MTSS1L': [],
#  'CFL2': ['NEM7'],
#  'FAM71A': [],
#  'PPP1R11': ['HCGV', 'Tctex5', 'HCG-V', 'CFAP255', 'TCTE5'],
#  'C12orf48': [],
#  'FAM177B': ['RP11-452F19.2', 'FLJ43505'],
#  'MAGEB5': ['MAGE-B5', 'CT3.3'],
#  'SLC25A28': ['MRS3/4', 'MRS4L'],
#  'LERFS': [],
#  'LINC02510': [],
#  'SRY': ['TDF'],
#  'GPR142': ['PGR2'],
#  'C19orf57': [],
#  'MIR3945': ['hsa-mir-3945'],
#  'KLF16': ['NSLP2', 'BTEB4', 'DRRF'],
#  'MIR1278': ['hsa-mir-1278', 'MIRN1278'],
#  'CLEC4E': ['MINCLE', 'CLECSF9'],
#  'TFPT': ['FB1', 'amida', 'INO80F'],
#  'TIPARP-AS1': [],
#  'AMT': ['GCST', 'NKH'],
#  'GMCL1L': [],
#  'LINC00937': [],
#  'HSPB2': ['Hs.78846', 'MKBP'],
#  'CMAS': [],
#  'EIF2AK2': ['PKR', 'PPP1R83', 'PRKR'],
#  'PDCD6IP': ['Alix', 'AIP1', 'Hp95'],
#  'PMS2CL': ['PMS2P13'],
#  'IGLL5': [],
#  'HRNR': ['S100a18', 'S100A16', 'FLG3'],
#  'CNOT2': ['CDC36', 'NOT2H', 'NOT2'],
#  'SCAP': ['KIAA0199'],
#  'EEF1E1': ['AIMP3', 'P18'],
#  'MIR222': ['hsa-mir-222', 'MIRN222'],
#  'ADAMTS12': [],
#  'FRY-AS1': [],
#  'TMEM270': ['MGC26719', 'WBSCR28'],
#  'LINC00839': [],
#  'KRT222': ['KA21', 'MGC45562', 'KRT222P'],
#  'ASIP': ['ASP', 'AGTIL'],
#  'CBSL': [],
#  'INA': ['NF-66', 'NEF5'],
#  'CSAG4': [],
#  'DSCR9': ['NCRNA00038'],
#  'BACH1': ['BACH-1', 'BTBD24'],
#  'MYH7': ['CMD1S', 'CMH1', 'MPD1'],
#  'LOC102725121': [],
#  'SMYD2': ['HSKM-B', 'ZMYND14', 'KMT3C'],
#  'LOC105379152': [],
#  'RTN4': ['NSP-CL', 'KIAA0886', 'NOGO', 'ASY'],
#  'LASS1': [],
#  'INO80': ['KIAA1259', 'hINO80', 'INO80A', 'INOC1'],
#  'NCRNA00175': [],
#  'LCORL': ['MLR1', 'FLJ30696'],
#  'LOC220930': [],
#  'LINC00659': [],
#  'FTO': ['KIAA1752', 'MGC5149', 'ALKBH9', 'IFEX9'],
#  'LINC00562': [],
#  'RAB40A': ['RAR2A', 'Rar-2'],
#  'OLFM5P': [],
#  'LOC101929950': [],
#  'GLT25D1': [],
#  'PCSK6': ['SPC4', 'PACE4'],
#  'ERICH1-AS1': [],
#  'CLEC7A': ['DECTIN-1', 'hDectin-1', 'CD369', 'SCARE2', 'CLECSF12'],
#  'GPRASP1': ['GASP', 'GASP1'],
#  'TOPORS-AS1': [],
#  'GPR158': ['KIAA1136'],
#  'LOC100132057': [],
#  'AGMO': ['FLJ16237', 'TMEM195'],
#  'LRRC8B': ['TA-LRRP', 'KIAA0231'],
#  'MIR17': ['hsa-mir-17', 'MIRN17'],
#  'LOC100507387': [],
#  'NIFK-AS1': [],
#  'GABRG1': [],
#  'LINC01990': [],
#  'COL10A1': [],
#  'SPRR2B': [],
#  'ANXA10': ['ANX14'],
#  'MIR4290': ['hsa-mir-4290'],
#  'RFLNB': ['MGC45871', 'RefilinB', 'Cfm1', 'FAM101B'],
#  'LINCR-0003': [],
#  'CHD1L': ['ALC1'],
#  'NDUFA9': ['SDR22E1', 'CI-39k', 'COQ11', 'NDUFS2L'],
#  'TIMM23B': ['bA592B15.7'],
#  'CDKN2B-AS1': ['ANRIL',
#   'RP11-145E5.4',
#   'NCRNA00089',
#   'p15AS',
#   'CDKN2B-AS',
#   'PCAT12',
#   'CDKN2BAS'],
#  'KRT14': ['EBS3', 'EBS4'],
#  'C1QTNF8': ['UNQ5829', 'CTRP8'],
#  'WHAMML1': [],
#  'SNORD116-28': ['HBII-85-28'],
#  'MIR5739': ['hsa-mir-5739'],
#  'PERM1': ['MGC13275', 'RP11-54O7.8', 'C1orf170'],
#  'LINC00968': [],
#  'FAM179B': [],
#  'C17orf49': [],
#  'IFNA10': ['IFN-alphaC'],
#  'B3GNT3': ['B3GN-T3', 'beta3Gn-T3', 'HP10328', 'B3GNT-3', 'TMEM3'],
#  'FOXQ1': ['HFH1'],
#  'MPHOSPH6': ['MPP6'],
#  'DNAJC18': ['MGC29463'],
#  'LINC00844': [],
#  'DMRTC2': [],
#  'C3orf24': [],
#  'KDELR1': ['ERD2.1', 'ERD2', 'HDEL'],
#  'EXOC6': ['SEC15L',
#   'FLJ1125',
#   'DKFZp761I2124',
#   'MGC33397',
#   'Sec15',
#   'EXOC6A',
#   'SEC15L1'],
#  'RHOBTB3': ['KIAA0878'],
#  'NSG2': ['HMP19', 'CALY3'],
#  'C15orf58': [],
#  'FAM78B': [],
#  'TTLL9': ['dJ310O13.1', 'C20orf125'],
#  'KIF7': ['JBTS12'],
#  'ZSCAN29': ['FLJ35867', 'Zfp690', 'ZNF690'],
#  'IFNG-AS1': ['Tmevpg1', "LincR-Ifng-3'AS", 'NEST'],
#  'MIR1471': ['hsa-mir-1471', 'MIRN1471'],
#  'PROM2': [],
#  'FOCAD': ['FLJ20375', 'KIAA1797'],
#  'CXorf21': [],
#  'SPATA5L1': [],
#  'CTRB1': ['CTRB'],
#  'PLEKHF2': ['ZFYVE18', 'PHAFIN2', 'FLJ13187'],
#  'LINC00367': ['TCONS_l2_00007488'],
#  'TGFB1I1': ['Hic-5', 'TSC-5', 'ARA55', 'HIC-5'],
#  'TAS2R46': ['T2R54'],
#  'LOC102724804': [],
#  'MYO7A': ['NSRD2', 'USH1B', 'DFNB2', 'DFNA11'],
#  'NDUFB4': ['B15'],
#  'LINC01277': [],
#  'ARHGEF37': ['FLJ41603'],
#  'LACRT': ['LACRITIN'],
#  'MSANTD3': ['MGC17337', 'C9orf30'],
#  'SCXA': [],
#  'PHF3': [],
#  'MIR548A3': ['hsa-mir-548a-3', 'MIRN548A3'],
#  'LOC105369438': [],
#  'KRTAP5-8': ['KRTAP5.8', 'UHSKerB', 'KRTAP5-2'],
#  'MIR4636': ['hsa-mir-4636'],
#  'KIR2DS4': ['cl-39', 'KKA3', 'nkat8', 'CD158I'],
#  'CD200R1L-AS1': [],
#  'CXorf48': [],
#  'KIAA0430': [],
#  'NPTN': ['SDR1', 'GP55', 'GP65', 'np65', 'np55', 'SDFR1'],
#  'IL10RB-DT': ['IFNAR2-AS1', 'IL10RB-AS1'],
#  'LAMTOR5': ['XIP', 'MGC71071', 'HBXIP'],
#  'NXPE3': ['MGC15606', 'FAM55C'],
#  'RHOU': ['WRCH-1',
#   'DJ646B12.2',
#   'FLJ10616',
#   'WRCH1',
#   'CDC42L1',
#   'hG28K',
#   'fJ646B12.2',
#   'ARHU'],
#  'MIR5701-1': ['hsa-mir-5701-1'],
#  'ARHGAP32': ['GRIT', 'KIAA0712', 'MGC1892', 'RICS', 'GC-GAP'],
#  'SCP2': [],
#  'ZNF449': ['ZSCAN19', 'FLJ23614'],
#  'LINC02380': [],
#  'HOXC11': ['HOX3H'],
#  'PPP1R12A-AS1': ['R12A-AS1'],
#  'MIMT1': ['MIM1', 'NCRNA00067', 'LINC00067'],
#  'TAG': [],
#  'FGF12': ['FHF1', 'FGF12B'],
#  'C2orf69': ['FLJ38973'],
#  'MIR325': ['hsa-mir-325', 'MIRN325'],
#  'CES1P1': ['PCE-3', 'CESR', 'CES1A3', 'CES4'],
#  'LINC02062': [],
#  'ABHD18': ['FLJ21106', 'C4orf29'],
#  'LINC01242': [],
#  'SPINK4': ['PEC-60', 'MGC133107'],
#  'LINC01881': [],
#  'CA11': ['CARP2', 'CARPX1'],
#  'LINC00624': [],
#  'COX7A2': ['COXVIIa-L', 'COX7AL'],
#  'ZNF749': ['FLJ16360'],
#  'LOC101927911': [],
#  'FAM174A': ['UNQ1912', 'NS5ATP6', 'TMEM157'],
#  'ODF3': [],
#  'MGC15885': [],
#  'SCARNA28': ['ZL1'],
#  'LINC00475': ['C9orf44'],
#  'LMF1': ['FLJ12681', 'JFP11', 'FLJ22302', 'TMEM112A', 'C16orf26', 'TMEM112'],
#  'DKFZp434L192': [],
#  'NLRP14': ['NOD5', 'GC-LRR', 'Nalp-iota', 'PAN8', 'CLR11.2', 'NALP14'],
#  'SAMD9': ['KIAA2004', 'FLJ20073', 'C7orf5'],
#  'LOC105370068': [],
#  'NUDT16P1': [],
#  'MIR220A': ['hsa-mir-220', 'MIRN220', 'MIRN220A'],
#  'SNORD38C': [],
#  'SELENOI': ['KIAA1724', 'SELI', 'SEPI', 'EPT1'],
#  'SLC66A2': ['FLJ22378', 'PQLC1'],
#  'CDC14B': ['Cdc14B1', 'Cdc14B2', 'CDC14B3', 'hCDC14B'],
#  'DLGAP1-AS3': [],
#  'RARRES1': ['TIG1', 'LXNL'],
#  'MIR4769': ['hsa-mir-4769'],
#  'PLK4': ['Sak', 'STK18'],
#  'IGBP1': ['α4', 'IBP1'],
#  'LINC01318': [],
#  'PRR15L': ['MGC11242', 'ATAD4'],
#  'EPS15L1': ['eps15R'],
#  'LOC146336': [],
#  'CPXM1': ['CPX-1', 'CPX1', 'CPXM'],
#  'LINC02627': [],
#  'WIZ': ['ZNF803'],
#  'FAM19A2': [],
#  'ANKRD34C': [],
#  'MIR432': ['hsa-mir-432', 'MIRN432'],
#  'MPHOSPH9': ['MPP9'],
#  'MIR3177': ['hsa-mir-3177'],
#  'CRYGB': ['CRYG2'],
#  'MIR5706': ['hsa-mir-5706'],
#  'KIAA1598': [],
#  'CCDC64': [],
#  'ZNF415': [],
#  'LOC104054148': [],
#  'SPATA6': ['SRF1', 'FLJ10007', 'SRF-1'],
#  'AGTRAP': ['ATRAP'],
#  'ZNHIT3': ['Hit1', 'TRIP3'],
#  'DSCAS': [],
#  'SDC4': ['SYND4', 'amphiglycan', 'ryudocan'],
#  'GRIA2': ['GluA2', 'GLURB', 'GluR-K2', 'GluR-B', 'GluR-2', 'GLUR2'],
#  'SPRN': ['Shadoo', 'bA108K14.1', 'FLJ41197'],
#  'B3GAT3': ['GlcAT-I'],
#  'LTBP3': ['LTBP2'],
#  'GUK1': [],
#  'RPL37A': ['L37A', 'eL43'],
#  'TRIM28': ['TIF1B',
#   'KAP1',
#   'TF1B',
#   'RNF96',
#   'PPP1R157',
#   'KAP-1',
#   'TIF1-beta',
#   'TIF1beta'],
#  'BTAF1': ['TAFII170', 'TAF172', 'MOT1', 'TAF-172', 'TAF(II)170'],
#  'NAPG': [],
#  'ATP1B1': ['ATP1B'],
#  'ZNF763': ['ZNF440L'],
#  'MRPS9': ['RPMS9', 'MRP-S9', 'S9mt', 'uS9m'],
#  'YPEL1': [],
#  'CDC37L1-DT': ['CDC37L1-AS1'],
#  'RNF41': ['SBBI03', 'NRDP1'],
#  'LOC101927495': [],
#  'H2AZ2': ['MGC10170', 'MGC10831', 'MGC1947', 'H2AV', 'H2AFV'],
#  'PRSS36': ['FLJ90661'],
#  'MIR4452': ['hsa-mir-4452'],
#  'NUDT9P1': ['MGC34007', 'bA56M3.1', 'C10orf98'],
#  'TSPY2': ['TSPYQ1'],
#  'ARMS2': ['LOC387715', 'ARMD8'],
#  'ZNF253': ['BMZF-1', 'FLJ90391', 'ZNF411'],
#  'PRKD2': ['PKD2', 'HSPC187', 'DKFZP586E0820'],
#  'LOC107984236': [],
#  'EPS8': [],
#  'CCL19': ['ELC', 'MIP-3b', 'exodus-3', 'CKb11', 'SCYA19'],
#  'DOCK6': ['KIAA1395', 'ZIR1'],
#  'CCL24': ['Ckb-6', 'MPIF-2', 'eotaxin-2', 'MPIF2', 'SCYA24'],
#  'RIMBP3': ['KIAA1666', 'RIMBP3.1', 'RIMBP3A'],
#  'ZNF398': ['ZER6', 'KIAA1339', 'P51', 'P71'],
#  'C20orf166-AS1': [],
#  'CAB39L': ['bA103J18.3', 'FLJ12577', 'MO2L', 'MLAA-34'],
#  'MRTO4': ['dJ657E11.4', 'MRT4', 'C1orf33'],
#  'MARCH7': [],
#  'S1PR5': ['Edg-8', 'EDG8'],
#  'H2BP1': ['HIST2H2BA'],
#  'EML4-AS1': [],
#  'MIR548AJ1': ['hsa-mir-548aj-1'],
#  'ZNF214': [],
#  'CA1': ['Car1'],
#  'SNORD62A': ['U62', 'U62A', 'RNU62'],
#  'TFAP4': ['AP-4', 'bHLHc41'],
#  'LMNTD1': ['FLJ36004', 'Pas1c1', 'IFLTD1'],
#  'PMP22': ['HNPP', 'GAS3', 'Sp110', 'HMSNIA', 'CMT1A'],
#  'LINC01484': [],
#  'SCG5': ['7B2', 'SgV', 'SGNE1'],
#  'TRPM6': ['CHAK2', 'FLJ22628', 'HOMG', 'HSH'],
#  'CCDC73': ['NY-SAR-79'],
#  'ZNF174': ['ZSCAN8'],
#  'POP7': ['RPP20', 'RPP2'],
#  'MIR153-1': ['hsa-mir-153-1', 'MIRN153-1'],
#  'LOC440117': [],
#  'FRG1EP': [],
#  'SMG1P7': [],
#  'LOC101927023': [],
#  'BTBD18': [],
#  'PWRN4': ['LINC01084'],
#  'S100A16': ['S100F', 'DT1P1A7', 'MGC17528'],
#  'LAMTOR2': ['MAPBPIP', 'MAPKSP1AP', 'p14', 'ENDAP', 'Ragulator2', 'ROBLD3'],
#  'CPSF3L': [],
#  'ATP2B2-IT2': [],
#  'MIR4798': ['hsa-mir-4798'],
#  'SSH3': ['FLJ20515', 'FLJ10928'],
#  'TRPC4AP': ['DKFZP727M231',
#   'DKFZp586C1223',
#   'dJ756N5.2',
#   'TRRP4AP',
#   'PPP1R158',
#   'C20orf188'],
#  'SNORD116-19': ['HBII-85-19'],
#  'MIR598': ['hsa-mir-598', 'MIRN598'],
#  'LINC01085': [],
#  'SLC25A51P1': ['bA707M13.1', 'MCART3P'],
#  'MISP': ['DKFZp686H18209', 'Caprice', 'MISP1', 'C19orf21'],
#  'OR1D4': ['OR17-30'],
#  'SCN1A-AS1': ['SCN1ANAT', 'SCN1A-NAT'],
#  'NVL': ['NVL2'],
#  'SNN': [],
#  'LOC389906': [],
#  ...}

# %%
len(gene_alias_mapping)
# Out:
# 32247

# %%
new = {}

# %%
for g in gene_alias_mapping:
    aliases = gene_alias_mapping[g]
    for a in aliases:
        all_genes = [g] + aliases
        all_genes.remove(a)
        new[a] = all_genes

# %%
len(new)
# Out:
# 49689

# %% [markdown]
# #### Create DepMap Mapper

# %%
depmap = "/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/CRISPR_DepMap_Public_24Q2_Score_Chronos_subsetted_metadata.csv"

# %%
score_matrix = pd.read_csv(depmap)
# Out:
# /tmp/ipykernel_964/1296929490.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   score_matrix = pd.read_csv(depmap)

# %%
score_matrix
# Out:
#        depmap_id cell_line_display_name                  lineage_1  \
# 0     ACH-001270                 127399                Soft Tissue
# 1     ACH-002680                170MGBA                  CNS/Brain
# 2     ACH-002401                  21MT2                     Breast
# 3     ACH-002399                   21NT                     Breast
# 4     ACH-000520                    59M       Ovary/Fallopian Tube
# ...          ...                    ...                        ...
# 1145  ACH-000146                   THP1                    Myeloid
# 1146  ACH-000835                    GCT                Soft Tissue
# 1147  ACH-001300                 CHLA15  Peripheral Nervous System
# 1148  ACH-001301                COGN278  Peripheral Nervous System
# 1149  ACH-001302                COGN305  Peripheral Nervous System
#
#                                               lineage_2  \
# 0                                      Synovial Sarcoma
# 1                                        Diffuse Glioma
# 2                             Invasive Breast Carcinoma
# 3                             Invasive Breast Carcinoma
# 4                              Ovarian Epithelial Tumor
# ...                                                 ...
# 1145                             Acute Myeloid Leukemia
# 1146  Undifferentiated Pleomorphic Sarcoma/Malignant...
# 1147                                      Neuroblastoma
# 1148                                      Neuroblastoma
# 1149                                      Neuroblastoma
#
#                                               lineage_3          lineage_5  \
# 0                                      Synovial Sarcoma                NaN
# 1                                          Glioblastoma       Glioblastoma
# 2                      Breast Invasive Ductal Carcinoma                NaN
# 3                      Breast Invasive Ductal Carcinoma                NaN
# 4                      High-Grade Serous Ovarian Cancer  High Grade Serous
# ...                                                 ...                ...
# 1145                             Acute Myeloid Leukemia                 M5
# 1146  Undifferentiated Pleomorphic Sarcoma/Malignant...                NaN
# 1147                                      Neuroblastoma                NaN
# 1148                                      Neuroblastoma                NaN
# 1149                                      Neuroblastoma                NaN
#
#      lineage_6  lineage_4      A1BG      A1CF  ...    ZWILCH     ZWINT  \
# 0          NaN        NaN -0.125700 -0.190342  ... -0.560529 -0.266138
# 1          NaN        NaN -0.056783 -0.074939  ... -0.149722 -0.521723
# 2          NaN        NaN -0.039836 -0.116822  ... -0.261890 -0.458087
# 3          NaN        NaN  0.013372 -0.082142  ... -0.315221 -0.431554
# 4          NaN        NaN -0.222447 -0.096272  ... -0.333100 -0.556162
# ...        ...        ...       ...       ...  ...       ...       ...
# 1145       NaN        NaN -0.142702 -0.110119  ... -0.300280 -0.182461
# 1146       NaN        NaN -0.174303 -0.017148  ... -0.278384 -0.498170
# 1147       NaN        NaN -0.210638  0.075649  ... -0.321568 -0.486237
# 1148  MYCN Amp        NaN -0.014705 -0.000141  ... -0.490207 -0.502931
# 1149  MYCN Amp        NaN -0.034169  0.025067  ... -0.494952 -0.918928
#
#           ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# 0     0.022924  0.021368 -0.096022  0.126506 -0.068497  0.075919 -0.352637
# 1     0.072913  0.058573 -0.100639 -0.123846 -0.217436 -0.100587 -0.064954
# 2     0.009890  0.145250  0.027379 -0.008181 -0.178623 -0.051439 -0.307155
# 3    -0.200092  0.004946 -0.051205 -0.006521 -0.240958 -0.013675 -0.263179
# 4    -0.151574 -0.308978 -0.178016 -0.031038 -0.394326 -0.105367 -0.159511
# ...        ...       ...       ...       ...       ...       ...       ...
# 1145  0.102202 -0.069822 -0.173859 -0.111945  0.098092  0.064468  0.003113
# 1146  0.024834  0.104500 -0.020534 -0.105610 -0.111710  0.042609 -0.238596
# 1147 -0.031050  0.193135 -0.337853 -0.035557 -0.274687  0.158534 -0.217785
# 1148  0.398217  0.238408  0.007151  0.091789 -0.489645 -0.033089 -0.210309
# 1149  0.237331  0.265877 -0.084940 -0.225591 -0.346542 -0.129247  0.145504
#
#           ZZZ3
# 0    -0.662216
# 1    -0.282006
# 2    -0.183515
# 3    -0.207334
# 4    -0.135067
# ...        ...
# 1145 -0.179357
# 1146 -0.414749
# 1147 -0.240230
# 1148 -0.135954
# 1149 -0.175496
#
# [1150 rows x 18443 columns]

# %%
depmap_genes = list(score_matrix.columns)
#depmap_genes.remove("Unnamed: 0")
depmap_genes.remove("depmap_id")
depmap_genes.remove("cell_line_display_name")
depmap_genes.remove("lineage_1")
depmap_genes.remove("lineage_2")
depmap_genes.remove("lineage_3")
depmap_genes.remove("lineage_4")
depmap_genes.remove("lineage_5")
depmap_genes.remove("lineage_6")
len(depmap_genes)
# Out:
# 18435

# %%
missing = []
for g in depmap_genes:
    if g not in gene_alias_mapping and g not in new:
        missing.append(g)

# %%
len(missing)
# Out:
# 262

# %%
missing_genes_mapping = {}

for gene in tqdm(missing, desc="Processing genes"):
    aliases = fetch_previous_hgnc_symbols(gene)
    if aliases == ['']:
        aliases = []
    missing_genes_mapping[gene] = aliases
# Out:
# Processing genes: 100%|███████████████████████████████████████████████████████████████| 262/262 [01:57<00:00,  2.23it/s]

# %%
missing_genes_mapping
# Out:
# {'ABTB3': ['FLJ33957', 'ABTB2B', 'BTBD11'],
#  'ACTMAP': ['FLJ41131', 'C19orf54'],
#  'ADGRD2': ['PGR24', 'GPR144'],
#  'ADPRS': ['ARH3', 'FLJ20446', 'ADPRHL2'],
#  'AQP7B': [],
#  'ATOSA': ['FLJ10980', 'KIAA1370', 'FAM214A'],
#  'ATOSB': ['FLJ11560', 'bA182N22.6', 'KIAA1539', 'FAM214B'],
#  'ATP5MJ': ['MP68', 'MLQ', '6.8PL', 'C14orf2', 'ATP5MPL'],
#  'ATP5MK': ['MGC14697', 'bA792D24.4', 'DAPIT', 'AGP', 'USMG5', 'ATP5MD'],
#  'SPMIP1': ['ATP6V1FNB'],
#  'BBLN': ['Hero9', 'MGC4639', 'EST00098', 'FLJ12823', 'C9orf16'],
#  'BLTP1': ['FLJ21404', 'FSA', 'KIAA1371', 'Tweek', 'KIAA1109'],
#  'BLTP2': ['DKFZp686M0843',
#   'MGC111488',
#   'BCOX1',
#   'CT101',
#   'BCOX',
#   'FMP27',
#   'Hob',
#   'KIAA0100'],
#  'BLTP3A': ['FLJ20302', 'dJ349A12.1', 'C6orf107', 'UHRF1BP1'],
#  'BLTP3B': ['KIAA0701', 'SHIP164', 'UHRF1BP1L'],
#  'BMAL1': ['MOP3', 'JAP3', 'PASD3', 'bHLHe5', 'ARNTL1', 'ARNTL'],
#  'BMAL2': ['MOP9', 'CLIF', 'PASD9', 'bHLHe6', 'ARNTL2'],
#  'BPNT2': ['FLJ20421', 'IMPA3', 'gPAPP', 'IMPAD1'],
#  'BRME1': ['MGC11271', 'MEIOK21', 'C19orf57'],
#  'SPMIP5': ['MGC33547', 'Em:AC016825.4', 'C10orf82'],
#  'TOP6BL': ['FLJ22531', 'TOPOVIBL', 'C11orf80'],
#  'RLIG1': ['DKFZp434N2030', 'C12orf29'],
#  'FERRY3': ['Fy-3', 'C12orf4'],
#  'REDIC1': ['FLJ40126', 'C12orf40'],
#  'MTNAP1': ['HLC-8', 'MIG3', 'FLJ20721', 'SPEP1', 'C17orf80'],
#  'LIAT1': ['LOC400566', 'C17orf97'],
#  'SPMAP1': ['LOC388381', 'C17orf98'],
#  'ARK2N': ['MGC12909', 'ARKL1', 'RNF111L1', 'Ark2N', 'C18orf25'],
#  'SPMIP3': ['C1orf100'],
#  'AIRIM': ['FLJ20508', 'C1orf109'],
#  'FIRRM': ['FLJ10706', 'Apolo1', 'FLIP', 'MEICA1', 'C1orf112'],
#  'KPLCE': ['LEP7', 'XP32', 'C1orf68'],
#  'ADISSP': ['FLJ20550', 'C20orf27'],
#  'CIMIP1': ['bA196N14.1', 'LLC1', 'C20orf85'],
#  'EPCIP': ['B37', 'PRED81', 'CU062', 'C21orf120', 'C21orf62'],
#  'CEP15': ['HT021', 'C3orf14'],
#  'SPMIP2': ['FLJ25371', 'C4orf45'],
#  'CFAP96': ['LOC441054', 'C4orf47'],
#  'NICOL1': ['NICOL', 'C4orf48'],
#  'SPMIP4': ['C7orf31'],
#  'SPATA31G1': ['MGC41945', 'C9orf131'],
#  'SPMIP6': ['bA573M23.4',
#   'NYD-SP22',
#   'MGC32921',
#   'MGC33614',
#   'CBE1',
#   'SMRP1',
#   'C9orf24'],
#  'QNG1': ['MGC10999', 'C9orf64'],
#  'TEKTL1': ['FLJ40365', 'CCDC105'],
#  'CFAP263': ['HSPC065', 'DKFZp434N1418', 'CCDC113'],
#  'DRC12': ['LOC283152', 'CCDC153'],
#  'CCDC194': [],
#  'CFAP184': ['FLJ90575', 'CCDC96'],
#  'CCNP': ['FLJ13265', 'CNTD2'],
#  'CDIN1': ['HH114', 'MGC11326', 'FLJ22851', 'C15orf41'],
#  'CENATAC': ['DLNB14', 'CCDC84'],
#  'CEP20': ['DKFZp686N1651',
#   'FLJ31153',
#   'PHSECRG2',
#   'FOR20',
#   'C16orf63',
#   'FOPNL'],
#  'CEP43': ['FOP', 'FGFR1OP'],
#  'CFAP107': ['MGC35194', 'C1orf158'],
#  'CFAP119': ['MGC104706', 'C16orf93', 'CCDC189'],
#  'CFAP141': ['C1orf189'],
#  'CFAP20DC': ['FLJ42117', 'FLJ42930', 'C3orf67'],
#  'CFAP210': ['LOC129881', 'C2orf77', 'CCDC173'],
#  'CFAP251': ['MGC33630', 'CaM-IP4', 'WDR66'],
#  'CFAP276': ['C1orf194'],
#  'CFAP418': ['FLJ30600',
#   'CORD16',
#   'RP64',
#   'BBS21',
#   'FAP418',
#   'MOT25.',
#   'SMALLTALK',
#   'C8orf37'],
#  'CFAP68': ['FLJ23499', 'C11orf1'],
#  'CFAP90': ['LOC134121', 'C5orf49'],
#  'CFAP91': ['AAT1',
#   'AAT1alpha',
#   'SPATA26',
#   'CaM-IP2',
#   'AAT-1',
#   'C3orf15',
#   'MAATS1'],
#  'CFAP92': ['FLJ43738', 'FAP92', 'KIAA1257'],
#  'CFAP95': ['C9orf135'],
#  'CFAP97D2': [],
#  'CHCT1': ['C17orf64'],
#  'CIBAR1': ['FLJ38979', 'BARMR1', 'FAM92A1', 'FAM92A'],
#  'CIBAR2': ['FLJ44299', 'FAM92B'],
#  'CIROP': ['LMLN2'],
#  'CLEC20A': ['FLJ44005', 'RP4-593C16.2', 'NCRNA00083', 'LINC00083'],
#  'CLXN': ['FLJ11767', 'ODAD5', 'EFCAB1'],
#  'CMKLR2': ['GPR1'],
#  'CRACDL': ['MGC42367', 'C2orf55', 'KIAA1211L'],
#  'CSTPP1': ['FLJ22210', 'MGC4707', 'C11orf49'],
#  'CYRIA': ['DKFZP566A1524', 'FLJ11080', 'CYRI-A', 'FAM49A'],
#  'CYRIB': ['BM-009', 'CYRI-B', 'CYRI', 'FAM49B'],
#  'DNAAF10': ['FLJ31741', 'Monad', 'WDR92'],
#  'DNAAF11': ['TSLRP', 'LRTP', 'CILD19', 'tilB', 'LRRC6'],
#  'DNAAF6': ['MGC35261', 'NYSAR97', 'TWISTER', 'CXorf41', 'PIH1D3'],
#  'DNAAF8': ['FLJ43261', 'DKFZp686H2240', 'Daap1', 'C16orf71'],
#  'DNAAF9': ['DKFZp434N061', 'C20orf194'],
#  'DNAI3': ['DIC3', 'FLJ30067', 'NYD-SP29', 'WDR63'],
#  'DNAI4': ['DIC4', 'FLJ23129', 'WDR78'],
#  'DNAI7': ['LAS1', 'FLJ10921', 'PPP1R54', 'CASC1', 'CFAP94'],
#  'DUSP13B': ['TMDP', 'SKRP4', 'DUSP13'],
#  'DUSP29': ['DUSP27', 'DUPD1'],
#  'DYNC2I1': ['FLJ10300', 'FAP163', 'CFAP163', 'DIC6', 'WDR60'],
#  'DYNC2I2': ['DIC5', 'MGC20486', 'bA216B9.3', 'FAP133', 'CFAP133', 'WDR34'],
#  'DYNLT2': ['TCTEX1D3', 'TCTEX2', 'Tctex4', 'oda12', 'TCTE3'],
#  'DYNLT2B': ['MGC33212', 'TCTEX1D2'],
#  'DYNLT4': ['TCTEX1D4'],
#  'DYNLT5': ['FLJ40873', 'TCTEX1D1'],
#  'EEIG1': ['Eeig1', 'bA203J24.7', 'SYM-3A', 'C9orf132', 'FAM102A'],
#  'EEIG2': ['DKFZp779B126', 'SYM-3B', 'FAM102B'],
#  'ELAPOR1': ['maba1', 'EIG121', 'KIAA1324'],
#  'ELAPOR2': ['FLJ31340', 'EIG121L', 'KIAA1324L'],
#  'ENTREP1': ['X123', 'ENTREP', 'C9orf61', 'FAM189A2'],
#  'ENTREP2': ['KIAA0574', 'TMEM228', 'FAM189A1'],
#  'ENTREP3': ['cote1', 'C1orf2', 'FAM189B'],
#  'EOLA1': ['CXorf40', 'CXorf40A'],
#  'EOLA2': ['CXorf40B'],
#  'VCF1': ['FLJ14775', 'FAM104A'],
#  'VCF2': ['FLJ20434', 'CXorf44', 'FAM104B'],
#  'CIMIP2A': ['FAM166A'],
#  'CIMIP2B': ['FAM166B'],
#  'CIMIP2C': ['LOC339778', 'C2orf70', 'FAM166C'],
#  'ARB2A': ['DKFZP564D172', 'Toupee', 'C5orf21', 'FAM172A'],
#  'CFAP144': ['LOC440585', 'hCG23177', 'FAM183A'],
#  'SPATA31F1': ['C9orf144B', 'FAM205A'],
#  'SPATA31F3': ['FAM205CP', 'FAM205C'],
#  'FBXW10B': ['HREP', 'SM25H2', 'FBXW10P1', 'CDRT1'],
#  'FHIP1A': ['FLJ43373', 'FHIP-L', 'FAM160A1'],
#  'FHIP1B': ['FLJ22665',
#   'KIAA1759',
#   'DKFZP566M1046',
#   'FHIP',
#   'C11orf56',
#   'FAM160A2'],
#  'FHIP2A': ['bA106M7.3', 'KIAA1600', 'FAM160B1'],
#  'FHIP2B': ['FLJ21801', 'RAI16', 'FAM160B2'],
#  'FOXL3': [],
#  'FREY1': ['Frey', 'C11orf94'],
#  'G6PC1': ['GSD1a', 'G6PT', 'G6PC'],
#  'GARIN1A': ['GARI', 'FAM137B', 'FAM71F2'],
#  'GARIN1B': ['NYD-SP18', 'GARI-L1', 'FAM137A', 'FAM71F1'],
#  'GARIN2': ['GARI-L2', 'C14orf54', 'FAM71D'],
#  'GARIN3': ['MGC26988', 'GARI-L3', 'FAM71B'],
#  'GARIN4': ['FLJ32796', 'GARI-L4', 'FAM71A'],
#  'GARIN5A': ['GARIL5', 'FAM71E1'],
#  'GARIN6': ['MGC39520', 'FAM71C'],
#  'GARRE1': ['MiniBAR', 'KIAA0355'],
#  'GATD3': ['KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'GBA1': ['GLUC', 'GBA'],
#  'GFUS': ['FX', 'P35B', 'SDR4E1', 'TSTA3'],
#  'GOLM2': ['H63', 'DKFZp459F1927', 'CASC4'],
#  'GPR15LG': ['UNQ1833',
#   'RLLV1833',
#   'FLJ21763',
#   'CSBF',
#   'AP-57',
#   'GPR15L',
#   'C10orf99'],
#  'CIMIP3': ['GUCA1ANB'],
#  'H2AC25': ['MGC3165', 'HIST3H2A', 'H2AW'],
#  'H2BC26': ['HIST3H2BB', 'H2BU1'],
#  'H2BK1': ['H2BE1'],
#  'H4C16': ['MGC24116', 'HIST4H4', 'H4-16'],
#  'HAPSTR1': ['FLJ41272', 'PRO0149', 'TAPR1', 'C16orf72'],
#  'HOATZ': ['FLJ46266', 'C11orf88'],
#  'IFT25': ['HSPCO34', 'PP25', 'FAP232', 'CFAP232', 'C1orf41', 'HSPB11'],
#  'HYCC1': ['DRCTNNB1A', 'HCC', 'hyccin', 'FAM126A'],
#  'HYCC2': ['MGC39518', 'FAM126B'],
#  'IFTAP': ['FLJ38678', 'HEPIS', 'NWC', 'C11orf74'],
#  'IHO1': ['FLJ25320', 'CT74', 'LELA1', 'CCDC36'],
#  'INTS15': ['MGC2718', 'C7orf26'],
#  'IQANK1': ['onco-lncRNA-3', 'CACClnc', 'FAM83H-AS1'],
#  'IRAG1': ['JAW1L', 'IRAG', 'MRVI1'],
#  'IRAG2': ['JAW1', 'LRMP'],
#  'KASH5': ['FLJ32658', 'CCDC155'],
#  'KATNIP': ['JBTS26', 'KIAA0556'],
#  'NHSL3': ['KIAA1522'],
#  'KICS2': ['FLJ32549', 'C12orf66'],
#  'KRBOX5': ['ZNF720'],
#  'LDAF1': ['promethin', 'TMEM159'],
#  'CIMAP2': ['FLJ40201', 'LEM', 'C1orf177', 'LEXM'],
#  'LHFPL7': ['bA9F11.1', 'TMEM211'],
#  'GUCA1ANB-GUCA1A': [],
#  'HAPSTR2': [],
#  'LORICRIN': ['LOR'],
#  'LYSET': ['DKFZP564F1123', 'GCAF', 'C14orf109', 'TMEM251'],
#  'MACIR': ['FLJ25291', 'C5orf30'],
#  'MATCAP1': ['LOC653319', 'TMCP1', 'KIAA0895L'],
#  'MATCAP2': ['TMCP2', 'KIAA0895'],
#  'MEIOSIN': ['HMGDC', 'BHMG1'],
#  'METTL25B': ['CGI-41', 'C1orf66', 'RRNAD1'],
#  'TMT1A': ['DKFZP586A0522', 'METTL7A'],
#  'TMT1B': ['MGC17301', 'ALDI', 'METTL7B'],
#  'MIDEAS': ['LSR68', 'C14orf117', 'C14orf43', 'ELMSAN1'],
#  'MISFA': ['Kastor', 'Polluks', 'SPTY2D1-AS1', 'SPTY2D1OS'],
#  'MIX23': ['FLJ33273', 'CCDC58'],
#  'KGD4': ['DC47', 'MRP-S36', 'MRPS36'],
#  'MSANTD5': [],
#  'MTRFR': ['FLJ38663', 'SPG55', 'COXPD7', 'mtRF-R', 'C12orf65'],
#  'MYG1': ['MYG', 'Gamm1', 'C12orf10'],
#  'MYL11': ['MRLC2', 'HUMMLC2B', 'MYLPF'],
#  'NALF1': ['NLF-1', 'FAM155A'],
#  'NALF2': ['TED', 'TMEM28', 'CXorf63', 'FAM155B'],
#  'NFILZ': ['LINC01862'],
#  'NOPCHAP1': ['MGC40397', 'DDSR1', 'C12orf45'],
#  'NTAQ1': ['FLJ10204', 'C8orf32', 'WDYHV1'],
#  'NTMT2': ['HOMT1B', 'C1orf184', 'METTL11B'],
#  'ODAD1': ['FLJ32926', 'CILD20', 'CCDC114'],
#  'ODAD2': ['FLJ10817', 'FLJ10376', 'DKFZP434P1735', 'CILD23', 'gudu', 'ARMC4'],
#  'ODAD3': ['MGC20983', 'ODA10', 'CCDC151'],
#  'ODAD4': ['DKFZP434H0115', 'TTC25'],
#  'CIMAP1A': ['SHIPPO1', 'hSHIPPO', 'CT135', 'ODF3'],
#  'CIMAP1B': ['FAP123', 'ODF3B'],
#  'CIMAP1C': ['MGC48986', 'ODF3L1'],
#  'CIMAP1D': ['FLJ40059', 'C19orf19', 'ODF3L2'],
#  'OOSP3': [],
#  'PABIR1': ['MGC17347', 'C9orf42', 'FAM122A'],
#  'PABIR2': ['DKFZp686L20116', 'RP11-308B5.5', 'SPACIA2', 'FAM122B'],
#  'PABIR3': ['RP3-473B4.1', 'FAM122C'],
#  'PALS1': ['FLJ12615', 'MPP5'],
#  'PALS2': ['VAM-1', 'p55T', 'MPP6'],
#  'NHERF4': ['FLJ22756', 'IKEPP', 'NaPi-Cap2', 'PDZK2', 'PDZD3'],
#  'PEDS1': ['Kua', 'TMEM189'],
#  'PHAF1': ['lin-10', 'FLJ12076', 'MYTHO', 'C16orf6', 'LIN10', 'C16orf70'],
#  'PHB1': ['BAP32', 'PHB'],
#  'PIERCE1': ['MGC29761', 'RbEST47', 'C9orf116'],
#  'PIERCE2': ['FLJ27352', 'C15orf65'],
#  'CIMAP3': ['FLJ23853', 'pitchfork', 'C1orf88', 'PIFO'],
#  'POLR1F': ['RPA43', 'A43', 'TWISTNB'],
#  'POLR1G': ['ASE-1', 'CAST', 'PAF49', 'RPA34', 'A34.5', 'CD3EAP'],
#  'POLR1H': ['hZR14', 'HTEX-6', 'tctex-6', 'RPA12', 'A12.2', 'ZNRD1'],
#  'POU2AF2': ['MGC50104', 'OCA-T1', 'C11orf53'],
#  'POU2AF3': ['CASC13', 'OCA-T2', 'C11orf93', 'COLCA2'],
#  'SAXO4': ['IIIG9', 'FLJ32771', 'C11orf66', 'PPP1R32'],
#  'PRP4K': ['Prp4', 'PR4H', 'KIAA0536', 'Prp4B', 'PRPF4B'],
#  'PTGR3': ['MGC45594', 'PTGR-3', 'ZADH2'],
#  'PTTG1IP2': [],
#  'RIGI': ['RIG-I', 'FLJ13599', 'DKFZp434J1111', 'RIG-1', 'RIG1', 'DDX58'],
#  'RIMOC1': ['LOC285636', 'C5orf51'],
#  'ARK2C': ['ARKL2', 'RNF111L2', 'Ark2C', 'lncAMPC', 'RNF165'],
#  'RUSF1': ['FLJ13868', 'C16orf58'],
#  'SANBR': ['KIAA1841'],
#  'SKIC2': ['HLP',
#   'DDX13',
#   'SKI2W',
#   '170A',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2',
#   'SKIV2L'],
#  'SKIC3': ['THES', 'SKI3', 'KIAA0372', 'TTC37'],
#  'SKIC8': ['REC14', 'SKI8', 'WDR61'],
#  'NHERF1': ['NHERF', 'EBP50', 'NHERF-1', 'NHE-RF', 'SLC9A3R1'],
#  'NHERF2': ['SIP-1', 'TKA-1', 'NHERF-2', 'E3KARP', 'OCTS2', 'SLC9A3R2'],
#  'SLX9': ['PRED56', 'C21orf70', 'FAM207A'],
#  'SMIM11': ['C21orf51', 'FAM165B', 'SMIM11A'],
#  'SMIM34': ['SMIM34A'],
#  'MTCL2': ['dJ132F21.1', 'FLJ44670', 'SOGA', 'C20orf117', 'KIAA0889', 'SOGA1'],
#  'SPACDR': ['IMAGE:4839025', 'C7orf61'],
#  'SPADH': [],
#  'SPMIP7': ['C7orf72', 'SPATA48'],
#  'AFG2A': ['SPAF', 'AFG2', 'SPATA5'],
#  'AFG2B': ['MGC5347', 'FLJ12286', 'SPATA5L1'],
#  'SPRING1': ['FLJ21415', 'SPRING', 'POST1', 'LUR1', 'C12orf49'],
#  'STEEP1': ['FLJ22965', 'CXorf56'],
#  'STYXL2': ['DUSP27'],
#  'TAFAZZIN': ['BTHS', 'G4.5', 'TAZ1', 'CMD3A', 'EFE2', 'EFE', 'TAZ'],
#  'TAMALIN': ['GRASP'],
#  'TASL': ['FLJ11577', 'CXorf21'],
#  'CRIPTO': ['CR', 'Cripto-1', 'CR-1', 'TDGF1'],
#  'TEKTIP1': ['LOC100128569', 'C19orf71'],
#  'SPMIP8': ['TEPP'],
#  'CIMIP4': ['MGC35206', 'EAN57', 'C22orf33', 'TEX33'],
#  'SPMIP9': ['FLJ25369', 'TSC21', 'C2orf51', 'TEX37'],
#  'SPMIP10': ['MGC163367',
#   'MGC163369',
#   'FLJ27505',
#   'Tseg7',
#   'C5orf48',
#   'TEX43'],
#  'SAXO5': ['FLJ35784', 'C19orf45', 'TEX45'],
#  'SPMIP11': ['LINC00935', 'TEX49'],
#  'SPMAP2': ['CT56', 'THEG1', 'THEG'],
#  'SPMAP2L': ['THEGL'],
#  'TMEM276': [],
#  'TRAPPC14': ['FLJ10925', 'C7orf43', 'MAP11'],
#  'IFT56': ['FLJ12571', 'dyf-13', 'DYF13', 'TTC26'],
#  'IFT70A': ['FLJ13946', 'FAP259', 'CFAP259', 'TTC30A'],
#  'IFT70B': ['FLJ30990', 'fleer', 'TTC30B'],
#  'UQCC4': ['gs103', 'CCSMST1', 'URLC5', 'C16orf91'],
#  'UQCC5': ['C3orf78', 'SMIM4'],
#  'UQCC6': ['FLJ13975', 'DKFZp547P055', 'BR', 'C12orf73'],
#  'XNDC1N': [],
#  'YJU2B': ['MGC10471', 'CCDC130'],
#  'FAM200C': ['Buster3', 'C5orf54', 'ZBED8'],
#  'ZFTA': ['MGC3032', 'C11orf95'],
#  'ZFTRAF1': ['CHRP', 'KIAA0496', 'MGC13010', 'CYHR1'],
#  'ZNG1A': ['CBWD1'],
#  'ZNG1B': ['CBWD2']}

# %%
new_missing = {}
for g in missing_genes_mapping:
    aliases = missing_genes_mapping[g]
    for a in aliases:
        all_genes = [g] + aliases
        all_genes.remove(a)
        new_missing[a] = all_genes

# %%
new_missing
# Out:
# {'FLJ33957': ['ABTB3', 'ABTB2B', 'BTBD11'],
#  'ABTB2B': ['ABTB3', 'FLJ33957', 'BTBD11'],
#  'BTBD11': ['ABTB3', 'FLJ33957', 'ABTB2B'],
#  'FLJ41131': ['ACTMAP', 'C19orf54'],
#  'C19orf54': ['ACTMAP', 'FLJ41131'],
#  'PGR24': ['ADGRD2', 'GPR144'],
#  'GPR144': ['ADGRD2', 'PGR24'],
#  'ARH3': ['ADPRS', 'FLJ20446', 'ADPRHL2'],
#  'FLJ20446': ['ADPRS', 'ARH3', 'ADPRHL2'],
#  'ADPRHL2': ['ADPRS', 'ARH3', 'FLJ20446'],
#  'FLJ10980': ['ATOSA', 'KIAA1370', 'FAM214A'],
#  'KIAA1370': ['ATOSA', 'FLJ10980', 'FAM214A'],
#  'FAM214A': ['ATOSA', 'FLJ10980', 'KIAA1370'],
#  'FLJ11560': ['ATOSB', 'bA182N22.6', 'KIAA1539', 'FAM214B'],
#  'bA182N22.6': ['ATOSB', 'FLJ11560', 'KIAA1539', 'FAM214B'],
#  'KIAA1539': ['ATOSB', 'FLJ11560', 'bA182N22.6', 'FAM214B'],
#  'FAM214B': ['ATOSB', 'FLJ11560', 'bA182N22.6', 'KIAA1539'],
#  'MP68': ['ATP5MJ', 'MLQ', '6.8PL', 'C14orf2', 'ATP5MPL'],
#  'MLQ': ['ATP5MJ', 'MP68', '6.8PL', 'C14orf2', 'ATP5MPL'],
#  '6.8PL': ['ATP5MJ', 'MP68', 'MLQ', 'C14orf2', 'ATP5MPL'],
#  'C14orf2': ['ATP5MJ', 'MP68', 'MLQ', '6.8PL', 'ATP5MPL'],
#  'ATP5MPL': ['ATP5MJ', 'MP68', 'MLQ', '6.8PL', 'C14orf2'],
#  'MGC14697': ['ATP5MK', 'bA792D24.4', 'DAPIT', 'AGP', 'USMG5', 'ATP5MD'],
#  'bA792D24.4': ['ATP5MK', 'MGC14697', 'DAPIT', 'AGP', 'USMG5', 'ATP5MD'],
#  'DAPIT': ['ATP5MK', 'MGC14697', 'bA792D24.4', 'AGP', 'USMG5', 'ATP5MD'],
#  'AGP': ['ATP5MK', 'MGC14697', 'bA792D24.4', 'DAPIT', 'USMG5', 'ATP5MD'],
#  'USMG5': ['ATP5MK', 'MGC14697', 'bA792D24.4', 'DAPIT', 'AGP', 'ATP5MD'],
#  'ATP5MD': ['ATP5MK', 'MGC14697', 'bA792D24.4', 'DAPIT', 'AGP', 'USMG5'],
#  'ATP6V1FNB': ['SPMIP1'],
#  'Hero9': ['BBLN', 'MGC4639', 'EST00098', 'FLJ12823', 'C9orf16'],
#  'MGC4639': ['BBLN', 'Hero9', 'EST00098', 'FLJ12823', 'C9orf16'],
#  'EST00098': ['BBLN', 'Hero9', 'MGC4639', 'FLJ12823', 'C9orf16'],
#  'FLJ12823': ['BBLN', 'Hero9', 'MGC4639', 'EST00098', 'C9orf16'],
#  'C9orf16': ['BBLN', 'Hero9', 'MGC4639', 'EST00098', 'FLJ12823'],
#  'FLJ21404': ['BLTP1', 'FSA', 'KIAA1371', 'Tweek', 'KIAA1109'],
#  'FSA': ['BLTP1', 'FLJ21404', 'KIAA1371', 'Tweek', 'KIAA1109'],
#  'KIAA1371': ['BLTP1', 'FLJ21404', 'FSA', 'Tweek', 'KIAA1109'],
#  'Tweek': ['BLTP1', 'FLJ21404', 'FSA', 'KIAA1371', 'KIAA1109'],
#  'KIAA1109': ['BLTP1', 'FLJ21404', 'FSA', 'KIAA1371', 'Tweek'],
#  'DKFZp686M0843': ['BLTP2',
#   'MGC111488',
#   'BCOX1',
#   'CT101',
#   'BCOX',
#   'FMP27',
#   'Hob',
#   'KIAA0100'],
#  'MGC111488': ['BLTP2',
#   'DKFZp686M0843',
#   'BCOX1',
#   'CT101',
#   'BCOX',
#   'FMP27',
#   'Hob',
#   'KIAA0100'],
#  'BCOX1': ['BLTP2',
#   'DKFZp686M0843',
#   'MGC111488',
#   'CT101',
#   'BCOX',
#   'FMP27',
#   'Hob',
#   'KIAA0100'],
#  'CT101': ['BLTP2',
#   'DKFZp686M0843',
#   'MGC111488',
#   'BCOX1',
#   'BCOX',
#   'FMP27',
#   'Hob',
#   'KIAA0100'],
#  'BCOX': ['BLTP2',
#   'DKFZp686M0843',
#   'MGC111488',
#   'BCOX1',
#   'CT101',
#   'FMP27',
#   'Hob',
#   'KIAA0100'],
#  'FMP27': ['BLTP2',
#   'DKFZp686M0843',
#   'MGC111488',
#   'BCOX1',
#   'CT101',
#   'BCOX',
#   'Hob',
#   'KIAA0100'],
#  'Hob': ['BLTP2',
#   'DKFZp686M0843',
#   'MGC111488',
#   'BCOX1',
#   'CT101',
#   'BCOX',
#   'FMP27',
#   'KIAA0100'],
#  'KIAA0100': ['BLTP2',
#   'DKFZp686M0843',
#   'MGC111488',
#   'BCOX1',
#   'CT101',
#   'BCOX',
#   'FMP27',
#   'Hob'],
#  'FLJ20302': ['BLTP3A', 'dJ349A12.1', 'C6orf107', 'UHRF1BP1'],
#  'dJ349A12.1': ['BLTP3A', 'FLJ20302', 'C6orf107', 'UHRF1BP1'],
#  'C6orf107': ['BLTP3A', 'FLJ20302', 'dJ349A12.1', 'UHRF1BP1'],
#  'UHRF1BP1': ['BLTP3A', 'FLJ20302', 'dJ349A12.1', 'C6orf107'],
#  'KIAA0701': ['BLTP3B', 'SHIP164', 'UHRF1BP1L'],
#  'SHIP164': ['BLTP3B', 'KIAA0701', 'UHRF1BP1L'],
#  'UHRF1BP1L': ['BLTP3B', 'KIAA0701', 'SHIP164'],
#  'MOP3': ['BMAL1', 'JAP3', 'PASD3', 'bHLHe5', 'ARNTL1', 'ARNTL'],
#  'JAP3': ['BMAL1', 'MOP3', 'PASD3', 'bHLHe5', 'ARNTL1', 'ARNTL'],
#  'PASD3': ['BMAL1', 'MOP3', 'JAP3', 'bHLHe5', 'ARNTL1', 'ARNTL'],
#  'bHLHe5': ['BMAL1', 'MOP3', 'JAP3', 'PASD3', 'ARNTL1', 'ARNTL'],
#  'ARNTL1': ['BMAL1', 'MOP3', 'JAP3', 'PASD3', 'bHLHe5', 'ARNTL'],
#  'ARNTL': ['BMAL1', 'MOP3', 'JAP3', 'PASD3', 'bHLHe5', 'ARNTL1'],
#  'MOP9': ['BMAL2', 'CLIF', 'PASD9', 'bHLHe6', 'ARNTL2'],
#  'CLIF': ['BMAL2', 'MOP9', 'PASD9', 'bHLHe6', 'ARNTL2'],
#  'PASD9': ['BMAL2', 'MOP9', 'CLIF', 'bHLHe6', 'ARNTL2'],
#  'bHLHe6': ['BMAL2', 'MOP9', 'CLIF', 'PASD9', 'ARNTL2'],
#  'ARNTL2': ['BMAL2', 'MOP9', 'CLIF', 'PASD9', 'bHLHe6'],
#  'FLJ20421': ['BPNT2', 'IMPA3', 'gPAPP', 'IMPAD1'],
#  'IMPA3': ['BPNT2', 'FLJ20421', 'gPAPP', 'IMPAD1'],
#  'gPAPP': ['BPNT2', 'FLJ20421', 'IMPA3', 'IMPAD1'],
#  'IMPAD1': ['BPNT2', 'FLJ20421', 'IMPA3', 'gPAPP'],
#  'MGC11271': ['BRME1', 'MEIOK21', 'C19orf57'],
#  'MEIOK21': ['BRME1', 'MGC11271', 'C19orf57'],
#  'C19orf57': ['BRME1', 'MGC11271', 'MEIOK21'],
#  'MGC33547': ['SPMIP5', 'Em:AC016825.4', 'C10orf82'],
#  'Em:AC016825.4': ['SPMIP5', 'MGC33547', 'C10orf82'],
#  'C10orf82': ['SPMIP5', 'MGC33547', 'Em:AC016825.4'],
#  'FLJ22531': ['TOP6BL', 'TOPOVIBL', 'C11orf80'],
#  'TOPOVIBL': ['TOP6BL', 'FLJ22531', 'C11orf80'],
#  'C11orf80': ['TOP6BL', 'FLJ22531', 'TOPOVIBL'],
#  'DKFZp434N2030': ['RLIG1', 'C12orf29'],
#  'C12orf29': ['RLIG1', 'DKFZp434N2030'],
#  'Fy-3': ['FERRY3', 'C12orf4'],
#  'C12orf4': ['FERRY3', 'Fy-3'],
#  'FLJ40126': ['REDIC1', 'C12orf40'],
#  'C12orf40': ['REDIC1', 'FLJ40126'],
#  'HLC-8': ['MTNAP1', 'MIG3', 'FLJ20721', 'SPEP1', 'C17orf80'],
#  'MIG3': ['MTNAP1', 'HLC-8', 'FLJ20721', 'SPEP1', 'C17orf80'],
#  'FLJ20721': ['MTNAP1', 'HLC-8', 'MIG3', 'SPEP1', 'C17orf80'],
#  'SPEP1': ['MTNAP1', 'HLC-8', 'MIG3', 'FLJ20721', 'C17orf80'],
#  'C17orf80': ['MTNAP1', 'HLC-8', 'MIG3', 'FLJ20721', 'SPEP1'],
#  'LOC400566': ['LIAT1', 'C17orf97'],
#  'C17orf97': ['LIAT1', 'LOC400566'],
#  'LOC388381': ['SPMAP1', 'C17orf98'],
#  'C17orf98': ['SPMAP1', 'LOC388381'],
#  'MGC12909': ['ARK2N', 'ARKL1', 'RNF111L1', 'Ark2N', 'C18orf25'],
#  'ARKL1': ['ARK2N', 'MGC12909', 'RNF111L1', 'Ark2N', 'C18orf25'],
#  'RNF111L1': ['ARK2N', 'MGC12909', 'ARKL1', 'Ark2N', 'C18orf25'],
#  'Ark2N': ['ARK2N', 'MGC12909', 'ARKL1', 'RNF111L1', 'C18orf25'],
#  'C18orf25': ['ARK2N', 'MGC12909', 'ARKL1', 'RNF111L1', 'Ark2N'],
#  'C1orf100': ['SPMIP3'],
#  'FLJ20508': ['AIRIM', 'C1orf109'],
#  'C1orf109': ['AIRIM', 'FLJ20508'],
#  'FLJ10706': ['FIRRM', 'Apolo1', 'FLIP', 'MEICA1', 'C1orf112'],
#  'Apolo1': ['FIRRM', 'FLJ10706', 'FLIP', 'MEICA1', 'C1orf112'],
#  'FLIP': ['FIRRM', 'FLJ10706', 'Apolo1', 'MEICA1', 'C1orf112'],
#  'MEICA1': ['FIRRM', 'FLJ10706', 'Apolo1', 'FLIP', 'C1orf112'],
#  'C1orf112': ['FIRRM', 'FLJ10706', 'Apolo1', 'FLIP', 'MEICA1'],
#  'LEP7': ['KPLCE', 'XP32', 'C1orf68'],
#  'XP32': ['KPLCE', 'LEP7', 'C1orf68'],
#  'C1orf68': ['KPLCE', 'LEP7', 'XP32'],
#  'FLJ20550': ['ADISSP', 'C20orf27'],
#  'C20orf27': ['ADISSP', 'FLJ20550'],
#  'bA196N14.1': ['CIMIP1', 'LLC1', 'C20orf85'],
#  'LLC1': ['CIMIP1', 'bA196N14.1', 'C20orf85'],
#  'C20orf85': ['CIMIP1', 'bA196N14.1', 'LLC1'],
#  'B37': ['EPCIP', 'PRED81', 'CU062', 'C21orf120', 'C21orf62'],
#  'PRED81': ['EPCIP', 'B37', 'CU062', 'C21orf120', 'C21orf62'],
#  'CU062': ['EPCIP', 'B37', 'PRED81', 'C21orf120', 'C21orf62'],
#  'C21orf120': ['EPCIP', 'B37', 'PRED81', 'CU062', 'C21orf62'],
#  'C21orf62': ['EPCIP', 'B37', 'PRED81', 'CU062', 'C21orf120'],
#  'HT021': ['CEP15', 'C3orf14'],
#  'C3orf14': ['CEP15', 'HT021'],
#  'FLJ25371': ['SPMIP2', 'C4orf45'],
#  'C4orf45': ['SPMIP2', 'FLJ25371'],
#  'LOC441054': ['CFAP96', 'C4orf47'],
#  'C4orf47': ['CFAP96', 'LOC441054'],
#  'NICOL': ['NICOL1', 'C4orf48'],
#  'C4orf48': ['NICOL1', 'NICOL'],
#  'C7orf31': ['SPMIP4'],
#  'MGC41945': ['SPATA31G1', 'C9orf131'],
#  'C9orf131': ['SPATA31G1', 'MGC41945'],
#  'bA573M23.4': ['SPMIP6',
#   'NYD-SP22',
#   'MGC32921',
#   'MGC33614',
#   'CBE1',
#   'SMRP1',
#   'C9orf24'],
#  'NYD-SP22': ['SPMIP6',
#   'bA573M23.4',
#   'MGC32921',
#   'MGC33614',
#   'CBE1',
#   'SMRP1',
#   'C9orf24'],
#  'MGC32921': ['SPMIP6',
#   'bA573M23.4',
#   'NYD-SP22',
#   'MGC33614',
#   'CBE1',
#   'SMRP1',
#   'C9orf24'],
#  'MGC33614': ['SPMIP6',
#   'bA573M23.4',
#   'NYD-SP22',
#   'MGC32921',
#   'CBE1',
#   'SMRP1',
#   'C9orf24'],
#  'CBE1': ['SPMIP6',
#   'bA573M23.4',
#   'NYD-SP22',
#   'MGC32921',
#   'MGC33614',
#   'SMRP1',
#   'C9orf24'],
#  'SMRP1': ['SPMIP6',
#   'bA573M23.4',
#   'NYD-SP22',
#   'MGC32921',
#   'MGC33614',
#   'CBE1',
#   'C9orf24'],
#  'C9orf24': ['SPMIP6',
#   'bA573M23.4',
#   'NYD-SP22',
#   'MGC32921',
#   'MGC33614',
#   'CBE1',
#   'SMRP1'],
#  'MGC10999': ['QNG1', 'C9orf64'],
#  'C9orf64': ['QNG1', 'MGC10999'],
#  'FLJ40365': ['TEKTL1', 'CCDC105'],
#  'CCDC105': ['TEKTL1', 'FLJ40365'],
#  'HSPC065': ['CFAP263', 'DKFZp434N1418', 'CCDC113'],
#  'DKFZp434N1418': ['CFAP263', 'HSPC065', 'CCDC113'],
#  'CCDC113': ['CFAP263', 'HSPC065', 'DKFZp434N1418'],
#  'LOC283152': ['DRC12', 'CCDC153'],
#  'CCDC153': ['DRC12', 'LOC283152'],
#  'FLJ90575': ['CFAP184', 'CCDC96'],
#  'CCDC96': ['CFAP184', 'FLJ90575'],
#  'FLJ13265': ['CCNP', 'CNTD2'],
#  'CNTD2': ['CCNP', 'FLJ13265'],
#  'HH114': ['CDIN1', 'MGC11326', 'FLJ22851', 'C15orf41'],
#  'MGC11326': ['CDIN1', 'HH114', 'FLJ22851', 'C15orf41'],
#  'FLJ22851': ['CDIN1', 'HH114', 'MGC11326', 'C15orf41'],
#  'C15orf41': ['CDIN1', 'HH114', 'MGC11326', 'FLJ22851'],
#  'DLNB14': ['CENATAC', 'CCDC84'],
#  'CCDC84': ['CENATAC', 'DLNB14'],
#  'DKFZp686N1651': ['CEP20',
#   'FLJ31153',
#   'PHSECRG2',
#   'FOR20',
#   'C16orf63',
#   'FOPNL'],
#  'FLJ31153': ['CEP20',
#   'DKFZp686N1651',
#   'PHSECRG2',
#   'FOR20',
#   'C16orf63',
#   'FOPNL'],
#  'PHSECRG2': ['CEP20',
#   'DKFZp686N1651',
#   'FLJ31153',
#   'FOR20',
#   'C16orf63',
#   'FOPNL'],
#  'FOR20': ['CEP20',
#   'DKFZp686N1651',
#   'FLJ31153',
#   'PHSECRG2',
#   'C16orf63',
#   'FOPNL'],
#  'C16orf63': ['CEP20',
#   'DKFZp686N1651',
#   'FLJ31153',
#   'PHSECRG2',
#   'FOR20',
#   'FOPNL'],
#  'FOPNL': ['CEP20',
#   'DKFZp686N1651',
#   'FLJ31153',
#   'PHSECRG2',
#   'FOR20',
#   'C16orf63'],
#  'FOP': ['CEP43', 'FGFR1OP'],
#  'FGFR1OP': ['CEP43', 'FOP'],
#  'MGC35194': ['CFAP107', 'C1orf158'],
#  'C1orf158': ['CFAP107', 'MGC35194'],
#  'MGC104706': ['CFAP119', 'C16orf93', 'CCDC189'],
#  'C16orf93': ['CFAP119', 'MGC104706', 'CCDC189'],
#  'CCDC189': ['CFAP119', 'MGC104706', 'C16orf93'],
#  'C1orf189': ['CFAP141'],
#  'FLJ42117': ['CFAP20DC', 'FLJ42930', 'C3orf67'],
#  'FLJ42930': ['CFAP20DC', 'FLJ42117', 'C3orf67'],
#  'C3orf67': ['CFAP20DC', 'FLJ42117', 'FLJ42930'],
#  'LOC129881': ['CFAP210', 'C2orf77', 'CCDC173'],
#  'C2orf77': ['CFAP210', 'LOC129881', 'CCDC173'],
#  'CCDC173': ['CFAP210', 'LOC129881', 'C2orf77'],
#  'MGC33630': ['CFAP251', 'CaM-IP4', 'WDR66'],
#  'CaM-IP4': ['CFAP251', 'MGC33630', 'WDR66'],
#  'WDR66': ['CFAP251', 'MGC33630', 'CaM-IP4'],
#  'C1orf194': ['CFAP276'],
#  'FLJ30600': ['CFAP418',
#   'CORD16',
#   'RP64',
#   'BBS21',
#   'FAP418',
#   'MOT25.',
#   'SMALLTALK',
#   'C8orf37'],
#  'CORD16': ['CFAP418',
#   'FLJ30600',
#   'RP64',
#   'BBS21',
#   'FAP418',
#   'MOT25.',
#   'SMALLTALK',
#   'C8orf37'],
#  'RP64': ['CFAP418',
#   'FLJ30600',
#   'CORD16',
#   'BBS21',
#   'FAP418',
#   'MOT25.',
#   'SMALLTALK',
#   'C8orf37'],
#  'BBS21': ['CFAP418',
#   'FLJ30600',
#   'CORD16',
#   'RP64',
#   'FAP418',
#   'MOT25.',
#   'SMALLTALK',
#   'C8orf37'],
#  'FAP418': ['CFAP418',
#   'FLJ30600',
#   'CORD16',
#   'RP64',
#   'BBS21',
#   'MOT25.',
#   'SMALLTALK',
#   'C8orf37'],
#  'MOT25.': ['CFAP418',
#   'FLJ30600',
#   'CORD16',
#   'RP64',
#   'BBS21',
#   'FAP418',
#   'SMALLTALK',
#   'C8orf37'],
#  'SMALLTALK': ['CFAP418',
#   'FLJ30600',
#   'CORD16',
#   'RP64',
#   'BBS21',
#   'FAP418',
#   'MOT25.',
#   'C8orf37'],
#  'C8orf37': ['CFAP418',
#   'FLJ30600',
#   'CORD16',
#   'RP64',
#   'BBS21',
#   'FAP418',
#   'MOT25.',
#   'SMALLTALK'],
#  'FLJ23499': ['CFAP68', 'C11orf1'],
#  'C11orf1': ['CFAP68', 'FLJ23499'],
#  'LOC134121': ['CFAP90', 'C5orf49'],
#  'C5orf49': ['CFAP90', 'LOC134121'],
#  'AAT1': ['CFAP91',
#   'AAT1alpha',
#   'SPATA26',
#   'CaM-IP2',
#   'AAT-1',
#   'C3orf15',
#   'MAATS1'],
#  'AAT1alpha': ['CFAP91',
#   'AAT1',
#   'SPATA26',
#   'CaM-IP2',
#   'AAT-1',
#   'C3orf15',
#   'MAATS1'],
#  'SPATA26': ['CFAP91',
#   'AAT1',
#   'AAT1alpha',
#   'CaM-IP2',
#   'AAT-1',
#   'C3orf15',
#   'MAATS1'],
#  'CaM-IP2': ['CFAP91',
#   'AAT1',
#   'AAT1alpha',
#   'SPATA26',
#   'AAT-1',
#   'C3orf15',
#   'MAATS1'],
#  'AAT-1': ['CFAP91',
#   'AAT1',
#   'AAT1alpha',
#   'SPATA26',
#   'CaM-IP2',
#   'C3orf15',
#   'MAATS1'],
#  'C3orf15': ['CFAP91',
#   'AAT1',
#   'AAT1alpha',
#   'SPATA26',
#   'CaM-IP2',
#   'AAT-1',
#   'MAATS1'],
#  'MAATS1': ['CFAP91',
#   'AAT1',
#   'AAT1alpha',
#   'SPATA26',
#   'CaM-IP2',
#   'AAT-1',
#   'C3orf15'],
#  'FLJ43738': ['CFAP92', 'FAP92', 'KIAA1257'],
#  'FAP92': ['CFAP92', 'FLJ43738', 'KIAA1257'],
#  'KIAA1257': ['CFAP92', 'FLJ43738', 'FAP92'],
#  'C9orf135': ['CFAP95'],
#  'C17orf64': ['CHCT1'],
#  'FLJ38979': ['CIBAR1', 'BARMR1', 'FAM92A1', 'FAM92A'],
#  'BARMR1': ['CIBAR1', 'FLJ38979', 'FAM92A1', 'FAM92A'],
#  'FAM92A1': ['CIBAR1', 'FLJ38979', 'BARMR1', 'FAM92A'],
#  'FAM92A': ['CIBAR1', 'FLJ38979', 'BARMR1', 'FAM92A1'],
#  'FLJ44299': ['CIBAR2', 'FAM92B'],
#  'FAM92B': ['CIBAR2', 'FLJ44299'],
#  'LMLN2': ['CIROP'],
#  'FLJ44005': ['CLEC20A', 'RP4-593C16.2', 'NCRNA00083', 'LINC00083'],
#  'RP4-593C16.2': ['CLEC20A', 'FLJ44005', 'NCRNA00083', 'LINC00083'],
#  'NCRNA00083': ['CLEC20A', 'FLJ44005', 'RP4-593C16.2', 'LINC00083'],
#  'LINC00083': ['CLEC20A', 'FLJ44005', 'RP4-593C16.2', 'NCRNA00083'],
#  'FLJ11767': ['CLXN', 'ODAD5', 'EFCAB1'],
#  'ODAD5': ['CLXN', 'FLJ11767', 'EFCAB1'],
#  'EFCAB1': ['CLXN', 'FLJ11767', 'ODAD5'],
#  'GPR1': ['CMKLR2'],
#  'MGC42367': ['CRACDL', 'C2orf55', 'KIAA1211L'],
#  'C2orf55': ['CRACDL', 'MGC42367', 'KIAA1211L'],
#  'KIAA1211L': ['CRACDL', 'MGC42367', 'C2orf55'],
#  'FLJ22210': ['CSTPP1', 'MGC4707', 'C11orf49'],
#  'MGC4707': ['CSTPP1', 'FLJ22210', 'C11orf49'],
#  'C11orf49': ['CSTPP1', 'FLJ22210', 'MGC4707'],
#  'DKFZP566A1524': ['CYRIA', 'FLJ11080', 'CYRI-A', 'FAM49A'],
#  'FLJ11080': ['CYRIA', 'DKFZP566A1524', 'CYRI-A', 'FAM49A'],
#  'CYRI-A': ['CYRIA', 'DKFZP566A1524', 'FLJ11080', 'FAM49A'],
#  'FAM49A': ['CYRIA', 'DKFZP566A1524', 'FLJ11080', 'CYRI-A'],
#  'BM-009': ['CYRIB', 'CYRI-B', 'CYRI', 'FAM49B'],
#  'CYRI-B': ['CYRIB', 'BM-009', 'CYRI', 'FAM49B'],
#  'CYRI': ['CYRIB', 'BM-009', 'CYRI-B', 'FAM49B'],
#  'FAM49B': ['CYRIB', 'BM-009', 'CYRI-B', 'CYRI'],
#  'FLJ31741': ['DNAAF10', 'Monad', 'WDR92'],
#  'Monad': ['DNAAF10', 'FLJ31741', 'WDR92'],
#  'WDR92': ['DNAAF10', 'FLJ31741', 'Monad'],
#  'TSLRP': ['DNAAF11', 'LRTP', 'CILD19', 'tilB', 'LRRC6'],
#  'LRTP': ['DNAAF11', 'TSLRP', 'CILD19', 'tilB', 'LRRC6'],
#  'CILD19': ['DNAAF11', 'TSLRP', 'LRTP', 'tilB', 'LRRC6'],
#  'tilB': ['DNAAF11', 'TSLRP', 'LRTP', 'CILD19', 'LRRC6'],
#  'LRRC6': ['DNAAF11', 'TSLRP', 'LRTP', 'CILD19', 'tilB'],
#  'MGC35261': ['DNAAF6', 'NYSAR97', 'TWISTER', 'CXorf41', 'PIH1D3'],
#  'NYSAR97': ['DNAAF6', 'MGC35261', 'TWISTER', 'CXorf41', 'PIH1D3'],
#  'TWISTER': ['DNAAF6', 'MGC35261', 'NYSAR97', 'CXorf41', 'PIH1D3'],
#  'CXorf41': ['DNAAF6', 'MGC35261', 'NYSAR97', 'TWISTER', 'PIH1D3'],
#  'PIH1D3': ['DNAAF6', 'MGC35261', 'NYSAR97', 'TWISTER', 'CXorf41'],
#  'FLJ43261': ['DNAAF8', 'DKFZp686H2240', 'Daap1', 'C16orf71'],
#  'DKFZp686H2240': ['DNAAF8', 'FLJ43261', 'Daap1', 'C16orf71'],
#  'Daap1': ['DNAAF8', 'FLJ43261', 'DKFZp686H2240', 'C16orf71'],
#  'C16orf71': ['DNAAF8', 'FLJ43261', 'DKFZp686H2240', 'Daap1'],
#  'DKFZp434N061': ['DNAAF9', 'C20orf194'],
#  'C20orf194': ['DNAAF9', 'DKFZp434N061'],
#  'DIC3': ['DNAI3', 'FLJ30067', 'NYD-SP29', 'WDR63'],
#  'FLJ30067': ['DNAI3', 'DIC3', 'NYD-SP29', 'WDR63'],
#  'NYD-SP29': ['DNAI3', 'DIC3', 'FLJ30067', 'WDR63'],
#  'WDR63': ['DNAI3', 'DIC3', 'FLJ30067', 'NYD-SP29'],
#  'DIC4': ['DNAI4', 'FLJ23129', 'WDR78'],
#  'FLJ23129': ['DNAI4', 'DIC4', 'WDR78'],
#  'WDR78': ['DNAI4', 'DIC4', 'FLJ23129'],
#  'LAS1': ['DNAI7', 'FLJ10921', 'PPP1R54', 'CASC1', 'CFAP94'],
#  'FLJ10921': ['DNAI7', 'LAS1', 'PPP1R54', 'CASC1', 'CFAP94'],
#  'PPP1R54': ['DNAI7', 'LAS1', 'FLJ10921', 'CASC1', 'CFAP94'],
#  'CASC1': ['DNAI7', 'LAS1', 'FLJ10921', 'PPP1R54', 'CFAP94'],
#  'CFAP94': ['DNAI7', 'LAS1', 'FLJ10921', 'PPP1R54', 'CASC1'],
#  'TMDP': ['DUSP13B', 'SKRP4', 'DUSP13'],
#  'SKRP4': ['DUSP13B', 'TMDP', 'DUSP13'],
#  'DUSP13': ['DUSP13B', 'TMDP', 'SKRP4'],
#  'DUSP27': ['STYXL2'],
#  'DUPD1': ['DUSP29', 'DUSP27'],
#  'FLJ10300': ['DYNC2I1', 'FAP163', 'CFAP163', 'DIC6', 'WDR60'],
#  'FAP163': ['DYNC2I1', 'FLJ10300', 'CFAP163', 'DIC6', 'WDR60'],
#  'CFAP163': ['DYNC2I1', 'FLJ10300', 'FAP163', 'DIC6', 'WDR60'],
#  'DIC6': ['DYNC2I1', 'FLJ10300', 'FAP163', 'CFAP163', 'WDR60'],
#  'WDR60': ['DYNC2I1', 'FLJ10300', 'FAP163', 'CFAP163', 'DIC6'],
#  'DIC5': ['DYNC2I2', 'MGC20486', 'bA216B9.3', 'FAP133', 'CFAP133', 'WDR34'],
#  'MGC20486': ['DYNC2I2', 'DIC5', 'bA216B9.3', 'FAP133', 'CFAP133', 'WDR34'],
#  'bA216B9.3': ['DYNC2I2', 'DIC5', 'MGC20486', 'FAP133', 'CFAP133', 'WDR34'],
#  'FAP133': ['DYNC2I2', 'DIC5', 'MGC20486', 'bA216B9.3', 'CFAP133', 'WDR34'],
#  'CFAP133': ['DYNC2I2', 'DIC5', 'MGC20486', 'bA216B9.3', 'FAP133', 'WDR34'],
#  'WDR34': ['DYNC2I2', 'DIC5', 'MGC20486', 'bA216B9.3', 'FAP133', 'CFAP133'],
#  'TCTEX1D3': ['DYNLT2', 'TCTEX2', 'Tctex4', 'oda12', 'TCTE3'],
#  'TCTEX2': ['DYNLT2', 'TCTEX1D3', 'Tctex4', 'oda12', 'TCTE3'],
#  'Tctex4': ['DYNLT2', 'TCTEX1D3', 'TCTEX2', 'oda12', 'TCTE3'],
#  'oda12': ['DYNLT2', 'TCTEX1D3', 'TCTEX2', 'Tctex4', 'TCTE3'],
#  'TCTE3': ['DYNLT2', 'TCTEX1D3', 'TCTEX2', 'Tctex4', 'oda12'],
#  'MGC33212': ['DYNLT2B', 'TCTEX1D2'],
#  'TCTEX1D2': ['DYNLT2B', 'MGC33212'],
#  'TCTEX1D4': ['DYNLT4'],
#  'FLJ40873': ['DYNLT5', 'TCTEX1D1'],
#  'TCTEX1D1': ['DYNLT5', 'FLJ40873'],
#  'Eeig1': ['EEIG1', 'bA203J24.7', 'SYM-3A', 'C9orf132', 'FAM102A'],
#  'bA203J24.7': ['EEIG1', 'Eeig1', 'SYM-3A', 'C9orf132', 'FAM102A'],
#  'SYM-3A': ['EEIG1', 'Eeig1', 'bA203J24.7', 'C9orf132', 'FAM102A'],
#  'C9orf132': ['EEIG1', 'Eeig1', 'bA203J24.7', 'SYM-3A', 'FAM102A'],
#  'FAM102A': ['EEIG1', 'Eeig1', 'bA203J24.7', 'SYM-3A', 'C9orf132'],
#  'DKFZp779B126': ['EEIG2', 'SYM-3B', 'FAM102B'],
#  'SYM-3B': ['EEIG2', 'DKFZp779B126', 'FAM102B'],
#  'FAM102B': ['EEIG2', 'DKFZp779B126', 'SYM-3B'],
#  'maba1': ['ELAPOR1', 'EIG121', 'KIAA1324'],
#  'EIG121': ['ELAPOR1', 'maba1', 'KIAA1324'],
#  'KIAA1324': ['ELAPOR1', 'maba1', 'EIG121'],
#  'FLJ31340': ['ELAPOR2', 'EIG121L', 'KIAA1324L'],
#  'EIG121L': ['ELAPOR2', 'FLJ31340', 'KIAA1324L'],
#  'KIAA1324L': ['ELAPOR2', 'FLJ31340', 'EIG121L'],
#  'X123': ['ENTREP1', 'ENTREP', 'C9orf61', 'FAM189A2'],
#  'ENTREP': ['ENTREP1', 'X123', 'C9orf61', 'FAM189A2'],
#  'C9orf61': ['ENTREP1', 'X123', 'ENTREP', 'FAM189A2'],
#  'FAM189A2': ['ENTREP1', 'X123', 'ENTREP', 'C9orf61'],
#  'KIAA0574': ['ENTREP2', 'TMEM228', 'FAM189A1'],
#  'TMEM228': ['ENTREP2', 'KIAA0574', 'FAM189A1'],
#  'FAM189A1': ['ENTREP2', 'KIAA0574', 'TMEM228'],
#  'cote1': ['ENTREP3', 'C1orf2', 'FAM189B'],
#  'C1orf2': ['ENTREP3', 'cote1', 'FAM189B'],
#  'FAM189B': ['ENTREP3', 'cote1', 'C1orf2'],
#  'CXorf40': ['EOLA1', 'CXorf40A'],
#  'CXorf40A': ['EOLA1', 'CXorf40'],
#  'CXorf40B': ['EOLA2'],
#  'FLJ14775': ['VCF1', 'FAM104A'],
#  'FAM104A': ['VCF1', 'FLJ14775'],
#  'FLJ20434': ['VCF2', 'CXorf44', 'FAM104B'],
#  'CXorf44': ['VCF2', 'FLJ20434', 'FAM104B'],
#  'FAM104B': ['VCF2', 'FLJ20434', 'CXorf44'],
#  'FAM166A': ['CIMIP2A'],
#  'FAM166B': ['CIMIP2B'],
#  'LOC339778': ['CIMIP2C', 'C2orf70', 'FAM166C'],
#  'C2orf70': ['CIMIP2C', 'LOC339778', 'FAM166C'],
#  'FAM166C': ['CIMIP2C', 'LOC339778', 'C2orf70'],
#  'DKFZP564D172': ['ARB2A', 'Toupee', 'C5orf21', 'FAM172A'],
#  'Toupee': ['ARB2A', 'DKFZP564D172', 'C5orf21', 'FAM172A'],
#  'C5orf21': ['ARB2A', 'DKFZP564D172', 'Toupee', 'FAM172A'],
#  'FAM172A': ['ARB2A', 'DKFZP564D172', 'Toupee', 'C5orf21'],
#  'LOC440585': ['CFAP144', 'hCG23177', 'FAM183A'],
#  'hCG23177': ['CFAP144', 'LOC440585', 'FAM183A'],
#  'FAM183A': ['CFAP144', 'LOC440585', 'hCG23177'],
#  'C9orf144B': ['SPATA31F1', 'FAM205A'],
#  'FAM205A': ['SPATA31F1', 'C9orf144B'],
#  'FAM205CP': ['SPATA31F3', 'FAM205C'],
#  'FAM205C': ['SPATA31F3', 'FAM205CP'],
#  'HREP': ['FBXW10B', 'SM25H2', 'FBXW10P1', 'CDRT1'],
#  'SM25H2': ['FBXW10B', 'HREP', 'FBXW10P1', 'CDRT1'],
#  'FBXW10P1': ['FBXW10B', 'HREP', 'SM25H2', 'CDRT1'],
#  'CDRT1': ['FBXW10B', 'HREP', 'SM25H2', 'FBXW10P1'],
#  'FLJ43373': ['FHIP1A', 'FHIP-L', 'FAM160A1'],
#  'FHIP-L': ['FHIP1A', 'FLJ43373', 'FAM160A1'],
#  'FAM160A1': ['FHIP1A', 'FLJ43373', 'FHIP-L'],
#  'FLJ22665': ['FHIP1B',
#   'KIAA1759',
#   'DKFZP566M1046',
#   'FHIP',
#   'C11orf56',
#   'FAM160A2'],
#  'KIAA1759': ['FHIP1B',
#   'FLJ22665',
#   'DKFZP566M1046',
#   'FHIP',
#   'C11orf56',
#   'FAM160A2'],
#  'DKFZP566M1046': ['FHIP1B',
#   'FLJ22665',
#   'KIAA1759',
#   'FHIP',
#   'C11orf56',
#   'FAM160A2'],
#  'FHIP': ['FHIP1B',
#   'FLJ22665',
#   'KIAA1759',
#   'DKFZP566M1046',
#   'C11orf56',
#   'FAM160A2'],
#  'C11orf56': ['FHIP1B',
#   'FLJ22665',
#   'KIAA1759',
#   'DKFZP566M1046',
#   'FHIP',
#   'FAM160A2'],
#  'FAM160A2': ['FHIP1B',
#   'FLJ22665',
#   'KIAA1759',
#   'DKFZP566M1046',
#   'FHIP',
#   'C11orf56'],
#  'bA106M7.3': ['FHIP2A', 'KIAA1600', 'FAM160B1'],
#  'KIAA1600': ['FHIP2A', 'bA106M7.3', 'FAM160B1'],
#  'FAM160B1': ['FHIP2A', 'bA106M7.3', 'KIAA1600'],
#  'FLJ21801': ['FHIP2B', 'RAI16', 'FAM160B2'],
#  'RAI16': ['FHIP2B', 'FLJ21801', 'FAM160B2'],
#  'FAM160B2': ['FHIP2B', 'FLJ21801', 'RAI16'],
#  'Frey': ['FREY1', 'C11orf94'],
#  'C11orf94': ['FREY1', 'Frey'],
#  'GSD1a': ['G6PC1', 'G6PT', 'G6PC'],
#  'G6PT': ['G6PC1', 'GSD1a', 'G6PC'],
#  'G6PC': ['G6PC1', 'GSD1a', 'G6PT'],
#  'GARI': ['GARIN1A', 'FAM137B', 'FAM71F2'],
#  'FAM137B': ['GARIN1A', 'GARI', 'FAM71F2'],
#  'FAM71F2': ['GARIN1A', 'GARI', 'FAM137B'],
#  'NYD-SP18': ['GARIN1B', 'GARI-L1', 'FAM137A', 'FAM71F1'],
#  'GARI-L1': ['GARIN1B', 'NYD-SP18', 'FAM137A', 'FAM71F1'],
#  'FAM137A': ['GARIN1B', 'NYD-SP18', 'GARI-L1', 'FAM71F1'],
#  'FAM71F1': ['GARIN1B', 'NYD-SP18', 'GARI-L1', 'FAM137A'],
#  'GARI-L2': ['GARIN2', 'C14orf54', 'FAM71D'],
#  'C14orf54': ['GARIN2', 'GARI-L2', 'FAM71D'],
#  'FAM71D': ['GARIN2', 'GARI-L2', 'C14orf54'],
#  'MGC26988': ['GARIN3', 'GARI-L3', 'FAM71B'],
#  'GARI-L3': ['GARIN3', 'MGC26988', 'FAM71B'],
#  'FAM71B': ['GARIN3', 'MGC26988', 'GARI-L3'],
#  'FLJ32796': ['GARIN4', 'GARI-L4', 'FAM71A'],
#  'GARI-L4': ['GARIN4', 'FLJ32796', 'FAM71A'],
#  'FAM71A': ['GARIN4', 'FLJ32796', 'GARI-L4'],
#  'GARIL5': ['GARIN5A', 'FAM71E1'],
#  'FAM71E1': ['GARIN5A', 'GARIL5'],
#  'MGC39520': ['GARIN6', 'FAM71C'],
#  'FAM71C': ['GARIN6', 'MGC39520'],
#  'MiniBAR': ['GARRE1', 'KIAA0355'],
#  'KIAA0355': ['GARRE1', 'MiniBAR'],
#  'KNP-Ia': ['GATD3',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'GT335': ['GATD3',
#   'KNP-Ia',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'ES1': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'HES1': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'D21S2048E': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'KNPI': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPH',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'KNPH': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNP-I',
#   'C21orf33',
#   'GATD3A'],
#  'KNP-I': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'C21orf33',
#   'GATD3A'],
#  'C21orf33': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'GATD3A'],
#  'GATD3A': ['GATD3',
#   'KNP-Ia',
#   'GT335',
#   'ES1',
#   'HES1',
#   'D21S2048E',
#   'KNPI',
#   'KNPH',
#   'KNP-I',
#   'C21orf33'],
#  'GLUC': ['GBA1', 'GBA'],
#  'GBA': ['GBA1', 'GLUC'],
#  'FX': ['GFUS', 'P35B', 'SDR4E1', 'TSTA3'],
#  'P35B': ['GFUS', 'FX', 'SDR4E1', 'TSTA3'],
#  'SDR4E1': ['GFUS', 'FX', 'P35B', 'TSTA3'],
#  'TSTA3': ['GFUS', 'FX', 'P35B', 'SDR4E1'],
#  'H63': ['GOLM2', 'DKFZp459F1927', 'CASC4'],
#  'DKFZp459F1927': ['GOLM2', 'H63', 'CASC4'],
#  'CASC4': ['GOLM2', 'H63', 'DKFZp459F1927'],
#  'UNQ1833': ['GPR15LG',
#   'RLLV1833',
#   'FLJ21763',
#   'CSBF',
#   'AP-57',
#   'GPR15L',
#   'C10orf99'],
#  'RLLV1833': ['GPR15LG',
#   'UNQ1833',
#   'FLJ21763',
#   'CSBF',
#   'AP-57',
#   'GPR15L',
#   'C10orf99'],
#  'FLJ21763': ['GPR15LG',
#   'UNQ1833',
#   'RLLV1833',
#   'CSBF',
#   'AP-57',
#   'GPR15L',
#   'C10orf99'],
#  'CSBF': ['GPR15LG',
#   'UNQ1833',
#   'RLLV1833',
#   'FLJ21763',
#   'AP-57',
#   'GPR15L',
#   'C10orf99'],
#  'AP-57': ['GPR15LG',
#   'UNQ1833',
#   'RLLV1833',
#   'FLJ21763',
#   'CSBF',
#   'GPR15L',
#   'C10orf99'],
#  'GPR15L': ['GPR15LG',
#   'UNQ1833',
#   'RLLV1833',
#   'FLJ21763',
#   'CSBF',
#   'AP-57',
#   'C10orf99'],
#  'C10orf99': ['GPR15LG',
#   'UNQ1833',
#   'RLLV1833',
#   'FLJ21763',
#   'CSBF',
#   'AP-57',
#   'GPR15L'],
#  'GUCA1ANB': ['CIMIP3'],
#  'MGC3165': ['H2AC25', 'HIST3H2A', 'H2AW'],
#  'HIST3H2A': ['H2AC25', 'MGC3165', 'H2AW'],
#  'H2AW': ['H2AC25', 'MGC3165', 'HIST3H2A'],
#  'HIST3H2BB': ['H2BC26', 'H2BU1'],
#  'H2BU1': ['H2BC26', 'HIST3H2BB'],
#  'H2BE1': ['H2BK1'],
#  'MGC24116': ['H4C16', 'HIST4H4', 'H4-16'],
#  'HIST4H4': ['H4C16', 'MGC24116', 'H4-16'],
#  'H4-16': ['H4C16', 'MGC24116', 'HIST4H4'],
#  'FLJ41272': ['HAPSTR1', 'PRO0149', 'TAPR1', 'C16orf72'],
#  'PRO0149': ['HAPSTR1', 'FLJ41272', 'TAPR1', 'C16orf72'],
#  'TAPR1': ['HAPSTR1', 'FLJ41272', 'PRO0149', 'C16orf72'],
#  'C16orf72': ['HAPSTR1', 'FLJ41272', 'PRO0149', 'TAPR1'],
#  'FLJ46266': ['HOATZ', 'C11orf88'],
#  'C11orf88': ['HOATZ', 'FLJ46266'],
#  'HSPCO34': ['IFT25', 'PP25', 'FAP232', 'CFAP232', 'C1orf41', 'HSPB11'],
#  'PP25': ['IFT25', 'HSPCO34', 'FAP232', 'CFAP232', 'C1orf41', 'HSPB11'],
#  'FAP232': ['IFT25', 'HSPCO34', 'PP25', 'CFAP232', 'C1orf41', 'HSPB11'],
#  'CFAP232': ['IFT25', 'HSPCO34', 'PP25', 'FAP232', 'C1orf41', 'HSPB11'],
#  'C1orf41': ['IFT25', 'HSPCO34', 'PP25', 'FAP232', 'CFAP232', 'HSPB11'],
#  'HSPB11': ['IFT25', 'HSPCO34', 'PP25', 'FAP232', 'CFAP232', 'C1orf41'],
#  'DRCTNNB1A': ['HYCC1', 'HCC', 'hyccin', 'FAM126A'],
#  'HCC': ['HYCC1', 'DRCTNNB1A', 'hyccin', 'FAM126A'],
#  'hyccin': ['HYCC1', 'DRCTNNB1A', 'HCC', 'FAM126A'],
#  'FAM126A': ['HYCC1', 'DRCTNNB1A', 'HCC', 'hyccin'],
#  'MGC39518': ['HYCC2', 'FAM126B'],
#  'FAM126B': ['HYCC2', 'MGC39518'],
#  'FLJ38678': ['IFTAP', 'HEPIS', 'NWC', 'C11orf74'],
#  'HEPIS': ['IFTAP', 'FLJ38678', 'NWC', 'C11orf74'],
#  'NWC': ['IFTAP', 'FLJ38678', 'HEPIS', 'C11orf74'],
#  'C11orf74': ['IFTAP', 'FLJ38678', 'HEPIS', 'NWC'],
#  'FLJ25320': ['IHO1', 'CT74', 'LELA1', 'CCDC36'],
#  'CT74': ['IHO1', 'FLJ25320', 'LELA1', 'CCDC36'],
#  'LELA1': ['IHO1', 'FLJ25320', 'CT74', 'CCDC36'],
#  'CCDC36': ['IHO1', 'FLJ25320', 'CT74', 'LELA1'],
#  'MGC2718': ['INTS15', 'C7orf26'],
#  'C7orf26': ['INTS15', 'MGC2718'],
#  'onco-lncRNA-3': ['IQANK1', 'CACClnc', 'FAM83H-AS1'],
#  'CACClnc': ['IQANK1', 'onco-lncRNA-3', 'FAM83H-AS1'],
#  'FAM83H-AS1': ['IQANK1', 'onco-lncRNA-3', 'CACClnc'],
#  'JAW1L': ['IRAG1', 'IRAG', 'MRVI1'],
#  'IRAG': ['IRAG1', 'JAW1L', 'MRVI1'],
#  'MRVI1': ['IRAG1', 'JAW1L', 'IRAG'],
#  'JAW1': ['IRAG2', 'LRMP'],
#  'LRMP': ['IRAG2', 'JAW1'],
#  'FLJ32658': ['KASH5', 'CCDC155'],
#  'CCDC155': ['KASH5', 'FLJ32658'],
#  'JBTS26': ['KATNIP', 'KIAA0556'],
#  'KIAA0556': ['KATNIP', 'JBTS26'],
#  'KIAA1522': ['NHSL3'],
#  'FLJ32549': ['KICS2', 'C12orf66'],
#  'C12orf66': ['KICS2', 'FLJ32549'],
#  'ZNF720': ['KRBOX5'],
#  'promethin': ['LDAF1', 'TMEM159'],
#  'TMEM159': ['LDAF1', 'promethin'],
#  'FLJ40201': ['CIMAP2', 'LEM', 'C1orf177', 'LEXM'],
#  'LEM': ['CIMAP2', 'FLJ40201', 'C1orf177', 'LEXM'],
#  'C1orf177': ['CIMAP2', 'FLJ40201', 'LEM', 'LEXM'],
#  'LEXM': ['CIMAP2', 'FLJ40201', 'LEM', 'C1orf177'],
#  'bA9F11.1': ['LHFPL7', 'TMEM211'],
#  'TMEM211': ['LHFPL7', 'bA9F11.1'],
#  'LOR': ['LORICRIN'],
#  'DKFZP564F1123': ['LYSET', 'GCAF', 'C14orf109', 'TMEM251'],
#  'GCAF': ['LYSET', 'DKFZP564F1123', 'C14orf109', 'TMEM251'],
#  'C14orf109': ['LYSET', 'DKFZP564F1123', 'GCAF', 'TMEM251'],
#  'TMEM251': ['LYSET', 'DKFZP564F1123', 'GCAF', 'C14orf109'],
#  'FLJ25291': ['MACIR', 'C5orf30'],
#  'C5orf30': ['MACIR', 'FLJ25291'],
#  'LOC653319': ['MATCAP1', 'TMCP1', 'KIAA0895L'],
#  'TMCP1': ['MATCAP1', 'LOC653319', 'KIAA0895L'],
#  'KIAA0895L': ['MATCAP1', 'LOC653319', 'TMCP1'],
#  'TMCP2': ['MATCAP2', 'KIAA0895'],
#  'KIAA0895': ['MATCAP2', 'TMCP2'],
#  'HMGDC': ['MEIOSIN', 'BHMG1'],
#  'BHMG1': ['MEIOSIN', 'HMGDC'],
#  'CGI-41': ['METTL25B', 'C1orf66', 'RRNAD1'],
#  'C1orf66': ['METTL25B', 'CGI-41', 'RRNAD1'],
#  'RRNAD1': ['METTL25B', 'CGI-41', 'C1orf66'],
#  'DKFZP586A0522': ['TMT1A', 'METTL7A'],
#  'METTL7A': ['TMT1A', 'DKFZP586A0522'],
#  'MGC17301': ['TMT1B', 'ALDI', 'METTL7B'],
#  'ALDI': ['TMT1B', 'MGC17301', 'METTL7B'],
#  'METTL7B': ['TMT1B', 'MGC17301', 'ALDI'],
#  'LSR68': ['MIDEAS', 'C14orf117', 'C14orf43', 'ELMSAN1'],
#  'C14orf117': ['MIDEAS', 'LSR68', 'C14orf43', 'ELMSAN1'],
#  'C14orf43': ['MIDEAS', 'LSR68', 'C14orf117', 'ELMSAN1'],
#  'ELMSAN1': ['MIDEAS', 'LSR68', 'C14orf117', 'C14orf43'],
#  'Kastor': ['MISFA', 'Polluks', 'SPTY2D1-AS1', 'SPTY2D1OS'],
#  'Polluks': ['MISFA', 'Kastor', 'SPTY2D1-AS1', 'SPTY2D1OS'],
#  'SPTY2D1-AS1': ['MISFA', 'Kastor', 'Polluks', 'SPTY2D1OS'],
#  'SPTY2D1OS': ['MISFA', 'Kastor', 'Polluks', 'SPTY2D1-AS1'],
#  'FLJ33273': ['MIX23', 'CCDC58'],
#  'CCDC58': ['MIX23', 'FLJ33273'],
#  'DC47': ['KGD4', 'MRP-S36', 'MRPS36'],
#  'MRP-S36': ['KGD4', 'DC47', 'MRPS36'],
#  'MRPS36': ['KGD4', 'DC47', 'MRP-S36'],
#  'FLJ38663': ['MTRFR', 'SPG55', 'COXPD7', 'mtRF-R', 'C12orf65'],
#  'SPG55': ['MTRFR', 'FLJ38663', 'COXPD7', 'mtRF-R', 'C12orf65'],
#  'COXPD7': ['MTRFR', 'FLJ38663', 'SPG55', 'mtRF-R', 'C12orf65'],
#  'mtRF-R': ['MTRFR', 'FLJ38663', 'SPG55', 'COXPD7', 'C12orf65'],
#  'C12orf65': ['MTRFR', 'FLJ38663', 'SPG55', 'COXPD7', 'mtRF-R'],
#  'MYG': ['MYG1', 'Gamm1', 'C12orf10'],
#  'Gamm1': ['MYG1', 'MYG', 'C12orf10'],
#  'C12orf10': ['MYG1', 'MYG', 'Gamm1'],
#  'MRLC2': ['MYL11', 'HUMMLC2B', 'MYLPF'],
#  'HUMMLC2B': ['MYL11', 'MRLC2', 'MYLPF'],
#  'MYLPF': ['MYL11', 'MRLC2', 'HUMMLC2B'],
#  'NLF-1': ['NALF1', 'FAM155A'],
#  'FAM155A': ['NALF1', 'NLF-1'],
#  'TED': ['NALF2', 'TMEM28', 'CXorf63', 'FAM155B'],
#  'TMEM28': ['NALF2', 'TED', 'CXorf63', 'FAM155B'],
#  'CXorf63': ['NALF2', 'TED', 'TMEM28', 'FAM155B'],
#  'FAM155B': ['NALF2', 'TED', 'TMEM28', 'CXorf63'],
#  'LINC01862': ['NFILZ'],
#  'MGC40397': ['NOPCHAP1', 'DDSR1', 'C12orf45'],
#  'DDSR1': ['NOPCHAP1', 'MGC40397', 'C12orf45'],
#  'C12orf45': ['NOPCHAP1', 'MGC40397', 'DDSR1'],
#  'FLJ10204': ['NTAQ1', 'C8orf32', 'WDYHV1'],
#  'C8orf32': ['NTAQ1', 'FLJ10204', 'WDYHV1'],
#  'WDYHV1': ['NTAQ1', 'FLJ10204', 'C8orf32'],
#  'HOMT1B': ['NTMT2', 'C1orf184', 'METTL11B'],
#  'C1orf184': ['NTMT2', 'HOMT1B', 'METTL11B'],
#  'METTL11B': ['NTMT2', 'HOMT1B', 'C1orf184'],
#  'FLJ32926': ['ODAD1', 'CILD20', 'CCDC114'],
#  'CILD20': ['ODAD1', 'FLJ32926', 'CCDC114'],
#  'CCDC114': ['ODAD1', 'FLJ32926', 'CILD20'],
#  'FLJ10817': ['ODAD2', 'FLJ10376', 'DKFZP434P1735', 'CILD23', 'gudu', 'ARMC4'],
#  'FLJ10376': ['ODAD2', 'FLJ10817', 'DKFZP434P1735', 'CILD23', 'gudu', 'ARMC4'],
#  'DKFZP434P1735': ['ODAD2', 'FLJ10817', 'FLJ10376', 'CILD23', 'gudu', 'ARMC4'],
#  'CILD23': ['ODAD2', 'FLJ10817', 'FLJ10376', 'DKFZP434P1735', 'gudu', 'ARMC4'],
#  'gudu': ['ODAD2', 'FLJ10817', 'FLJ10376', 'DKFZP434P1735', 'CILD23', 'ARMC4'],
#  'ARMC4': ['ODAD2', 'FLJ10817', 'FLJ10376', 'DKFZP434P1735', 'CILD23', 'gudu'],
#  'MGC20983': ['ODAD3', 'ODA10', 'CCDC151'],
#  'ODA10': ['ODAD3', 'MGC20983', 'CCDC151'],
#  'CCDC151': ['ODAD3', 'MGC20983', 'ODA10'],
#  'DKFZP434H0115': ['ODAD4', 'TTC25'],
#  'TTC25': ['ODAD4', 'DKFZP434H0115'],
#  'SHIPPO1': ['CIMAP1A', 'hSHIPPO', 'CT135', 'ODF3'],
#  'hSHIPPO': ['CIMAP1A', 'SHIPPO1', 'CT135', 'ODF3'],
#  'CT135': ['CIMAP1A', 'SHIPPO1', 'hSHIPPO', 'ODF3'],
#  'ODF3': ['CIMAP1A', 'SHIPPO1', 'hSHIPPO', 'CT135'],
#  'FAP123': ['CIMAP1B', 'ODF3B'],
#  'ODF3B': ['CIMAP1B', 'FAP123'],
#  'MGC48986': ['CIMAP1C', 'ODF3L1'],
#  'ODF3L1': ['CIMAP1C', 'MGC48986'],
#  'FLJ40059': ['CIMAP1D', 'C19orf19', 'ODF3L2'],
#  'C19orf19': ['CIMAP1D', 'FLJ40059', 'ODF3L2'],
#  'ODF3L2': ['CIMAP1D', 'FLJ40059', 'C19orf19'],
#  'MGC17347': ['PABIR1', 'C9orf42', 'FAM122A'],
#  'C9orf42': ['PABIR1', 'MGC17347', 'FAM122A'],
#  'FAM122A': ['PABIR1', 'MGC17347', 'C9orf42'],
#  'DKFZp686L20116': ['PABIR2', 'RP11-308B5.5', 'SPACIA2', 'FAM122B'],
#  'RP11-308B5.5': ['PABIR2', 'DKFZp686L20116', 'SPACIA2', 'FAM122B'],
#  'SPACIA2': ['PABIR2', 'DKFZp686L20116', 'RP11-308B5.5', 'FAM122B'],
#  'FAM122B': ['PABIR2', 'DKFZp686L20116', 'RP11-308B5.5', 'SPACIA2'],
#  'RP3-473B4.1': ['PABIR3', 'FAM122C'],
#  'FAM122C': ['PABIR3', 'RP3-473B4.1'],
#  'FLJ12615': ['PALS1', 'MPP5'],
#  'MPP5': ['PALS1', 'FLJ12615'],
#  'VAM-1': ['PALS2', 'p55T', 'MPP6'],
#  'p55T': ['PALS2', 'VAM-1', 'MPP6'],
#  'MPP6': ['PALS2', 'VAM-1', 'p55T'],
#  'FLJ22756': ['NHERF4', 'IKEPP', 'NaPi-Cap2', 'PDZK2', 'PDZD3'],
#  'IKEPP': ['NHERF4', 'FLJ22756', 'NaPi-Cap2', 'PDZK2', 'PDZD3'],
#  'NaPi-Cap2': ['NHERF4', 'FLJ22756', 'IKEPP', 'PDZK2', 'PDZD3'],
#  'PDZK2': ['NHERF4', 'FLJ22756', 'IKEPP', 'NaPi-Cap2', 'PDZD3'],
#  'PDZD3': ['NHERF4', 'FLJ22756', 'IKEPP', 'NaPi-Cap2', 'PDZK2'],
#  'Kua': ['PEDS1', 'TMEM189'],
#  'TMEM189': ['PEDS1', 'Kua'],
#  'lin-10': ['PHAF1', 'FLJ12076', 'MYTHO', 'C16orf6', 'LIN10', 'C16orf70'],
#  'FLJ12076': ['PHAF1', 'lin-10', 'MYTHO', 'C16orf6', 'LIN10', 'C16orf70'],
#  'MYTHO': ['PHAF1', 'lin-10', 'FLJ12076', 'C16orf6', 'LIN10', 'C16orf70'],
#  'C16orf6': ['PHAF1', 'lin-10', 'FLJ12076', 'MYTHO', 'LIN10', 'C16orf70'],
#  'LIN10': ['PHAF1', 'lin-10', 'FLJ12076', 'MYTHO', 'C16orf6', 'C16orf70'],
#  'C16orf70': ['PHAF1', 'lin-10', 'FLJ12076', 'MYTHO', 'C16orf6', 'LIN10'],
#  'BAP32': ['PHB1', 'PHB'],
#  'PHB': ['PHB1', 'BAP32'],
#  'MGC29761': ['PIERCE1', 'RbEST47', 'C9orf116'],
#  'RbEST47': ['PIERCE1', 'MGC29761', 'C9orf116'],
#  'C9orf116': ['PIERCE1', 'MGC29761', 'RbEST47'],
#  'FLJ27352': ['PIERCE2', 'C15orf65'],
#  'C15orf65': ['PIERCE2', 'FLJ27352'],
#  'FLJ23853': ['CIMAP3', 'pitchfork', 'C1orf88', 'PIFO'],
#  'pitchfork': ['CIMAP3', 'FLJ23853', 'C1orf88', 'PIFO'],
#  'C1orf88': ['CIMAP3', 'FLJ23853', 'pitchfork', 'PIFO'],
#  'PIFO': ['CIMAP3', 'FLJ23853', 'pitchfork', 'C1orf88'],
#  'RPA43': ['POLR1F', 'A43', 'TWISTNB'],
#  'A43': ['POLR1F', 'RPA43', 'TWISTNB'],
#  'TWISTNB': ['POLR1F', 'RPA43', 'A43'],
#  'ASE-1': ['POLR1G', 'CAST', 'PAF49', 'RPA34', 'A34.5', 'CD3EAP'],
#  'CAST': ['POLR1G', 'ASE-1', 'PAF49', 'RPA34', 'A34.5', 'CD3EAP'],
#  'PAF49': ['POLR1G', 'ASE-1', 'CAST', 'RPA34', 'A34.5', 'CD3EAP'],
#  'RPA34': ['POLR1G', 'ASE-1', 'CAST', 'PAF49', 'A34.5', 'CD3EAP'],
#  'A34.5': ['POLR1G', 'ASE-1', 'CAST', 'PAF49', 'RPA34', 'CD3EAP'],
#  'CD3EAP': ['POLR1G', 'ASE-1', 'CAST', 'PAF49', 'RPA34', 'A34.5'],
#  'hZR14': ['POLR1H', 'HTEX-6', 'tctex-6', 'RPA12', 'A12.2', 'ZNRD1'],
#  'HTEX-6': ['POLR1H', 'hZR14', 'tctex-6', 'RPA12', 'A12.2', 'ZNRD1'],
#  'tctex-6': ['POLR1H', 'hZR14', 'HTEX-6', 'RPA12', 'A12.2', 'ZNRD1'],
#  'RPA12': ['POLR1H', 'hZR14', 'HTEX-6', 'tctex-6', 'A12.2', 'ZNRD1'],
#  'A12.2': ['POLR1H', 'hZR14', 'HTEX-6', 'tctex-6', 'RPA12', 'ZNRD1'],
#  'ZNRD1': ['POLR1H', 'hZR14', 'HTEX-6', 'tctex-6', 'RPA12', 'A12.2'],
#  'MGC50104': ['POU2AF2', 'OCA-T1', 'C11orf53'],
#  'OCA-T1': ['POU2AF2', 'MGC50104', 'C11orf53'],
#  'C11orf53': ['POU2AF2', 'MGC50104', 'OCA-T1'],
#  'CASC13': ['POU2AF3', 'OCA-T2', 'C11orf93', 'COLCA2'],
#  'OCA-T2': ['POU2AF3', 'CASC13', 'C11orf93', 'COLCA2'],
#  'C11orf93': ['POU2AF3', 'CASC13', 'OCA-T2', 'COLCA2'],
#  'COLCA2': ['POU2AF3', 'CASC13', 'OCA-T2', 'C11orf93'],
#  'IIIG9': ['SAXO4', 'FLJ32771', 'C11orf66', 'PPP1R32'],
#  'FLJ32771': ['SAXO4', 'IIIG9', 'C11orf66', 'PPP1R32'],
#  'C11orf66': ['SAXO4', 'IIIG9', 'FLJ32771', 'PPP1R32'],
#  'PPP1R32': ['SAXO4', 'IIIG9', 'FLJ32771', 'C11orf66'],
#  'Prp4': ['PRP4K', 'PR4H', 'KIAA0536', 'Prp4B', 'PRPF4B'],
#  'PR4H': ['PRP4K', 'Prp4', 'KIAA0536', 'Prp4B', 'PRPF4B'],
#  'KIAA0536': ['PRP4K', 'Prp4', 'PR4H', 'Prp4B', 'PRPF4B'],
#  'Prp4B': ['PRP4K', 'Prp4', 'PR4H', 'KIAA0536', 'PRPF4B'],
#  'PRPF4B': ['PRP4K', 'Prp4', 'PR4H', 'KIAA0536', 'Prp4B'],
#  'MGC45594': ['PTGR3', 'PTGR-3', 'ZADH2'],
#  'PTGR-3': ['PTGR3', 'MGC45594', 'ZADH2'],
#  'ZADH2': ['PTGR3', 'MGC45594', 'PTGR-3'],
#  'RIG-I': ['RIGI', 'FLJ13599', 'DKFZp434J1111', 'RIG-1', 'RIG1', 'DDX58'],
#  'FLJ13599': ['RIGI', 'RIG-I', 'DKFZp434J1111', 'RIG-1', 'RIG1', 'DDX58'],
#  'DKFZp434J1111': ['RIGI', 'RIG-I', 'FLJ13599', 'RIG-1', 'RIG1', 'DDX58'],
#  'RIG-1': ['RIGI', 'RIG-I', 'FLJ13599', 'DKFZp434J1111', 'RIG1', 'DDX58'],
#  'RIG1': ['RIGI', 'RIG-I', 'FLJ13599', 'DKFZp434J1111', 'RIG-1', 'DDX58'],
#  'DDX58': ['RIGI', 'RIG-I', 'FLJ13599', 'DKFZp434J1111', 'RIG-1', 'RIG1'],
#  'LOC285636': ['RIMOC1', 'C5orf51'],
#  'C5orf51': ['RIMOC1', 'LOC285636'],
#  'ARKL2': ['ARK2C', 'RNF111L2', 'Ark2C', 'lncAMPC', 'RNF165'],
#  'RNF111L2': ['ARK2C', 'ARKL2', 'Ark2C', 'lncAMPC', 'RNF165'],
#  'Ark2C': ['ARK2C', 'ARKL2', 'RNF111L2', 'lncAMPC', 'RNF165'],
#  'lncAMPC': ['ARK2C', 'ARKL2', 'RNF111L2', 'Ark2C', 'RNF165'],
#  'RNF165': ['ARK2C', 'ARKL2', 'RNF111L2', 'Ark2C', 'lncAMPC'],
#  'FLJ13868': ['RUSF1', 'C16orf58'],
#  'C16orf58': ['RUSF1', 'FLJ13868'],
#  'KIAA1841': ['SANBR'],
#  'HLP': ['SKIC2',
#   'DDX13',
#   'SKI2W',
#   '170A',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2',
#   'SKIV2L'],
#  'DDX13': ['SKIC2',
#   'HLP',
#   'SKI2W',
#   '170A',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2',
#   'SKIV2L'],
#  'SKI2W': ['SKIC2',
#   'HLP',
#   'DDX13',
#   '170A',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2',
#   'SKIV2L'],
#  '170A': ['SKIC2',
#   'HLP',
#   'DDX13',
#   'SKI2W',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2',
#   'SKIV2L'],
#  'SKIV2L1': ['SKIC2',
#   'HLP',
#   'DDX13',
#   'SKI2W',
#   '170A',
#   'SKI2',
#   'SKIV2',
#   'SKIV2L'],
#  'SKI2': ['SKIC2',
#   'HLP',
#   'DDX13',
#   'SKI2W',
#   '170A',
#   'SKIV2L1',
#   'SKIV2',
#   'SKIV2L'],
#  'SKIV2': ['SKIC2',
#   'HLP',
#   'DDX13',
#   'SKI2W',
#   '170A',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2L'],
#  'SKIV2L': ['SKIC2',
#   'HLP',
#   'DDX13',
#   'SKI2W',
#   '170A',
#   'SKIV2L1',
#   'SKI2',
#   'SKIV2'],
#  'THES': ['SKIC3', 'SKI3', 'KIAA0372', 'TTC37'],
#  'SKI3': ['SKIC3', 'THES', 'KIAA0372', 'TTC37'],
#  'KIAA0372': ['SKIC3', 'THES', 'SKI3', 'TTC37'],
#  'TTC37': ['SKIC3', 'THES', 'SKI3', 'KIAA0372'],
#  'REC14': ['SKIC8', 'SKI8', 'WDR61'],
#  'SKI8': ['SKIC8', 'REC14', 'WDR61'],
#  'WDR61': ['SKIC8', 'REC14', 'SKI8'],
#  'NHERF': ['NHERF1', 'EBP50', 'NHERF-1', 'NHE-RF', 'SLC9A3R1'],
#  'EBP50': ['NHERF1', 'NHERF', 'NHERF-1', 'NHE-RF', 'SLC9A3R1'],
#  'NHERF-1': ['NHERF1', 'NHERF', 'EBP50', 'NHE-RF', 'SLC9A3R1'],
#  'NHE-RF': ['NHERF1', 'NHERF', 'EBP50', 'NHERF-1', 'SLC9A3R1'],
#  'SLC9A3R1': ['NHERF1', 'NHERF', 'EBP50', 'NHERF-1', 'NHE-RF'],
#  'SIP-1': ['NHERF2', 'TKA-1', 'NHERF-2', 'E3KARP', 'OCTS2', 'SLC9A3R2'],
#  'TKA-1': ['NHERF2', 'SIP-1', 'NHERF-2', 'E3KARP', 'OCTS2', 'SLC9A3R2'],
#  'NHERF-2': ['NHERF2', 'SIP-1', 'TKA-1', 'E3KARP', 'OCTS2', 'SLC9A3R2'],
#  'E3KARP': ['NHERF2', 'SIP-1', 'TKA-1', 'NHERF-2', 'OCTS2', 'SLC9A3R2'],
#  'OCTS2': ['NHERF2', 'SIP-1', 'TKA-1', 'NHERF-2', 'E3KARP', 'SLC9A3R2'],
#  'SLC9A3R2': ['NHERF2', 'SIP-1', 'TKA-1', 'NHERF-2', 'E3KARP', 'OCTS2'],
#  'PRED56': ['SLX9', 'C21orf70', 'FAM207A'],
#  'C21orf70': ['SLX9', 'PRED56', 'FAM207A'],
#  'FAM207A': ['SLX9', 'PRED56', 'C21orf70'],
#  'C21orf51': ['SMIM11', 'FAM165B', 'SMIM11A'],
#  'FAM165B': ['SMIM11', 'C21orf51', 'SMIM11A'],
#  'SMIM11A': ['SMIM11', 'C21orf51', 'FAM165B'],
#  'SMIM34A': ['SMIM34'],
#  'dJ132F21.1': ['MTCL2', 'FLJ44670', 'SOGA', 'C20orf117', 'KIAA0889', 'SOGA1'],
#  'FLJ44670': ['MTCL2', 'dJ132F21.1', 'SOGA', 'C20orf117', 'KIAA0889', 'SOGA1'],
#  'SOGA': ['MTCL2', 'dJ132F21.1', 'FLJ44670', 'C20orf117', 'KIAA0889', 'SOGA1'],
#  'C20orf117': ['MTCL2', 'dJ132F21.1', 'FLJ44670', 'SOGA', 'KIAA0889', 'SOGA1'],
#  'KIAA0889': ['MTCL2', 'dJ132F21.1', 'FLJ44670', 'SOGA', 'C20orf117', 'SOGA1'],
#  'SOGA1': ['MTCL2', 'dJ132F21.1', 'FLJ44670', 'SOGA', 'C20orf117', 'KIAA0889'],
#  'IMAGE:4839025': ['SPACDR', 'C7orf61'],
#  'C7orf61': ['SPACDR', 'IMAGE:4839025'],
#  'C7orf72': ['SPMIP7', 'SPATA48'],
#  'SPATA48': ['SPMIP7', 'C7orf72'],
#  'SPAF': ['AFG2A', 'AFG2', 'SPATA5'],
#  'AFG2': ['AFG2A', 'SPAF', 'SPATA5'],
#  'SPATA5': ['AFG2A', 'SPAF', 'AFG2'],
#  'MGC5347': ['AFG2B', 'FLJ12286', 'SPATA5L1'],
#  'FLJ12286': ['AFG2B', 'MGC5347', 'SPATA5L1'],
#  'SPATA5L1': ['AFG2B', 'MGC5347', 'FLJ12286'],
#  'FLJ21415': ['SPRING1', 'SPRING', 'POST1', 'LUR1', 'C12orf49'],
#  'SPRING': ['SPRING1', 'FLJ21415', 'POST1', 'LUR1', 'C12orf49'],
#  'POST1': ['SPRING1', 'FLJ21415', 'SPRING', 'LUR1', 'C12orf49'],
#  'LUR1': ['SPRING1', 'FLJ21415', 'SPRING', 'POST1', 'C12orf49'],
#  'C12orf49': ['SPRING1', 'FLJ21415', 'SPRING', 'POST1', 'LUR1'],
#  'FLJ22965': ['STEEP1', 'CXorf56'],
#  'CXorf56': ['STEEP1', 'FLJ22965'],
#  'BTHS': ['TAFAZZIN', 'G4.5', 'TAZ1', 'CMD3A', 'EFE2', 'EFE', 'TAZ'],
#  'G4.5': ['TAFAZZIN', 'BTHS', 'TAZ1', 'CMD3A', 'EFE2', 'EFE', 'TAZ'],
#  'TAZ1': ['TAFAZZIN', 'BTHS', 'G4.5', 'CMD3A', 'EFE2', 'EFE', 'TAZ'],
#  'CMD3A': ['TAFAZZIN', 'BTHS', 'G4.5', 'TAZ1', 'EFE2', 'EFE', 'TAZ'],
#  'EFE2': ['TAFAZZIN', 'BTHS', 'G4.5', 'TAZ1', 'CMD3A', 'EFE', 'TAZ'],
#  'EFE': ['TAFAZZIN', 'BTHS', 'G4.5', 'TAZ1', 'CMD3A', 'EFE2', 'TAZ'],
#  'TAZ': ['TAFAZZIN', 'BTHS', 'G4.5', 'TAZ1', 'CMD3A', 'EFE2', 'EFE'],
#  'GRASP': ['TAMALIN'],
#  'FLJ11577': ['TASL', 'CXorf21'],
#  'CXorf21': ['TASL', 'FLJ11577'],
#  'CR': ['CRIPTO', 'Cripto-1', 'CR-1', 'TDGF1'],
#  'Cripto-1': ['CRIPTO', 'CR', 'CR-1', 'TDGF1'],
#  'CR-1': ['CRIPTO', 'CR', 'Cripto-1', 'TDGF1'],
#  'TDGF1': ['CRIPTO', 'CR', 'Cripto-1', 'CR-1'],
#  'LOC100128569': ['TEKTIP1', 'C19orf71'],
#  'C19orf71': ['TEKTIP1', 'LOC100128569'],
#  'TEPP': ['SPMIP8'],
#  'MGC35206': ['CIMIP4', 'EAN57', 'C22orf33', 'TEX33'],
#  'EAN57': ['CIMIP4', 'MGC35206', 'C22orf33', 'TEX33'],
#  'C22orf33': ['CIMIP4', 'MGC35206', 'EAN57', 'TEX33'],
#  'TEX33': ['CIMIP4', 'MGC35206', 'EAN57', 'C22orf33'],
#  'FLJ25369': ['SPMIP9', 'TSC21', 'C2orf51', 'TEX37'],
#  'TSC21': ['SPMIP9', 'FLJ25369', 'C2orf51', 'TEX37'],
#  'C2orf51': ['SPMIP9', 'FLJ25369', 'TSC21', 'TEX37'],
#  'TEX37': ['SPMIP9', 'FLJ25369', 'TSC21', 'C2orf51'],
#  'MGC163367': ['SPMIP10',
#   'MGC163369',
#   'FLJ27505',
#   'Tseg7',
#   'C5orf48',
#   'TEX43'],
#  'MGC163369': ['SPMIP10',
#   'MGC163367',
#   'FLJ27505',
#   'Tseg7',
#   'C5orf48',
#   'TEX43'],
#  'FLJ27505': ['SPMIP10',
#   'MGC163367',
#   'MGC163369',
#   'Tseg7',
#   'C5orf48',
#   'TEX43'],
#  'Tseg7': ['SPMIP10',
#   'MGC163367',
#   'MGC163369',
#   'FLJ27505',
#   'C5orf48',
#   'TEX43'],
#  'C5orf48': ['SPMIP10',
#   'MGC163367',
#   'MGC163369',
#   'FLJ27505',
#   'Tseg7',
#   'TEX43'],
#  'TEX43': ['SPMIP10',
#   'MGC163367',
#   'MGC163369',
#   'FLJ27505',
#   'Tseg7',
#   'C5orf48'],
#  'FLJ35784': ['SAXO5', 'C19orf45', 'TEX45'],
#  'C19orf45': ['SAXO5', 'FLJ35784', 'TEX45'],
#  'TEX45': ['SAXO5', 'FLJ35784', 'C19orf45'],
#  'LINC00935': ['SPMIP11', 'TEX49'],
#  'TEX49': ['SPMIP11', 'LINC00935'],
#  'CT56': ['SPMAP2', 'THEG1', 'THEG'],
#  'THEG1': ['SPMAP2', 'CT56', 'THEG'],
#  'THEG': ['SPMAP2', 'CT56', 'THEG1'],
#  'THEGL': ['SPMAP2L'],
#  'FLJ10925': ['TRAPPC14', 'C7orf43', 'MAP11'],
#  'C7orf43': ['TRAPPC14', 'FLJ10925', 'MAP11'],
#  'MAP11': ['TRAPPC14', 'FLJ10925', 'C7orf43'],
#  'FLJ12571': ['IFT56', 'dyf-13', 'DYF13', 'TTC26'],
#  'dyf-13': ['IFT56', 'FLJ12571', 'DYF13', 'TTC26'],
#  'DYF13': ['IFT56', 'FLJ12571', 'dyf-13', 'TTC26'],
#  'TTC26': ['IFT56', 'FLJ12571', 'dyf-13', 'DYF13'],
#  'FLJ13946': ['IFT70A', 'FAP259', 'CFAP259', 'TTC30A'],
#  'FAP259': ['IFT70A', 'FLJ13946', 'CFAP259', 'TTC30A'],
#  'CFAP259': ['IFT70A', 'FLJ13946', 'FAP259', 'TTC30A'],
#  'TTC30A': ['IFT70A', 'FLJ13946', 'FAP259', 'CFAP259'],
#  'FLJ30990': ['IFT70B', 'fleer', 'TTC30B'],
#  'fleer': ['IFT70B', 'FLJ30990', 'TTC30B'],
#  'TTC30B': ['IFT70B', 'FLJ30990', 'fleer'],
#  'gs103': ['UQCC4', 'CCSMST1', 'URLC5', 'C16orf91'],
#  'CCSMST1': ['UQCC4', 'gs103', 'URLC5', 'C16orf91'],
#  'URLC5': ['UQCC4', 'gs103', 'CCSMST1', 'C16orf91'],
#  'C16orf91': ['UQCC4', 'gs103', 'CCSMST1', 'URLC5'],
#  'C3orf78': ['UQCC5', 'SMIM4'],
#  'SMIM4': ['UQCC5', 'C3orf78'],
#  'FLJ13975': ['UQCC6', 'DKFZp547P055', 'BR', 'C12orf73'],
#  'DKFZp547P055': ['UQCC6', 'FLJ13975', 'BR', 'C12orf73'],
#  'BR': ['UQCC6', 'FLJ13975', 'DKFZp547P055', 'C12orf73'],
#  'C12orf73': ['UQCC6', 'FLJ13975', 'DKFZp547P055', 'BR'],
#  'MGC10471': ['YJU2B', 'CCDC130'],
#  'CCDC130': ['YJU2B', 'MGC10471'],
#  'Buster3': ['FAM200C', 'C5orf54', 'ZBED8'],
#  'C5orf54': ['FAM200C', 'Buster3', 'ZBED8'],
#  'ZBED8': ['FAM200C', 'Buster3', 'C5orf54'],
#  'MGC3032': ['ZFTA', 'C11orf95'],
#  'C11orf95': ['ZFTA', 'MGC3032'],
#  'CHRP': ['ZFTRAF1', 'KIAA0496', 'MGC13010', 'CYHR1'],
#  'KIAA0496': ['ZFTRAF1', 'CHRP', 'MGC13010', 'CYHR1'],
#  'MGC13010': ['ZFTRAF1', 'CHRP', 'KIAA0496', 'CYHR1'],
#  'CYHR1': ['ZFTRAF1', 'CHRP', 'KIAA0496', 'MGC13010'],
#  'CBWD1': ['ZNG1A'],
#  'CBWD2': ['ZNG1B']}

# %%
for gene in missing:
    aliases = missing_genes_mapping[gene]
    for a in aliases:
        if a in gene_alias_mapping:
            print(gene)
            print(a, gene_alias_mapping[a])
        if a in new:
            print(gene)
            print(a, new[a])
        print()
# Out:
# ABTB3
# BTBD11 []
#
#
# ACTMAP
# C19orf54 []
#
#
# ADGRD2
# GPR144 []
#
#
#
# ADPRS
# ADPRHL2 []
#
#
# ATOSA
# KIAA1370 []
#
# ATOSA
# FAM214A []
#
#
#
# ATOSB
# KIAA1539 []
#
# ATOSB
# FAM214B []
#
#
#
#
# ATP5MJ
# C14orf2 []
#
# ATP5MJ
# ATP5MPL []
#
#
#
#
#
# ATP5MK
# USMG5 []
#
# ATP5MK
# ATP5MD []
#
# SPMIP1
# ATP6V1FNB []
#
#
#
#
#
# BBLN
# C9orf16 []
#
#
#
#
#
# BLTP1
# KIAA1109 []
#
#
#
#
#
#
#
#
# BLTP2
# KIAA0100 []
#
#
#
#
# BLTP3A
# UHRF1BP1 []
#
#
#
# BLTP3B
# UHRF1BP1L []
#
# BMAL1
# MOP3 ['SBNO1', 'FLJ10701', 'FLJ10833', 'Sno']
#
#
#
#
#
# BMAL1
# ARNTL []
#
#
#
#
#
# BMAL2
# ARNTL2 []
#
#
#
#
# BPNT2
# IMPAD1 []
#
#
#
# BRME1
# C19orf57 []
#
#
#
# SPMIP5
# C10orf82 []
#
#
#
# TOP6BL
# C11orf80 []
#
#
# RLIG1
# C12orf29 []
#
#
# FERRY3
# C12orf4 []
#
#
# REDIC1
# C12orf40 []
#
#
#
#
#
# MTNAP1
# C17orf80 []
#
#
# LIAT1
# C17orf97 []
#
#
# SPMAP1
# C17orf98 []
#
#
#
#
#
# ARK2N
# C18orf25 []
#
# SPMIP3
# C1orf100 []
#
#
# AIRIM
# C1orf109 []
#
#
#
# FIRRM
# FLIP ['CFLAR', 'CASH', 'Casper', 'CLARP', 'FLAME', 'I-FLICE', 'MRIT', 'c-FLIP', 'cFLIP', 'CASP8AP1']
#
#
# FIRRM
# C1orf112 []
#
#
#
# KPLCE
# C1orf68 []
#
#
# ADISSP
# C20orf27 []
#
#
#
# CIMIP1
# C20orf85 []
#
# EPCIP
# B37 ['ATN1', 'D12S755E', 'DRPLA']
#
#
#
#
# EPCIP
# C21orf62 []
#
#
# CEP15
# C3orf14 []
#
#
# SPMIP2
# C4orf45 []
#
#
# CFAP96
# C4orf47 []
#
#
# NICOL1
# C4orf48 []
#
# SPMIP4
# C7orf31 []
#
#
# SPATA31G1
# C9orf131 []
#
#
#
#
#
#
#
# SPMIP6
# C9orf24 []
#
#
# QNG1
# C9orf64 []
#
#
# TEKTL1
# CCDC105 []
#
#
#
# CFAP263
# CCDC113 []
#
#
# DRC12
# CCDC153 []
#
#
# CFAP184
# CCDC96 []
#
#
# CCNP
# CNTD2 []
#
#
#
#
# CDIN1
# C15orf41 []
#
#
# CENATAC
# CCDC84 []
#
#
#
#
#
# CEP20
# C16orf63 []
#
# CEP20
# FOPNL []
#
# CEP43
# FOP ['CHTOP', 'DKFZP547E1010', 'SRAG', 'C1orf77']
#
# CEP43
# FGFR1OP []
#
#
# CFAP107
# C1orf158 []
#
#
# CFAP119
# C16orf93 []
#
# CFAP119
# CCDC189 []
#
# CFAP141
# C1orf189 []
#
#
#
# CFAP20DC
# C3orf67 []
#
#
# CFAP210
# C2orf77 []
#
# CFAP210
# CCDC173 []
#
#
#
# CFAP251
# WDR66 []
#
# CFAP276
# C1orf194 []
#
#
#
#
#
#
#
#
# CFAP418
# C8orf37 []
#
#
# CFAP68
# C11orf1 []
#
#
# CFAP90
# C5orf49 []
#
#
#
#
#
#
# CFAP91
# C3orf15 []
#
# CFAP91
# MAATS1 []
#
#
#
# CFAP92
# KIAA1257 []
#
# CFAP95
# C9orf135 []
#
# CHCT1
# C17orf64 []
#
#
#
# CIBAR1
# FAM92A1 []
#
# CIBAR1
# FAM92A []
#
#
# CIBAR2
# FAM92B []
#
# CIROP
# LMLN2 []
#
#
#
#
#
#
#
# CLXN
# EFCAB1 []
#
# CMKLR2
# GPR1 []
#
#
# CRACDL
# C2orf55 []
#
# CRACDL
# KIAA1211L []
#
#
#
# CSTPP1
# C11orf49 []
#
#
#
#
# CYRIA
# FAM49A []
#
#
#
#
# CYRIB
# FAM49B []
#
#
#
# DNAAF10
# WDR92 []
#
#
#
#
#
# DNAAF11
# LRRC6 []
#
#
#
#
# DNAAF6
# CXorf41 []
#
# DNAAF6
# PIH1D3 []
#
#
#
#
# DNAAF8
# C16orf71 []
#
#
# DNAAF9
# C20orf194 []
#
#
#
#
# DNAI3
# WDR63 []
#
#
#
# DNAI4
# WDR78 []
#
#
#
#
# DNAI7
# CASC1 []
#
#
#
#
# DUSP13B
# DUSP13 []
#
# DUSP29
# DUSP27 []
#
# DUSP29
# DUPD1 []
#
#
#
#
#
# DYNC2I1
# WDR60 []
#
#
#
#
#
#
# DYNC2I2
# WDR34 []
#
#
#
#
#
# DYNLT2
# TCTE3 []
#
#
# DYNLT2B
# TCTEX1D2 []
#
# DYNLT4
# TCTEX1D4 []
#
#
# DYNLT5
# TCTEX1D1 []
#
#
#
#
#
# EEIG1
# FAM102A []
#
#
#
# EEIG2
# FAM102B []
#
#
#
# ELAPOR1
# KIAA1324 []
#
#
#
# ELAPOR2
# KIAA1324L []
#
#
#
#
# ENTREP1
# FAM189A2 []
#
#
#
# ENTREP2
# FAM189A1 []
#
#
#
# ENTREP3
# FAM189B []
#
#
# EOLA1
# CXorf40A []
#
# EOLA2
# CXorf40B []
#
#
# VCF1
# FAM104A []
#
#
#
# VCF2
# FAM104B []
#
# CIMIP2A
# FAM166A []
#
# CIMIP2B
# FAM166B []
#
#
# CIMIP2C
# C2orf70 []
#
# CIMIP2C
# FAM166C []
#
#
#
#
# ARB2A
# FAM172A []
#
#
#
# CFAP144
# FAM183A []
#
# SPATA31F1
# C9orf144B []
#
# SPATA31F1
# FAM205A []
#
#
# SPATA31F3
# FAM205C []
#
# FBXW10B
# HREP ['FBXW10', 'SM2SH2', 'Fbw10', 'C17orf1', 'C17orf1A']
#
#
#
# FBXW10B
# CDRT1 []
#
#
#
# FHIP1A
# FAM160A1 []
#
#
#
#
#
#
# FHIP1B
# FAM160A2 []
#
#
#
# FHIP2A
# FAM160B1 []
#
#
#
# FHIP2B
# FAM160B2 []
#
#
# FREY1
# C11orf94 []
#
#
# G6PC1
# G6PT ['SLC37A4', 'GSD1b', 'GSD1c', 'GSD1d', 'SPX4', 'G6PT1', 'G6PT2', 'G6PT3']
#
# G6PC1
# G6PC []
#
#
#
# GARIN1A
# FAM71F2 []
#
#
#
#
# GARIN1B
# FAM71F1 []
#
#
#
# GARIN2
# FAM71D []
#
#
#
# GARIN3
# FAM71B []
#
#
#
# GARIN4
# FAM71A []
#
#
# GARIN5A
# FAM71E1 []
#
#
# GARIN6
# FAM71C []
#
#
# GARRE1
# KIAA0355 []
#
#
#
#
# GATD3
# HES1 ['FLJ20408', 'HES-1', 'bHLHb39', 'HRY']
#
#
#
#
#
# GATD3
# C21orf33 []
#
# GATD3
# GATD3A []
#
# GBA1
# GLUC ['GBA3', 'KLrP', 'CBGL1']
#
# GBA1
# GBA []
#
#
#
#
# GFUS
# TSTA3 []
#
#
#
# GOLM2
# CASC4 []
#
#
#
#
#
#
#
# GPR15LG
# C10orf99 []
#
#
#
# H2AC25
# HIST3H2A []
#
# H2AC25
# H2AW []
#
# H2BC26
# HIST3H2BB []
#
# H2BC26
# H2BU1 []
#
# H2BK1
# H2BE1 []
#
#
# H4C16
# HIST4H4 []
#
# H4C16
# H4-16 []
#
#
#
#
# HAPSTR1
# C16orf72 []
#
#
# HOATZ
# C11orf88 []
#
#
#
#
#
#
# IFT25
# HSPB11 []
#
#
#
#
# HYCC1
# FAM126A []
#
#
# HYCC2
# FAM126B []
#
#
#
#
# IFTAP
# C11orf74 []
#
#
#
#
# IHO1
# CCDC36 []
#
#
# INTS15
# C7orf26 []
#
#
#
# IQANK1
# FAM83H-AS1 []
#
#
#
# IRAG1
# MRVI1 []
#
#
# IRAG2
# LRMP []
#
#
# KASH5
# CCDC155 []
#
#
# KATNIP
# KIAA0556 []
#
# NHSL3
# KIAA1522 []
#
#
# KICS2
# C12orf66 []
#
# KRBOX5
# ZNF720 []
#
#
# LDAF1
# TMEM159 []
#
#
#
# CIMAP2
# C1orf177 []
#
# CIMAP2
# LEXM []
#
#
# LHFPL7
# TMEM211 []
#
# LORICRIN
# LOR []
# LORICRIN
# LOR ['LOXL2', 'WS9-14']
#
#
#
# LYSET
# C14orf109 []
#
# LYSET
# TMEM251 []
#
#
# MACIR
# C5orf30 []
#
#
#
# MATCAP1
# KIAA0895L []
#
#
# MATCAP2
# KIAA0895 []
#
#
# MEIOSIN
# BHMG1 []
#
#
# METTL25B
# C1orf66 []
#
# METTL25B
# RRNAD1 []
#
#
# TMT1A
# METTL7A []
#
#
#
# TMT1B
# METTL7B []
#
#
#
# MIDEAS
# C14orf43 []
#
# MIDEAS
# ELMSAN1 []
#
#
#
# MISFA
# SPTY2D1-AS1 []
#
# MISFA
# SPTY2D1OS []
#
#
# MIX23
# CCDC58 []
#
#
#
# KGD4
# MRPS36 []
#
#
#
#
#
# MTRFR
# C12orf65 []
#
#
#
# MYG1
# C12orf10 []
#
# MYL11
# MRLC2 ['MYL12B']
#
#
# MYL11
# MYLPF []
#
#
# NALF1
# FAM155A []
#
#
#
#
# NALF2
# FAM155B []
#
#
#
#
# NOPCHAP1
# C12orf45 []
#
#
#
# NTAQ1
# WDYHV1 []
#
#
#
# NTMT2
# METTL11B []
#
#
#
# ODAD1
# CCDC114 []
#
#
#
#
#
#
# ODAD2
# ARMC4 []
#
#
#
# ODAD3
# CCDC151 []
#
#
# ODAD4
# TTC25 []
#
#
#
#
# CIMAP1A
# ODF3 []
#
#
# CIMAP1B
# ODF3B []
#
#
# CIMAP1C
# ODF3L1 []
#
#
#
# CIMAP1D
# ODF3L2 []
#
#
#
# PABIR1
# FAM122A []
#
#
#
#
# PABIR2
# FAM122B []
#
#
# PABIR3
# FAM122C []
#
#
# PALS1
# MPP5 []
#
#
#
# PALS2
# MPP6 []
# PALS2
# MPP6 ['MPHOSPH6']
#
#
#
#
#
# NHERF4
# PDZD3 []
#
#
# PEDS1
# TMEM189 []
#
#
#
#
#
#
# PHAF1
# C16orf70 []
#
#
# PHB1
# PHB []
#
#
#
# PIERCE1
# C9orf116 []
#
#
# PIERCE2
# C15orf65 []
#
#
#
# CIMAP3
# C1orf88 []
#
# CIMAP3
# PIFO []
#
#
#
# POLR1F
# TWISTNB []
#
#
# POLR1G
# CAST ['MIR583HG']
# POLR1G
# CAST ['ERC2', 'CAST1', 'KIAA0378', 'SPBC110', 'Spc110', 'ELKSL']
#
#
#
#
# POLR1G
# CD3EAP []
#
#
#
#
#
#
# POLR1H
# ZNRD1 []
#
#
#
# POU2AF2
# C11orf53 []
#
#
#
# POU2AF3
# C11orf93 []
#
# POU2AF3
# COLCA2 []
#
#
#
# SAXO4
# C11orf66 []
#
# SAXO4
# PPP1R32 []
#
#
#
#
#
# PRP4K
# PRPF4B []
#
#
#
# PTGR3
# ZADH2 []
#
#
#
#
#
# RIGI
# RIG1 ['PLAAT4', 'TIG3', 'HRASLS4', 'PLAAT-4', 'RARRES3']
#
# RIGI
# DDX58 []
#
#
# RIMOC1
# C5orf51 []
#
#
#
#
#
# ARK2C
# RNF165 []
#
#
# RUSF1
# C16orf58 []
#
# SANBR
# KIAA1841 []
#
# SKIC2
# HLP ['HAP1', 'hHLP1', 'HIP5', 'HAP2']
#
#
#
#
#
#
#
# SKIC2
# SKIV2L []
#
#
#
#
# SKIC3
# TTC37 []
#
#
#
# SKIC8
# WDR61 []
#
#
#
#
#
# NHERF1
# SLC9A3R1 []
#
# NHERF2
# SIP-1 ['ZEB2', 'KIAA0569', 'SIP1', 'ZFHX1B']
#
#
#
#
#
# NHERF2
# SLC9A3R2 []
#
#
# SLX9
# C21orf70 []
#
# SLX9
# FAM207A []
#
#
# SMIM11
# FAM165B []
#
# SMIM11
# SMIM11A []
#
# SMIM34
# SMIM34A []
#
#
#
#
# MTCL2
# C20orf117 []
#
#
# MTCL2
# SOGA1 []
#
#
# SPACDR
# C7orf61 []
#
# SPMIP7
# C7orf72 []
#
# SPMIP7
# SPATA48 []
#
#
#
# AFG2A
# SPATA5 []
#
#
#
# AFG2B
# SPATA5L1 []
#
#
# SPRING1
# SPRING ['TRIM9', 'RNF91']
#
#
#
# SPRING1
# C12orf49 []
#
#
# STEEP1
# CXorf56 []
#
# STYXL2
# DUSP27 []
#
#
#
#
#
#
#
# TAFAZZIN
# TAZ []
# TAFAZZIN
# TAZ ['WWTR1', 'DKFZp586I1419']
#
# TAMALIN
# GRASP []
#
#
# TASL
# CXorf21 []
#
# CRIPTO
# CR ['EDARADD']
#
#
#
# CRIPTO
# TDGF1 []
#
#
# TEKTIP1
# C19orf71 []
#
# SPMIP8
# TEPP []
#
#
#
# CIMIP4
# C22orf33 []
#
# CIMIP4
# TEX33 []
#
#
#
# SPMIP9
# C2orf51 []
#
# SPMIP9
# TEX37 []
#
#
#
#
#
# SPMIP10
# C5orf48 []
#
# SPMIP10
# TEX43 []
#
#
# SAXO5
# C19orf45 []
#
# SAXO5
# TEX45 []
#
# SPMIP11
# LINC00935 []
#
# SPMIP11
# TEX49 []
#
#
#
# SPMAP2
# THEG []
#
# SPMAP2L
# THEGL []
#
#
# TRAPPC14
# C7orf43 []
#
# TRAPPC14
# MAP11 []
#
#
#
#
# IFT56
# TTC26 []
#
#
#
#
# IFT70A
# TTC30A []
#
#
#
# IFT70B
# TTC30B []
#
#
#
#
# UQCC4
# C16orf91 []
#
# UQCC5
# C3orf78 []
#
# UQCC5
# SMIM4 []
#
#
#
#
# UQCC6
# C12orf73 []
#
#
# YJU2B
# CCDC130 []
#
#
# FAM200C
# C5orf54 []
#
# FAM200C
# ZBED8 []
#
#
# ZFTA
# C11orf95 []
#
#
#
#
# ZFTRAF1
# CYHR1 []
#
# ZNG1A
# CBWD1 []
#
# ZNG1B
# CBWD2 []

# %%
mapper = {}

# %%
for g in depmap_genes:
    if g in gene_alias_mapping:
        mapper[g] = g
    elif g in new:
        mapper[g] = new[g][0]
    elif g in missing_genes_mapping:
        aliases = missing_genes_mapping[g]
        for a in aliases:
            if a in gene_alias_mapping:
                mapper[g] = a
            if a in new:
                mapper[g] = new[a][0]

# %%
mapper
# Out:
# {'A1BG': 'A1BG',
#  'A1CF': 'A1CF',
#  'A2M': 'A2M',
#  'A2ML1': 'A2ML1',
#  'A3GALT2': 'A3GALT2',
#  'A4GALT': 'A4GALT',
#  'A4GNT': 'A4GNT',
#  'AAAS': 'AAAS',
#  'AACS': 'AACS',
#  'AADAC': 'AADAC',
#  'AADACL2': 'AADACL2',
#  'AADACL3': 'AADACL3',
#  'AADACL4': 'AADACL4',
#  'AADAT': 'AADAT',
#  'AAGAB': 'AAGAB',
#  'AAK1': 'AAK1',
#  'AAMDC': 'AAMDC',
#  'AAMP': 'AAMP',
#  'AANAT': 'AANAT',
#  'AAR2': 'AAR2',
#  'AARD': 'AARD',
#  'AARS1': 'AARS1',
#  'AARS2': 'AARS2',
#  'AARSD1': 'AARSD1',
#  'AASDH': 'AASDH',
#  'AASDHPPT': 'AASDHPPT',
#  'AASS': 'AASS',
#  'AATF': 'AATF',
#  'AATK': 'AATK',
#  'ABAT': 'ABAT',
#  'ABCA1': 'ABCA1',
#  'ABCA10': 'ABCA10',
#  'ABCA12': 'ABCA12',
#  'ABCA13': 'ABCA13',
#  'ABCA2': 'ABCA2',
#  'ABCA3': 'ABCA3',
#  'ABCA4': 'ABCA4',
#  'ABCA5': 'ABCA5',
#  'ABCA6': 'ABCA6',
#  'ABCA7': 'ABCA7',
#  'ABCA8': 'ABCA8',
#  'ABCA9': 'ABCA9',
#  'ABCB1': 'ABCB1',
#  'ABCB10': 'ABCB10',
#  'ABCB11': 'ABCB11',
#  'ABCB4': 'ABCB4',
#  'ABCB5': 'ABCB5',
#  'ABCB6': 'ABCB6',
#  'ABCB7': 'ABCB7',
#  'ABCB8': 'ABCB8',
#  'ABCB9': 'ABCB9',
#  'ABCC1': 'ABCC1',
#  'ABCC10': 'ABCC10',
#  'ABCC11': 'ABCC11',
#  'ABCC12': 'ABCC12',
#  'ABCC2': 'ABCC2',
#  'ABCC3': 'ABCC3',
#  'ABCC4': 'ABCC4',
#  'ABCC5': 'ABCC5',
#  'ABCC6': 'ABCC6',
#  'ABCC8': 'ABCC8',
#  'ABCC9': 'ABCC9',
#  'ABCD1': 'ABCD1',
#  'ABCD2': 'ABCD2',
#  'ABCD3': 'ABCD3',
#  'ABCD4': 'ABCD4',
#  'ABCE1': 'ABCE1',
#  'ABCF1': 'ABCF1',
#  'ABCF3': 'ABCF3',
#  'ABCG1': 'ABCG1',
#  'ABCG2': 'ABCG2',
#  'ABCG4': 'ABCG4',
#  'ABCG5': 'ABCG5',
#  'ABCG8': 'ABCG8',
#  'ABHD1': 'ABHD1',
#  'ABHD10': 'ABHD10',
#  'ABHD11': 'ABHD11',
#  'ABHD12': 'ABHD12',
#  'ABHD12B': 'ABHD12B',
#  'ABHD13': 'ABHD13',
#  'ABHD14A': 'ABHD14A',
#  'ABHD14B': 'ABHD14B',
#  'ABHD15': 'ABHD15',
#  'ABHD16A': 'ABHD16A',
#  'ABHD16B': 'ABHD16B',
#  'ABHD17A': 'ABHD17A',
#  'ABHD17B': 'ABHD17B',
#  'ABHD17C': 'ABHD17C',
#  'ABHD18': 'ABHD18',
#  'ABHD2': 'ABHD2',
#  'ABHD3': 'ABHD3',
#  'ABHD4': 'ABHD4',
#  'ABHD5': 'ABHD5',
#  'ABHD6': 'ABHD6',
#  'ABHD8': 'ABHD8',
#  'ABI1': 'ABI1',
#  'ABI2': 'ABI2',
#  'ABI3': 'ABI3',
#  'ABI3BP': 'ABI3BP',
#  'ABITRAM': 'ABITRAM',
#  'ABL1': 'ABL1',
#  'ABL2': 'ABL2',
#  'ABLIM1': 'ABLIM1',
#  'ABLIM2': 'ABLIM2',
#  'ABLIM3': 'ABLIM3',
#  'ABR': 'ABR',
#  'ABRA': 'ABRA',
#  'ABRACL': 'ABRACL',
#  'ABRAXAS1': 'ABRAXAS1',
#  'ABRAXAS2': 'ABRAXAS2',
#  'ABT1': 'ABT1',
#  'ABTB1': 'ABTB1',
#  'ABTB2': 'ABTB2',
#  'ABTB3': 'BTBD11',
#  'ACAA1': 'ACAA1',
#  'ACAA2': 'ACAA2',
#  'ACACA': 'ACACA',
#  'ACACB': 'ACACB',
#  'ACAD10': 'ACAD10',
#  'ACAD11': 'ACAD11',
#  'ACAD8': 'ACAD8',
#  'ACAD9': 'ACAD9',
#  'ACADL': 'ACADL',
#  'ACADM': 'ACADM',
#  'ACADS': 'ACADS',
#  'ACADSB': 'ACADSB',
#  'ACADVL': 'ACADVL',
#  'ACAN': 'ACAN',
#  'ACAP1': 'ACAP1',
#  'ACAP2': 'ACAP2',
#  'ACAP3': 'ACAP3',
#  'ACAT1': 'ACAT1',
#  'ACAT2': 'ACAT2',
#  'ACBD3': 'ACBD3',
#  'ACBD4': 'ACBD4',
#  'ACBD5': 'ACBD5',
#  'ACBD6': 'ACBD6',
#  'ACBD7': 'ACBD7',
#  'ACCS': 'ACCS',
#  'ACCSL': 'ACCSL',
#  'ACD': 'ACD',
#  'ACE': 'ACE',
#  'ACE2': 'ACE2',
#  'ACER1': 'ACER1',
#  'ACER2': 'ACER2',
#  'ACER3': 'ACER3',
#  'ACHE': 'ACHE',
#  'ACIN1': 'ACIN1',
#  'ACKR1': 'ACKR1',
#  'ACKR2': 'ACKR2',
#  'ACKR3': 'ACKR3',
#  'ACKR4': 'ACKR4',
#  'ACLY': 'ACLY',
#  'ACMSD': 'ACMSD',
#  'ACO1': 'ACO1',
#  'ACO2': 'ACO2',
#  'ACOD1': 'ACOD1',
#  'ACOT1': 'ACOT1',
#  'ACOT11': 'ACOT11',
#  'ACOT12': 'ACOT12',
#  'ACOT13': 'ACOT13',
#  'ACOT2': 'ACOT2',
#  'ACOT4': 'ACOT4',
#  'ACOT6': 'ACOT6',
#  'ACOT7': 'ACOT7',
#  'ACOT8': 'ACOT8',
#  'ACOT9': 'ACOT9',
#  'ACOX1': 'ACOX1',
#  'ACOX2': 'ACOX2',
#  'ACOX3': 'ACOX3',
#  'ACOXL': 'ACOXL',
#  'ACP1': 'ACP1',
#  'ACP2': 'ACP2',
#  'ACP3': 'ACP3',
#  'ACP4': 'ACP4',
#  'ACP5': 'ACP5',
#  'ACP6': 'ACP6',
#  'ACP7': 'ACP7',
#  'ACR': 'ACR',
#  'ACRBP': 'ACRBP',
#  'ACRV1': 'ACRV1',
#  'ACSBG1': 'ACSBG1',
#  'ACSBG2': 'ACSBG2',
#  'ACSF2': 'ACSF2',
#  'ACSF3': 'ACSF3',
#  'ACSL1': 'ACSL1',
#  'ACSL3': 'ACSL3',
#  'ACSL4': 'ACSL4',
#  'ACSL5': 'ACSL5',
#  'ACSL6': 'ACSL6',
#  'ACSM1': 'ACSM1',
#  'ACSM2A': 'ACSM2A',
#  'ACSM2B': 'ACSM2B',
#  'ACSM3': 'ACSM3',
#  'ACSM4': 'ACSM4',
#  'ACSM5': 'ACSM5',
#  'ACSM6': 'ACSM6',
#  'ACSS1': 'ACSS1',
#  'ACSS2': 'ACSS2',
#  'ACSS3': 'ACSS3',
#  'ACTA1': 'ACTA1',
#  'ACTA2': 'ACTA2',
#  'ACTB': 'ACTB',
#  'ACTBL2': 'ACTBL2',
#  'ACTC1': 'ACTC1',
#  'ACTG1': 'ACTG1',
#  'ACTG2': 'ACTG2',
#  'ACTL10': 'ACTL10',
#  'ACTL6A': 'ACTL6A',
#  'ACTL6B': 'ACTL6B',
#  'ACTL7A': 'ACTL7A',
#  'ACTL7B': 'ACTL7B',
#  'ACTL8': 'ACTL8',
#  'ACTL9': 'ACTL9',
#  'ACTMAP': 'C19orf54',
#  'ACTN1': 'ACTN1',
#  'ACTN2': 'ACTN2',
#  'ACTN3': 'ACTN3',
#  'ACTN4': 'ACTN4',
#  'ACTR10': 'ACTR10',
#  'ACTR1A': 'ACTR1A',
#  'ACTR1B': 'ACTR1B',
#  'ACTR2': 'ACTR2',
#  'ACTR3': 'ACTR3',
#  'ACTR3B': 'ACTR3B',
#  'ACTR3C': 'ACTR3C',
#  'ACTR5': 'ACTR5',
#  'ACTR6': 'ACTR6',
#  'ACTR8': 'ACTR8',
#  'ACTRT1': 'ACTRT1',
#  'ACTRT2': 'ACTRT2',
#  'ACTRT3': 'ACTRT3',
#  'ACVR1': 'ACVR1',
#  'ACVR1B': 'ACVR1B',
#  'ACVR1C': 'ACVR1C',
#  'ACVR2A': 'ACVR2A',
#  'ACVR2B': 'ACVR2B',
#  'ACVRL1': 'ACVRL1',
#  'ACY1': 'ACY1',
#  'ACY3': 'ACY3',
#  'ACYP1': 'ACYP1',
#  'ACYP2': 'ACYP2',
#  'ADA': 'ADA',
#  'ADA2': 'ADA2',
#  'ADAD1': 'ADAD1',
#  'ADAD2': 'ADAD2',
#  'ADAL': 'ADAL',
#  'ADAM10': 'ADAM10',
#  'ADAM11': 'ADAM11',
#  'ADAM12': 'ADAM12',
#  'ADAM15': 'ADAM15',
#  'ADAM17': 'ADAM17',
#  'ADAM18': 'ADAM18',
#  'ADAM19': 'ADAM19',
#  'ADAM2': 'ADAM2',
#  'ADAM20': 'ADAM20',
#  'ADAM21': 'ADAM21',
#  'ADAM22': 'ADAM22',
#  'ADAM23': 'ADAM23',
#  'ADAM28': 'ADAM28',
#  'ADAM29': 'ADAM29',
#  'ADAM30': 'ADAM30',
#  'ADAM32': 'ADAM32',
#  'ADAM33': 'ADAM33',
#  'ADAM7': 'ADAM7',
#  'ADAM8': 'ADAM8',
#  'ADAM9': 'ADAM9',
#  'ADAMDEC1': 'ADAMDEC1',
#  'ADAMTS1': 'ADAMTS1',
#  'ADAMTS10': 'ADAMTS10',
#  'ADAMTS12': 'ADAMTS12',
#  'ADAMTS13': 'ADAMTS13',
#  'ADAMTS14': 'ADAMTS14',
#  'ADAMTS15': 'ADAMTS15',
#  'ADAMTS16': 'ADAMTS16',
#  'ADAMTS17': 'ADAMTS17',
#  'ADAMTS18': 'ADAMTS18',
#  'ADAMTS19': 'ADAMTS19',
#  'ADAMTS2': 'ADAMTS2',
#  'ADAMTS20': 'ADAMTS20',
#  'ADAMTS3': 'ADAMTS3',
#  'ADAMTS4': 'ADAMTS4',
#  'ADAMTS5': 'ADAMTS5',
#  'ADAMTS6': 'ADAMTS6',
#  'ADAMTS7': 'ADAMTS7',
#  'ADAMTS8': 'ADAMTS8',
#  'ADAMTS9': 'ADAMTS9',
#  'ADAMTSL1': 'ADAMTSL1',
#  'ADAMTSL2': 'ADAMTSL2',
#  'ADAMTSL3': 'ADAMTSL3',
#  'ADAMTSL4': 'ADAMTSL4',
#  'ADAMTSL5': 'ADAMTSL5',
#  'ADAP1': 'ADAP1',
#  'ADAP2': 'ADAP2',
#  'ADAR': 'ADAR',
#  'ADARB1': 'ADARB1',
#  'ADARB2': 'ADARB2',
#  'ADAT1': 'ADAT1',
#  'ADAT2': 'ADAT2',
#  'ADAT3': 'ADAT3',
#  'ADCK1': 'ADCK1',
#  'ADCK2': 'ADCK2',
#  'ADCK5': 'ADCK5',
#  'ADCY1': 'ADCY1',
#  'ADCY10': 'ADCY10',
#  'ADCY2': 'ADCY2',
#  'ADCY3': 'ADCY3',
#  'ADCY4': 'ADCY4',
#  'ADCY5': 'ADCY5',
#  'ADCY6': 'ADCY6',
#  'ADCY7': 'ADCY7',
#  'ADCY8': 'ADCY8',
#  'ADCY9': 'ADCY9',
#  'ADCYAP1': 'ADCYAP1',
#  'ADCYAP1R1': 'ADCYAP1R1',
#  'ADD1': 'ADD1',
#  'ADD2': 'ADD2',
#  'ADD3': 'ADD3',
#  'ADGRA1': 'ADGRA1',
#  'ADGRA2': 'ADGRA2',
#  'ADGRA3': 'ADGRA3',
#  'ADGRB1': 'ADGRB1',
#  'ADGRB2': 'ADGRB2',
#  'ADGRB3': 'ADGRB3',
#  'ADGRD1': 'ADGRD1',
#  'ADGRD2': 'GPR144',
#  'ADGRE1': 'ADGRE1',
#  'ADGRE2': 'ADGRE2',
#  'ADGRE3': 'ADGRE3',
#  'ADGRE5': 'ADGRE5',
#  'ADGRF1': 'ADGRF1',
#  'ADGRF3': 'ADGRF3',
#  'ADGRF4': 'ADGRF4',
#  'ADGRF5': 'ADGRF5',
#  'ADGRG1': 'ADGRG1',
#  'ADGRG2': 'ADGRG2',
#  'ADGRG3': 'ADGRG3',
#  'ADGRG4': 'ADGRG4',
#  'ADGRG5': 'ADGRG5',
#  'ADGRG6': 'ADGRG6',
#  'ADGRG7': 'ADGRG7',
#  'ADGRL1': 'ADGRL1',
#  'ADGRL2': 'ADGRL2',
#  'ADGRL3': 'ADGRL3',
#  'ADGRL4': 'ADGRL4',
#  'ADGRV1': 'ADGRV1',
#  'ADH1A': 'ADH1A',
#  'ADH1B': 'ADH1B',
#  'ADH1C': 'ADH1C',
#  'ADH4': 'ADH4',
#  'ADH5': 'ADH5',
#  'ADH6': 'ADH6',
#  'ADH7': 'ADH7',
#  'ADHFE1': 'ADHFE1',
#  'ADI1': 'ADI1',
#  'ADIG': 'ADIG',
#  'ADIPOQ': 'ADIPOQ',
#  'ADIPOR1': 'ADIPOR1',
#  'ADIPOR2': 'ADIPOR2',
#  'ADIRF': 'ADIRF',
#  'ADK': 'ADK',
#  'ADM': 'ADM',
#  'ADM2': 'ADM2',
#  'ADM5': 'ADM5',
#  'ADNP': 'ADNP',
#  'ADNP2': 'ADNP2',
#  'ADO': 'ADO',
#  'ADORA1': 'ADORA1',
#  'ADORA2A': 'ADORA2A',
#  'ADORA2B': 'ADORA2B',
#  'ADORA3': 'ADORA3',
#  'ADPGK': 'ADPGK',
#  'ADPRH': 'ADPRH',
#  'ADPRHL1': 'ADPRHL1',
#  'ADPRM': 'ADPRM',
#  'ADPRS': 'ADPRHL2',
#  'ADRA1A': 'ADRA1A',
#  'ADRA1B': 'ADRA1B',
#  'ADRA1D': 'ADRA1D',
#  'ADRA2A': 'ADRA2A',
#  'ADRA2B': 'ADRA2B',
#  'ADRA2C': 'ADRA2C',
#  'ADRB1': 'ADRB1',
#  'ADRB2': 'ADRB2',
#  'ADRB3': 'ADRB3',
#  'ADRM1': 'ADRM1',
#  'ADSL': 'ADSL',
#  'ADSS1': 'ADSS1',
#  'ADSS2': 'ADSS2',
#  'ADTRP': 'ADTRP',
#  'AEBP1': 'AEBP1',
#  'AEBP2': 'AEBP2',
#  'AEN': 'AEN',
#  'AFAP1': 'AFAP1',
#  'AFAP1L1': 'AFAP1L1',
#  'AFAP1L2': 'AFAP1L2',
#  'AFDN': 'AFDN',
#  'AFF1': 'AFF1',
#  'AFF2': 'AFF2',
#  'AFF3': 'AFF3',
#  'AFF4': 'AFF4',
#  'AFG1L': 'AFG1L',
#  'AFG3L2': 'AFG3L2',
#  'AFM': 'AFM',
#  'AFMID': 'AFMID',
#  'AFP': 'AFP',
#  'AFTPH': 'AFTPH',
#  'AGA': 'AGA',
#  'AGAP1': 'AGAP1',
#  'AGAP2': 'AGAP2',
#  'AGAP3': 'AGAP3',
#  'AGAP5': 'AGAP5',
#  'AGAP6': 'AGAP6',
#  'AGAP9': 'AGAP9',
#  'AGBL1': 'AGBL1',
#  'AGBL2': 'AGBL2',
#  'AGBL3': 'AGBL3',
#  'AGBL4': 'AGBL4',
#  'AGBL5': 'AGBL5',
#  'AGER': 'AGER',
#  'AGFG1': 'AGFG1',
#  'AGFG2': 'AGFG2',
#  'AGGF1': 'AGGF1',
#  'AGK': 'AGK',
#  'AGL': 'AGL',
#  'AGMAT': 'AGMAT',
#  'AGMO': 'AGMO',
#  'AGO1': 'AGO1',
#  'AGO2': 'AGO2',
#  'AGO3': 'AGO3',
#  'AGO4': 'AGO4',
#  'AGPAT1': 'AGPAT1',
#  'AGPAT2': 'AGPAT2',
#  'AGPAT3': 'AGPAT3',
#  'AGPAT4': 'AGPAT4',
#  'AGPAT5': 'AGPAT5',
#  'AGPS': 'AGPS',
#  'AGR2': 'AGR2',
#  'AGR3': 'AGR3',
#  'AGRN': 'AGRN',
#  'AGRP': 'AGRP',
#  'AGT': 'AGT',
#  'AGTPBP1': 'AGTPBP1',
#  'AGTR1': 'AGTR1',
#  'AGTR2': 'AGTR2',
#  'AGTRAP': 'AGTRAP',
#  'AGXT': 'AGXT',
#  'AGXT2': 'AGXT2',
#  'AHCTF1': 'AHCTF1',
#  'AHCY': 'AHCY',
#  'AHCYL1': 'AHCYL1',
#  'AHCYL2': 'AHCYL2',
#  'AHDC1': 'AHDC1',
#  'AHI1': 'AHI1',
#  'AHNAK': 'AHNAK',
#  'AHNAK2': 'AHNAK2',
#  'AHR': 'AHR',
#  'AHRR': 'AHRR',
#  'AHSA1': 'AHSA1',
#  'AHSG': 'AHSG',
#  'AHSP': 'AHSP',
#  'AICDA': 'AICDA',
#  'AIDA': 'AIDA',
#  'AIF1': 'AIF1',
#  'AIF1L': 'AIF1L',
#  'AIFM1': 'AIFM1',
#  'AIFM2': 'AIFM2',
#  'AIFM3': 'AIFM3',
#  'AIG1': 'AIG1',
#  'AIM2': 'AIM2',
#  'AIMP1': 'AIMP1',
#  'AIMP2': 'AIMP2',
#  'AIP': 'AIP',
#  'AIPL1': 'AIPL1',
#  'AIRE': 'AIRE',
#  'AJAP1': 'AJAP1',
#  'AJM1': 'AJM1',
#  'AJUBA': 'AJUBA',
#  'AK1': 'AK1',
#  'AK2': 'AK2',
#  'AK3': 'AK3',
#  'AK4': 'AK4',
#  'AK5': 'AK5',
#  'AK6': 'AK6',
#  'AK7': 'AK7',
#  'AK8': 'AK8',
#  'AK9': 'AK9',
#  'AKAIN1': 'AKAIN1',
#  'AKAP1': 'AKAP1',
#  'AKAP10': 'AKAP10',
#  'AKAP11': 'AKAP11',
#  'AKAP12': 'AKAP12',
#  'AKAP13': 'AKAP13',
#  'AKAP14': 'AKAP14',
#  'AKAP17A': 'AKAP17A',
#  'AKAP3': 'AKAP3',
#  'AKAP4': 'AKAP4',
#  'AKAP5': 'AKAP5',
#  'AKAP6': 'AKAP6',
#  'AKAP7': 'AKAP7',
#  'AKAP8': 'AKAP8',
#  'AKAP8L': 'AKAP8L',
#  'AKAP9': 'AKAP9',
#  'AKIP1': 'AKIP1',
#  'AKIRIN1': 'AKIRIN1',
#  'AKIRIN2': 'AKIRIN2',
#  'AKNA': 'AKNA',
#  'AKNAD1': 'AKNAD1',
#  'AKR1A1': 'AKR1A1',
#  'AKR1B1': 'AKR1B1',
#  'AKR1B10': 'AKR1B10',
#  'AKR1B15': 'AKR1B15',
#  'AKR1C2': 'AKR1C2',
#  'AKR1C3': 'AKR1C3',
#  'AKR1C4': 'AKR1C4',
#  'AKR1D1': 'AKR1D1',
#  'AKR1E2': 'AKR1E2',
#  'AKR7A2': 'AKR7A2',
#  'AKR7A3': 'AKR7A3',
#  'AKT1': 'AKT1',
#  'AKT1S1': 'AKT1S1',
#  'AKT2': 'AKT2',
#  'AKT3': 'AKT3',
#  'AKTIP': 'AKTIP',
#  'ALAD': 'ALAD',
#  'ALAS1': 'ALAS1',
#  'ALAS2': 'ALAS2',
#  'ALB': 'ALB',
#  'ALCAM': 'ALCAM',
#  'ALDH16A1': 'ALDH16A1',
#  'ALDH18A1': 'ALDH18A1',
#  'ALDH1A1': 'ALDH1A1',
#  'ALDH1A2': 'ALDH1A2',
#  'ALDH1A3': 'ALDH1A3',
#  'ALDH1B1': 'ALDH1B1',
#  'ALDH1L1': 'ALDH1L1',
#  'ALDH1L2': 'ALDH1L2',
#  'ALDH2': 'ALDH2',
#  'ALDH3A1': 'ALDH3A1',
#  'ALDH3A2': 'ALDH3A2',
#  'ALDH3B1': 'ALDH3B1',
#  'ALDH3B2': 'ALDH3B2',
#  'ALDH4A1': 'ALDH4A1',
#  'ALDH5A1': 'ALDH5A1',
#  'ALDH6A1': 'ALDH6A1',
#  'ALDH7A1': 'ALDH7A1',
#  'ALDH8A1': 'ALDH8A1',
#  'ALDH9A1': 'ALDH9A1',
#  'ALDOA': 'ALDOA',
#  'ALDOB': 'ALDOB',
#  'ALDOC': 'ALDOC',
#  'ALG1': 'ALG1',
#  'ALG10': 'ALG10',
#  'ALG10B': 'ALG10B',
#  'ALG11': 'ALG11',
#  'ALG12': 'ALG12',
#  'ALG13': 'ALG13',
#  'ALG14': 'ALG14',
#  'ALG2': 'ALG2',
#  'ALG3': 'ALG3',
#  'ALG5': 'ALG5',
#  'ALG6': 'ALG6',
#  'ALG8': 'ALG8',
#  'ALG9': 'ALG9',
#  'ALK': 'ALK',
#  'ALKAL1': 'ALKAL1',
#  'ALKAL2': 'ALKAL2',
#  'ALKBH1': 'ALKBH1',
#  'ALKBH2': 'ALKBH2',
#  'ALKBH3': 'ALKBH3',
#  'ALKBH4': 'ALKBH4',
#  'ALKBH5': 'ALKBH5',
#  'ALKBH6': 'ALKBH6',
#  'ALKBH7': 'ALKBH7',
#  'ALKBH8': 'ALKBH8',
#  'ALLC': 'ALLC',
#  'ALMS1': 'ALMS1',
#  'ALOX12': 'ALOX12',
#  'ALOX12B': 'ALOX12B',
#  'ALOX15': 'ALOX15',
#  'ALOX15B': 'ALOX15B',
#  'ALOX5': 'ALOX5',
#  'ALOX5AP': 'ALOX5AP',
#  'ALOXE3': 'ALOXE3',
#  'ALPG': 'ALPG',
#  'ALPI': 'ALPI',
#  'ALPK1': 'ALPK1',
#  'ALPK2': 'ALPK2',
#  'ALPK3': 'ALPK3',
#  'ALPL': 'ALPL',
#  'ALPP': 'ALPP',
#  'ALS2': 'ALS2',
#  'ALS2CL': 'ALS2CL',
#  'ALX1': 'ALX1',
#  'ALX3': 'ALX3',
#  'ALX4': 'ALX4',
#  'ALYREF': 'ALYREF',
#  'AMACR': 'AMACR',
#  'AMBN': 'AMBN',
#  'AMBP': 'AMBP',
#  'AMBRA1': 'AMBRA1',
#  'AMD1': 'AMD1',
#  'AMDHD1': 'AMDHD1',
#  'AMDHD2': 'AMDHD2',
#  'AMELX': 'AMELX',
#  'AMELY': 'AMELY',
#  'AMER1': 'AMER1',
#  'AMER2': 'AMER2',
#  'AMER3': 'AMER3',
#  'AMFR': 'AMFR',
#  'AMH': 'AMH',
#  'AMHR2': 'AMHR2',
#  'AMIGO1': 'AMIGO1',
#  'AMIGO2': 'AMIGO2',
#  'AMIGO3': 'AMIGO3',
#  'AMMECR1': 'AMMECR1',
#  'AMMECR1L': 'AMMECR1L',
#  'AMN': 'AMN',
#  'AMN1': 'AMN1',
#  'AMOT': 'AMOT',
#  'AMOTL1': 'AMOTL1',
#  'AMOTL2': 'AMOTL2',
#  'AMPD1': 'AMPD1',
#  'AMPD2': 'AMPD2',
#  'AMPD3': 'AMPD3',
#  'AMPH': 'AMPH',
#  'AMT': 'AMT',
#  'AMTN': 'AMTN',
#  'AMY2A': 'AMY2A',
#  'AMZ1': 'AMZ1',
#  'AMZ2': 'AMZ2',
#  'ANAPC1': 'ANAPC1',
#  'ANAPC10': 'ANAPC10',
#  'ANAPC11': 'ANAPC11',
#  'ANAPC13': 'ANAPC13',
#  'ANAPC15': 'ANAPC15',
#  'ANAPC16': 'ANAPC16',
#  'ANAPC2': 'ANAPC2',
#  'ANAPC4': 'ANAPC4',
#  'ANAPC5': 'ANAPC5',
#  'ANAPC7': 'ANAPC7',
#  'ANG': 'ANG',
#  'ANGEL1': 'ANGEL1',
#  'ANGEL2': 'ANGEL2',
#  'ANGPT1': 'ANGPT1',
#  'ANGPT2': 'ANGPT2',
#  'ANGPT4': 'ANGPT4',
#  'ANGPTL1': 'ANGPTL1',
#  'ANGPTL2': 'ANGPTL2',
#  'ANGPTL3': 'ANGPTL3',
#  'ANGPTL4': 'ANGPTL4',
#  'ANGPTL5': 'ANGPTL5',
#  'ANGPTL6': 'ANGPTL6',
#  'ANGPTL7': 'ANGPTL7',
#  'ANGPTL8': 'ANGPTL8',
#  'ANHX': 'ANHX',
#  'ANK1': 'ANK1',
#  'ANK2': 'ANK2',
#  'ANK3': 'ANK3',
#  'ANKAR': 'ANKAR',
#  'ANKDD1A': 'ANKDD1A',
#  'ANKDD1B': 'ANKDD1B',
#  'ANKEF1': 'ANKEF1',
#  'ANKFN1': 'ANKFN1',
#  'ANKFY1': 'ANKFY1',
#  'ANKH': 'ANKH',
#  'ANKHD1': 'ANKHD1',
#  'ANKIB1': 'ANKIB1',
#  'ANKK1': 'ANKK1',
#  'ANKLE1': 'ANKLE1',
#  'ANKLE2': 'ANKLE2',
#  'ANKMY1': 'ANKMY1',
#  'ANKMY2': 'ANKMY2',
#  'ANKRA2': 'ANKRA2',
#  'ANKRD1': 'ANKRD1',
#  'ANKRD10': 'ANKRD10',
#  'ANKRD11': 'ANKRD11',
#  'ANKRD12': 'ANKRD12',
#  'ANKRD13A': 'ANKRD13A',
#  'ANKRD13B': 'ANKRD13B',
#  'ANKRD13C': 'ANKRD13C',
#  'ANKRD13D': 'ANKRD13D',
#  'ANKRD16': 'ANKRD16',
#  'ANKRD17': 'ANKRD17',
#  'ANKRD18A': 'ANKRD18A',
#  'ANKRD18B': 'ANKRD18B',
#  'ANKRD2': 'ANKRD2',
#  'ANKRD22': 'ANKRD22',
#  'ANKRD23': 'ANKRD23',
#  'ANKRD24': 'ANKRD24',
#  'ANKRD26': 'ANKRD26',
#  'ANKRD27': 'ANKRD27',
#  'ANKRD28': 'ANKRD28',
#  'ANKRD29': 'ANKRD29',
#  'ANKRD30A': 'ANKRD30A',
#  'ANKRD30B': 'ANKRD30B',
#  'ANKRD30BL': 'ANKRD30BL',
#  'ANKRD31': 'ANKRD31',
#  'ANKRD33': 'ANKRD33',
#  'ANKRD33B': 'ANKRD33B',
#  'ANKRD34A': 'ANKRD34A',
#  'ANKRD34B': 'ANKRD34B',
#  'ANKRD34C': 'ANKRD34C',
#  'ANKRD35': 'ANKRD35',
#  'ANKRD36': 'ANKRD36',
#  'ANKRD36B': 'ANKRD36B',
#  'ANKRD36C': 'ANKRD36C',
#  'ANKRD37': 'ANKRD37',
#  'ANKRD39': 'ANKRD39',
#  'ANKRD40': 'ANKRD40',
#  'ANKRD40CL': 'ANKRD40CL',
#  'ANKRD42': 'ANKRD42',
#  'ANKRD44': 'ANKRD44',
#  'ANKRD45': 'ANKRD45',
#  'ANKRD46': 'ANKRD46',
#  'ANKRD49': 'ANKRD49',
#  'ANKRD50': 'ANKRD50',
#  'ANKRD52': 'ANKRD52',
#  'ANKRD53': 'ANKRD53',
#  'ANKRD54': 'ANKRD54',
#  'ANKRD55': 'ANKRD55',
#  'ANKRD6': 'ANKRD6',
#  'ANKRD60': 'ANKRD60',
#  'ANKRD61': 'ANKRD61',
#  'ANKRD62': 'ANKRD62',
#  'ANKRD63': 'ANKRD63',
#  'ANKRD65': 'ANKRD65',
#  'ANKRD66': 'ANKRD66',
#  'ANKRD7': 'ANKRD7',
#  'ANKRD9': 'ANKRD9',
#  'ANKS1A': 'ANKS1A',
#  'ANKS1B': 'ANKS1B',
#  'ANKS3': 'ANKS3',
#  'ANKS4B': 'ANKS4B',
#  'ANKS6': 'ANKS6',
#  'ANKUB1': 'ANKUB1',
#  'ANKZF1': 'ANKZF1',
#  'ANLN': 'ANLN',
#  'ANO1': 'ANO1',
#  'ANO10': 'ANO10',
#  'ANO2': 'ANO2',
#  'ANO3': 'ANO3',
#  'ANO4': 'ANO4',
#  'ANO5': 'ANO5',
#  'ANO6': 'ANO6',
#  'ANO7': 'ANO7',
#  'ANO8': 'ANO8',
#  'ANO9': 'ANO9',
#  'ANOS1': 'ANOS1',
#  'ANP32A': 'ANP32A',
#  'ANP32B': 'ANP32B',
#  'ANP32D': 'ANP32D',
#  'ANP32E': 'ANP32E',
#  'ANPEP': 'ANPEP',
#  'ANTKMT': 'ANTKMT',
#  'ANTXR1': 'ANTXR1',
#  'ANTXR2': 'ANTXR2',
#  'ANTXRL': 'ANTXRL',
#  'ANXA1': 'ANXA1',
#  'ANXA10': 'ANXA10',
#  'ANXA11': 'ANXA11',
#  'ANXA13': 'ANXA13',
#  'ANXA2': 'ANXA2',
#  'ANXA2R': 'ANXA2R',
#  'ANXA3': 'ANXA3',
#  'ANXA4': 'ANXA4',
#  'ANXA5': 'ANXA5',
#  'ANXA6': 'ANXA6',
#  'ANXA7': 'ANXA7',
#  'ANXA8': 'ANXA8',
#  'ANXA8L1': 'ANXA8L1',
#  'ANXA9': 'ANXA9',
#  'AOAH': 'AOAH',
#  'AOC1': 'AOC1',
#  'AOC2': 'AOC2',
#  'AOC3': 'AOC3',
#  'AOPEP': 'AOPEP',
#  'AOX1': 'AOX1',
#  'AP1AR': 'AP1AR',
#  'AP1B1': 'AP1B1',
#  'AP1G1': 'AP1G1',
#  'AP1G2': 'AP1G2',
#  'AP1M1': 'AP1M1',
#  'AP1M2': 'AP1M2',
#  'AP1S1': 'AP1S1',
#  'AP1S2': 'AP1S2',
#  'AP1S3': 'AP1S3',
#  'AP2A1': 'AP2A1',
#  'AP2A2': 'AP2A2',
#  'AP2B1': 'AP2B1',
#  'AP2M1': 'AP2M1',
#  'AP2S1': 'AP2S1',
#  'AP3B1': 'AP3B1',
#  'AP3B2': 'AP3B2',
#  'AP3D1': 'AP3D1',
#  'AP3M1': 'AP3M1',
#  'AP3M2': 'AP3M2',
#  'AP3S1': 'AP3S1',
#  'AP3S2': 'AP3S2',
#  'AP4B1': 'AP4B1',
#  'AP4E1': 'AP4E1',
#  'AP4M1': 'AP4M1',
#  'AP4S1': 'AP4S1',
#  'AP5B1': 'AP5B1',
#  'AP5M1': 'AP5M1',
#  'AP5S1': 'AP5S1',
#  'AP5Z1': 'AP5Z1',
#  'APAF1': 'APAF1',
#  'APBA1': 'APBA1',
#  'APBA2': 'APBA2',
#  'APBA3': 'APBA3',
#  'APBB1': 'APBB1',
#  'APBB1IP': 'APBB1IP',
#  'APBB2': 'APBB2',
#  'APBB3': 'APBB3',
#  'APC': 'APC',
#  'APC2': 'APC2',
#  'APCDD1': 'APCDD1',
#  'APCDD1L': 'APCDD1L',
#  'APCS': 'APCS',
#  'APEH': 'APEH',
#  'APELA': 'APELA',
#  'APEX1': 'APEX1',
#  'APEX2': 'APEX2',
#  'APH1A': 'APH1A',
#  'APH1B': 'APH1B',
#  'API5': 'API5',
#  'APIP': 'APIP',
#  'APLF': 'APLF',
#  'APLN': 'APLN',
#  'APLNR': 'APLNR',
#  'APLP1': 'APLP1',
#  'APLP2': 'APLP2',
#  'APMAP': 'APMAP',
#  'APOA1': 'APOA1',
#  'APOA2': 'APOA2',
#  'APOA4': 'APOA4',
#  'APOA5': 'APOA5',
#  'APOB': 'APOB',
#  'APOBEC1': 'APOBEC1',
#  'APOBEC2': 'APOBEC2',
#  'APOBEC3A': 'APOBEC3A',
#  'APOBEC3B': 'APOBEC3B',
#  'APOBEC3C': 'APOBEC3C',
#  'APOBEC3D': 'APOBEC3D',
#  'APOBEC3F': 'APOBEC3F',
#  'APOBEC3G': 'APOBEC3G',
#  'APOBEC3H': 'APOBEC3H',
#  'APOBEC4': 'APOBEC4',
#  'APOBR': 'APOBR',
#  'APOC1': 'APOC1',
#  'APOC2': 'APOC2',
#  'APOC3': 'APOC3',
#  'APOC4': 'APOC4',
#  'APOD': 'APOD',
#  'APOE': 'APOE',
#  'APOF': 'APOF',
#  'APOH': 'APOH',
#  'APOL1': 'APOL1',
#  'APOL2': 'APOL2',
#  'APOL3': 'APOL3',
#  'APOL4': 'APOL4',
#  'APOL5': 'APOL5',
#  'APOL6': 'APOL6',
#  'APOLD1': 'APOLD1',
#  'APOM': 'APOM',
#  'APOO': 'APOO',
#  'APOOL': 'APOOL',
#  'APP': 'APP',
#  'APPBP2': 'APPBP2',
#  'APPL1': 'APPL1',
#  'APPL2': 'APPL2',
#  'APRT': 'APRT',
#  'APTX': 'APTX',
#  'AQP1': 'AQP1',
#  'AQP10': 'AQP10',
#  'AQP11': 'AQP11',
#  'AQP12B': 'AQP12B',
#  'AQP2': 'AQP2',
#  'AQP3': 'AQP3',
#  'AQP4': 'AQP4',
#  'AQP5': 'AQP5',
#  'AQP6': 'AQP6',
#  'AQP7': 'AQP7',
#  'AQP8': 'AQP8',
#  'AQP9': 'AQP9',
#  'AQR': 'AQR',
#  'AR': 'AR',
#  'ARAF': 'ARAF',
#  'ARAP1': 'ARAP1',
#  'ARAP2': 'ARAP2',
#  'ARAP3': 'ARAP3',
#  'ARC': 'ARC',
#  'ARCN1': 'ARCN1',
#  'AREG': 'AREG',
#  'AREL1': 'AREL1',
#  'ARF1': 'ARF1',
#  'ARF3': 'ARF3',
#  'ARF4': 'ARF4',
#  'ARF5': 'ARF5',
#  'ARF6': 'ARF6',
#  'ARFGAP1': 'ARFGAP1',
#  'ARFGAP2': 'ARFGAP2',
#  'ARFGAP3': 'ARFGAP3',
#  'ARFGEF1': 'ARFGEF1',
#  'ARFGEF2': 'ARFGEF2',
#  'ARFGEF3': 'ARFGEF3',
#  'ARFIP1': 'ARFIP1',
#  'ARFIP2': 'ARFIP2',
#  'ARFRP1': 'ARFRP1',
#  'ARG1': 'ARG1',
#  'ARG2': 'ARG2',
#  'ARGFX': 'ARGFX',
#  'ARGLU1': 'ARGLU1',
#  'ARHGAP1': 'ARHGAP1',
#  'ARHGAP10': 'ARHGAP10',
#  'ARHGAP11A': 'ARHGAP11A',
#  'ARHGAP12': 'ARHGAP12',
#  'ARHGAP15': 'ARHGAP15',
#  'ARHGAP17': 'ARHGAP17',
#  'ARHGAP18': 'ARHGAP18',
#  'ARHGAP19': 'ARHGAP19',
#  'ARHGAP20': 'ARHGAP20',
#  'ARHGAP21': 'ARHGAP21',
#  'ARHGAP22': 'ARHGAP22',
#  'ARHGAP23': 'ARHGAP23',
#  'ARHGAP24': 'ARHGAP24',
#  'ARHGAP25': 'ARHGAP25',
#  'ARHGAP26': 'ARHGAP26',
#  'ARHGAP27': 'ARHGAP27',
#  'ARHGAP28': 'ARHGAP28',
#  'ARHGAP29': 'ARHGAP29',
#  'ARHGAP30': 'ARHGAP30',
#  'ARHGAP31': 'ARHGAP31',
#  'ARHGAP32': 'ARHGAP32',
#  'ARHGAP33': 'ARHGAP33',
#  'ARHGAP35': 'ARHGAP35',
#  'ARHGAP36': 'ARHGAP36',
#  'ARHGAP39': 'ARHGAP39',
#  'ARHGAP4': 'ARHGAP4',
#  'ARHGAP44': 'ARHGAP44',
#  'ARHGAP45': 'ARHGAP45',
#  'ARHGAP5': 'ARHGAP5',
#  'ARHGAP6': 'ARHGAP6',
#  'ARHGAP8': 'ARHGAP8',
#  'ARHGAP9': 'ARHGAP9',
#  'ARHGDIA': 'ARHGDIA',
#  'ARHGDIB': 'ARHGDIB',
#  'ARHGDIG': 'ARHGDIG',
#  'ARHGEF1': 'ARHGEF1',
#  'ARHGEF10': 'ARHGEF10',
#  'ARHGEF10L': 'ARHGEF10L',
#  'ARHGEF11': 'ARHGEF11',
#  'ARHGEF12': 'ARHGEF12',
#  'ARHGEF15': 'ARHGEF15',
#  'ARHGEF16': 'ARHGEF16',
#  'ARHGEF17': 'ARHGEF17',
#  'ARHGEF18': 'ARHGEF18',
#  'ARHGEF19': 'ARHGEF19',
#  'ARHGEF2': 'ARHGEF2',
#  'ARHGEF25': 'ARHGEF25',
#  'ARHGEF26': 'ARHGEF26',
#  'ARHGEF28': 'ARHGEF28',
#  'ARHGEF3': 'ARHGEF3',
#  'ARHGEF33': 'ARHGEF33',
#  'ARHGEF35': 'ARHGEF35',
#  'ARHGEF37': 'ARHGEF37',
#  'ARHGEF38': 'ARHGEF38',
#  'ARHGEF39': 'ARHGEF39',
#  'ARHGEF4': 'ARHGEF4',
#  'ARHGEF40': 'ARHGEF40',
#  'ARHGEF5': 'ARHGEF5',
#  'ARHGEF6': 'ARHGEF6',
#  'ARHGEF7': 'ARHGEF7',
#  'ARHGEF9': 'ARHGEF9',
#  'ARID1A': 'ARID1A',
#  'ARID1B': 'ARID1B',
#  'ARID2': 'ARID2',
#  'ARID3A': 'ARID3A',
#  'ARID3B': 'ARID3B',
#  'ARID3C': 'ARID3C',
#  'ARID4A': 'ARID4A',
#  'ARID4B': 'ARID4B',
#  'ARID5A': 'ARID5A',
#  'ARID5B': 'ARID5B',
#  'ARIH1': 'ARIH1',
#  'ARIH2': 'ARIH2',
#  'ARL1': 'ARL1',
#  'ARL10': 'ARL10',
#  'ARL11': 'ARL11',
#  'ARL13A': 'ARL13A',
#  'ARL13B': 'ARL13B',
#  'ARL14': 'ARL14',
#  'ARL14EP': 'ARL14EP',
#  'ARL14EPL': 'ARL14EPL',
#  'ARL15': 'ARL15',
#  'ARL16': 'ARL16',
#  'ARL2': 'ARL2',
#  'ARL2BP': 'ARL2BP',
#  'ARL3': 'ARL3',
#  ...}

# %%
len(mapper)
# Out:
# 18420

# %%
len(depmap_genes)
# Out:
# 18435

# %% [markdown]
# #### Create Final Mapper

# %%
data = []
for gene in mapper:
    curr = []
    curr.append(mapper[gene])
    curr.append(gene)
    data.append(curr)
df = pd.DataFrame(data)
df.columns = ["Gene Name", "DepMap Gene Name"]

# %%
df.to_csv("/mnt/c/Users/Owner/OneDrive/Documents/BENG_Senior_Design/DepMap/data/coamp_gene_mapper_12.21.24.tsv", sep = "\t", index = False)
